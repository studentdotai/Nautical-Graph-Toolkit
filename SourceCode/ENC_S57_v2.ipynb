# %% [markdown]
# ### Imports

# %%
from osgeo import ogr, osr
import os
import base64 # for encoding the image (SVG)
import re

import glob

# %% [markdown]
# ### Files

# %%
s57_folder = "GIS_files/11CGD_ENCs/ENC_ROOT"
s57_all_encs = 'GIS_files/All_ENCs'
geopackage_export_folder = 'GIS_export/ENC2/'
enc_dvd = "G:/Python Projects/ENC Files/DVD_1"

# %% [markdown]
# Converting S57 to GeoPackage

# %%
os.environ['OGR_S57_OPTIONS'] = '''RETURN_PRIMITIVES=OFF, 
                                   SPLIT_MULTIPOINT=ON,
                                   ADD_SOUNDG_DEPTH=ON,
                                   RETURN_LINKAGES=ON, 
                                   RECODE_BY_DSSI=ON'''

def is_empty_or_null(value):
    if value is None:
        return True
    if isinstance(value, str):
        return value.strip() == "" or value.strip().lower() in ["null", "none"]
    return False



def convert_s57_to_geopackage(s57_file_path, geopackage_export_folder):
    """
    Convert an S-57 ENC file to GeoPackage format.

    Parameters:
    s57_file_path (str): Path to the input S-57 file.
    geopackage_path (str): Path to the output GeoPackage file.

    Returns:
    None
    """
    # Extract the base name of the S57 file (without extension)
    s57_base_name = os.path.splitext(os.path.basename(s57_file_path))[0]
    
    # Create the full path for the output GeoPackage directly in the export folder
    geopackage_export_path = os.path.join(geopackage_export_folder, f"{s57_base_name}.gpkg")
    
    # Ensure the export folder exists
    os.makedirs(geopackage_export_folder, exist_ok=True)

    print(f"Attempting to create GeoPackage at: {geopackage_export_path}")
    # Register drivers
    ogr.RegisterAll()
    s57_driver = ogr.GetDriverByName('S57')
    gpkg_driver = ogr.GetDriverByName('GPKG')

    # Open the S-57 file
    s57 = s57_driver.Open(s57_file_path)
    if s57 is None:
        raise RuntimeError(f"Could not open S-57 file: {s57_file_path}")
    else:
        print(f"S-57 file opened: {s57_file_path}")

    # Create the GeoPackage file
    gpkg = gpkg_driver.CreateDataSource(geopackage_export_path)
    if gpkg is None:
        raise RuntimeError(f"Could not create GeoPackage: {geopackage_export_path}")
    else:
        print(f"GeoPackage created: {geopackage_export_path}")

    # Get the number of layers in the S-57 file
    num_layers = s57.GetLayerCount()
    print(f"Number of layers in S-57 file: {num_layers}")

    # # Check if the S-57 projection is EPSG:4326 (WGS84)
    
    # print(f"S-57 spatial reference system: {srs_s57}")
    # if srs_s57 is not None:
    #     if srs.IsSame(osr.SpatialReference().ImportFromEPSG(4326)):
    #         print("S-57 projection is EPSG:4326 (WGS84)")
    #     else:
    #         print("S-57 projection is not EPSG:4326")
    # else:
    #     print("Spatial reference system is not defined")
    

    # Loop through the layers in the S-57 file
    for i in range(num_layers):
        layer = s57.GetLayer(i)
        layer_name = layer.GetName()
        layer_defn = layer.GetLayerDefn()
        print(f"\nProcessing S-57 layer: {layer_name} in {s57_base_name} ENC")

        # Get the spatial reference system of the layer
        srs = layer.GetSpatialRef()
        if srs:
            # Get the EPSG code
            epsg_code = srs.GetAuthorityCode(None)
            # Get the projection name
            datum_name = srs.GetAttrValue('DATUM')
            proj_name = srs.GetAttrValue('PROJECTION')
            units = srs.GetAttrValue('UNIT')
            
            print(f"Layer {i+1}: {layer_name}")
            print(f"EPSG Code: {epsg_code}")
            print(f"Datum: {datum_name if datum_name else 'Not specified'}")
            print(f"Projection: {proj_name if proj_name else 'Not specified'}")
            print(f"Units: {units if units else 'Not specified'}")
        else:
            print(f"\nLayer {i+1}: {layer_name}")
            print("No spatial reference system defined")

        # Create the corresponding layer in the GeoPackage file
        gpkg_layer = gpkg.CreateLayer(layer_name, srs, layer.GetGeomType())
        if gpkg_layer is None:
            raise RuntimeError(f"Could not create layer: {layer_name}")
        else:
            print(f"GeoPackage layer created: {layer_name}")

        # Add fields to the GeoPackage layer
        for i in range(layer_defn.GetFieldCount()):
            s57_field_defn = layer_defn.GetFieldDefn(i)
            field_name = s57_field_defn.GetName()
            field_type = s57_field_defn.GetType()
            
            field_defn = ogr.FieldDefn(field_name, field_type)
            gpkg_layer.CreateField(field_defn)

        # Get the number of features in the layer
        num_features = layer.GetFeatureCount()
        print(f"Number of features in {layer_name} layer: {num_features}")
        
        """This approach uses the layer's GetNextFeature() method to iterate through 
        features, which is more reliable than using indices. It will properly iterate 
        through all available features and their fields, avoiding the "Skipping null 
        feature" issue for valid features."""

        # Loop through the features in the layer
        layer.ResetReading()  # Reset the reading position to the start of the layer
        feature = layer.GetNextFeature()


        while feature:
            feature_id = feature.GetFID()
            print(f"Processing feature ID: {feature_id}")

            # Get the feature geometry
            geometry = feature.GetGeometryRef()

            # Create the feature in the GeoPackage layer
            gpkg_feature = ogr.Feature(gpkg_layer.GetLayerDefn())

            if layer_name != "DSID":
                if geometry is None:
                    print(f"Feature {feature_id} has no geometry, skipping")
                    feature = layer.GetNextFeature()
                    continue
                print(f"Processing {geometry.GetGeometryName()} geometry...")
                gpkg_feature.SetGeometry(geometry)

            # Loop through the fields in the feature
            for i in range(feature.GetFieldCount()):
                field_def = feature.GetFieldDefnRef(i)
                field_name = field_def.GetName()
                field_type = field_defn.GetType()
                field_value = feature.GetFieldAsString(field_name)
                
                # Check if the field is NULL in S-57
                if is_empty_or_null(field_value):
                    gpkg_feature.SetFieldNull(i)
                else: 
                    gpkg_feature.SetField(field_name, field_value)

            # Add the feature to the GeoPackage layer
            if gpkg_layer.CreateFeature(gpkg_feature) != 0:
                raise RuntimeError(f"Failed to create feature {feature_id} in layer {layer_name}")
            
            print(f"Feature {feature_id} created in layer: {layer_name}")

            if layer.GetName() == "DSID":
                edition = feature.GetFieldAsString("DSID_EDTN")
                update = feature.GetFieldAsString("DSID_UPDN")
                print(f"ENC {s57_base_name} EDITION: {edition}")
                print(f"ENC {s57_base_name} UPDATE: {update}")

            # Get the next feature
            feature = layer.GetNextFeature()
        
        # Compare None values
        field_names = [layer_defn.GetFieldDefn(i).GetName() for i in range(layer_defn.GetFieldCount())]
        for s57_feature, gpkg_feature in zip(layer, gpkg_layer):
            for i, field_name in enumerate(field_names):
                s57_field_type = s57_feature.GetFieldDefnRef(field_name).GetType()
                
                # Handle list types correctly
                if s57_field_type in [ogr.OFTStringList, ogr.OFTIntegerList, ogr.OFTRealList]:
                    # Retrieve the correct list based on the field type
                    if s57_field_type == ogr.OFTStringList:
                        get_value = s57_feature.GetFieldAsStringList(i)
                    elif s57_field_type == ogr.OFTIntegerList:
                        get_value = s57_feature.GetFieldAsIntegerList(i)
                    elif s57_field_type == ogr.OFTRealList:
                        get_value = s57_feature.GetFieldAsDoubleList(i)

                    if get_value:
                        # Convert all elements to strings (if needed)
                        string_list = ",".join([str(item) for item in get_value])
                        gpkg_feature.SetField(i, string_list)
                        

                s57_value = s57_feature.GetField(field_name)
                gpkg_value = gpkg_feature.GetField(field_name)
                if s57_value is None and gpkg_value is not None:
                    print(f"Mismatch in {field_name} ({s57_field_type}): S-57 None, GeoPackage {gpkg_value}")
                elif s57_value is not None and gpkg_value is None:
                    print(f"Mismatch in {field_name} ({s57_field_type}): S-57 {s57_value}, GeoPackage None")
                    
                        
        # Reset the layer reading position after processing
        layer.ResetReading()
    # Close the dataset
    gpkg = None
    s57 = None

# Browse the ENC_ROOT folder and process all S-57 files
def process_enc_folder(enc_folder_path, geopackage_export_folder):
    s57_files = []
    for root, dirs, files in os.walk(enc_folder_path):
        for path in glob.glob(os.path.join(root, '*.000')):
            s57_files.extend([os.path.normpath(path) for path in glob.glob(os.path.join(root, '*.[0-9][0-9][0-9]'))])
    
    print(f"Found {len(s57_files)} S-57 files in folder: {enc_folder_path}")
    if s57_files:
        print(s57_files)
        for s57_file in s57_files:
            print(f"\nProcessing S-57 file: {s57_file}")
            convert_s57_to_geopackage(s57_file, geopackage_export_folder)  

# Example usage
s57_folder = "GIS_files/07CGD_ENCs/ENC_ROOT"
geopackage_export_folder = 'GIS_export/ENC2/'
process_enc_folder(s57_folder, geopackage_export_folder)
# Out:
# Found 842 S-57 files in folder: GIS_files/07CGD_ENCs/ENC_ROOT
# ['GIS_files\\07CGD_ENCs\\ENC_ROOT\\US1GC09M\\US1GC09M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US1GC09M\\US1GC09M.001', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US1GC09M\\US1GC09M.002', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US1GC09M\\US1GC09M.003', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US2EC01M\\US2EC01M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US2EC01M\\US2EC01M.001', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US2EC01M\\US2EC01M.002', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US2EC02M\\US2EC02M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US2GC09M\\US2GC09M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US3FL28M\\US3FL28M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US3FL28M\\US3FL28M.001', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US3FL30M\\US3FL30M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US3FL90M\\US3FL90M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US3GA10M\\US3GA10M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US3GC06M\\US3GC06M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US3GC07M\\US3GC07M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US3PR10M\\US3PR10M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US3PR10M\\US3PR10M.001', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US3SC10M\\US3SC10M.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US410840\\US410840.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US410865\\US410865.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US410880\\US410880.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US410880\\US410880.001', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US410930\\US410930.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1EP\\US4FL1EP.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1EQ\\US4FL1EQ.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1ER\\US4FL1ER.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1ES\\US4FL1ES.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1FP\\US4FL1FP.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1FQ\\US4FL1FQ.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1FR\\US4FL1FR.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1FS\\US4FL1FS.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1GS\\US4FL1GS.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1GT\\US4FL1GT.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1GU\\US4FL1GU.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1GV\\US4FL1GV.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1GW\\US4FL1GW.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1HS\\US4FL1HS.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1HT\\US4FL1HT.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1HU\\US4FL1HU.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1HV\\US4FL1HV.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1HW\\US4FL1HW.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1IS\\US4FL1IS.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1IT\\US4FL1IT.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1IU\\US4FL1IU.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1IV\\US4FL1IV.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1JS\\US4FL1JS.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1JT\\US4FL1JT.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1JT\\US4FL1JT.001', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1JU\\US4FL1JU.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1JV\\US4FL1JV.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1KR\\US4FL1KR.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1KS\\US4FL1KS.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1KT\\US4FL1KT.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1LR\\US4FL1LR.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1LS\\US4FL1LS.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1LT\\US4FL1LT.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1MP\\US4FL1MP.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1MQ\\US4FL1MQ.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1MR\\US4FL1MR.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1MR\\US4FL1MR.001', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1MS\\US4FL1MS.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1MS\\US4FL1MS.001', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1MS\\US4FL1MS.002', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1MS\\US4FL1MS.003', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1MS\\US4FL1MS.004', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1NP\\US4FL1NP.000', 'GIS_files\\07CGD_ENCs\\ENC_ROOT\\US4FL1NQ\\US ...
#
# Processing S-57 file: GIS_files\07CGD_ENCs\ENC_ROOT\US1GC09M\US1GC09M.000
# Attempting to create GeoPackage at: GIS_export/ENC2/US1GC09M.gpkg
# S-57 file opened: GIS_files\07CGD_ENCs\ENC_ROOT\US1GC09M\US1GC09M.000
# GeoPackage created: GIS_export/ENC2/US1GC09M.gpkg
# Number of layers in S-57 file: 66
#
# Processing S-57 layer: DSID in US1GC09M ENC
#
# Layer 1: DSID
# No spatial reference system defined
# GeoPackage layer created: DSID
# Number of features in DSID layer: 1
# Processing feature ID: 0
# Feature 0 created in layer: DSID
# ENC US1GC09M EDITION: 65
# ENC US1GC09M UPDATE: 3
# Mismatch in DSID_PSDN (4): S-57 , GeoPackage None
#
# Processing S-57 layer: IsolatedNode in US1GC09M ENC
# Layer 2: IsolatedNode
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: IsolatedNode
# Number of features in IsolatedNode layer: 0
#
# Processing S-57 layer: ConnectedNode in US1GC09M ENC
# Layer 3: ConnectedNode
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: ConnectedNode
# Number of features in ConnectedNode layer: 0
#
# Processing S-57 layer: Edge in US1GC09M ENC
# Layer 4: Edge
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: Edge
# Number of features in Edge layer: 0
#
# Processing S-57 layer: Face in US1GC09M ENC
# Layer 5: Face
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: Face
# Number of features in Face layer: 0
#
# Processing S-57 layer: ADMARE in US1GC09M ENC
# Layer 6: ADMARE
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: ADMARE
# Number of features in ADMARE layer: 6
# Processing feature ID: 4773
# Processing POLYGON geometry...
# Feature 4773 created in layer: ADMARE
# Processing feature ID: 4774
# Processing POLYGON geometry...
# Feature 4774 created in layer: ADMARE
# Processing feature ID: 4775
# Processing POLYGON geometry...
# Feature 4775 created in layer: ADMARE
# Processing feature ID: 4776
# Processing POLYGON geometry...
# Feature 4776 created in layer: ADMARE
# Processing feature ID: 4777
# Processing POLYGON geometry...
# Feature 4777 created in layer: ADMARE
# Processing feature ID: 4778
# Processing POLYGON geometry...
# Feature 4778 created in layer: ADMARE
#
# Processing S-57 layer: ACHARE in US1GC09M ENC
# Layer 7: ACHARE
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: ACHARE
# Number of features in ACHARE layer: 1
# Processing feature ID: 4869
# Processing POINT geometry...
# Feature 4869 created in layer: ACHARE
#
# Processing S-57 layer: BCNLAT in US1GC09M ENC
# Layer 8: BCNLAT
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: BCNLAT
# Number of features in BCNLAT layer: 6
# Processing feature ID: 0
# Processing POINT geometry...
# Feature 0 created in layer: BCNLAT
# Processing feature ID: 1
# Processing POINT geometry...
# Feature 1 created in layer: BCNLAT
# Processing feature ID: 2
# Processing POINT geometry...
# Feature 2 created in layer: BCNLAT
# Processing feature ID: 3
# Processing POINT geometry...
# Feature 3 created in layer: BCNLAT
# Processing feature ID: 4
# Processing POINT geometry...
# Feature 4 created in layer: BCNLAT
# Processing feature ID: 5
# Processing POINT geometry...
# Feature 5 created in layer: BCNLAT
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
#
# Processing S-57 layer: BCNSPP in US1GC09M ENC
# Layer 9: BCNSPP
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: BCNSPP
# Number of features in BCNSPP layer: 76
# Processing feature ID: 6
# Processing POINT geometry...
# Feature 6 created in layer: BCNSPP
# Processing feature ID: 7
# Processing POINT geometry...
# Feature 7 created in layer: BCNSPP
# Processing feature ID: 8
# Processing POINT geometry...
# Feature 8 created in layer: BCNSPP
# Processing feature ID: 9
# Processing POINT geometry...
# Feature 9 created in layer: BCNSPP
# Processing feature ID: 10
# Processing POINT geometry...
# Feature 10 created in layer: BCNSPP
# Processing feature ID: 11
# Processing POINT geometry...
# Feature 11 created in layer: BCNSPP
# Processing feature ID: 12
# Processing POINT geometry...
# Feature 12 created in layer: BCNSPP
# Processing feature ID: 13
# Processing POINT geometry...
# Feature 13 created in layer: BCNSPP
# Processing feature ID: 14
# Processing POINT geometry...
# Feature 14 created in layer: BCNSPP
# Processing feature ID: 15
# Processing POINT geometry...
# Feature 15 created in layer: BCNSPP
# Processing feature ID: 16
# Processing POINT geometry...
# Feature 16 created in layer: BCNSPP
# Processing feature ID: 17
# Processing POINT geometry...
# Feature 17 created in layer: BCNSPP
# Processing feature ID: 18
# Processing POINT geometry...
# Feature 18 created in layer: BCNSPP
# Processing feature ID: 19
# Processing POINT geometry...
# Feature 19 created in layer: BCNSPP
# Processing feature ID: 20
# Processing POINT geometry...
# Feature 20 created in layer: BCNSPP
# Processing feature ID: 21
# Processing POINT geometry...
# Feature 21 created in layer: BCNSPP
# Processing feature ID: 22
# Processing POINT geometry...
# Feature 22 created in layer: BCNSPP
# Processing feature ID: 23
# Processing POINT geometry...
# Feature 23 created in layer: BCNSPP
# Processing feature ID: 24
# Processing POINT geometry...
# Feature 24 created in layer: BCNSPP
# Processing feature ID: 25
# Processing POINT geometry...
# Feature 25 created in layer: BCNSPP
# Processing feature ID: 26
# Processing POINT geometry...
# Feature 26 created in layer: BCNSPP
# Processing feature ID: 27
# Processing POINT geometry...
# Feature 27 created in layer: BCNSPP
# Processing feature ID: 28
# Processing POINT geometry...
# Feature 28 created in layer: BCNSPP
# Processing feature ID: 29
# Processing POINT geometry...
# Feature 29 created in layer: BCNSPP
# Processing feature ID: 30
# Processing POINT geometry...
# Feature 30 created in layer: BCNSPP
# Processing feature ID: 31
# Processing POINT geometry...
# Feature 31 created in layer: BCNSPP
# Processing feature ID: 32
# Processing POINT geometry...
# Feature 32 created in layer: BCNSPP
# Processing feature ID: 33
# Processing POINT geometry...
# Feature 33 created in layer: BCNSPP
# Processing feature ID: 34
# Processing POINT geometry...
# Feature 34 created in layer: BCNSPP
# Processing feature ID: 35
# Processing POINT geometry...
# Feature 35 created in layer: BCNSPP
# Processing feature ID: 36
# Processing POINT geometry...
# Feature 36 created in layer: BCNSPP
# Processing feature ID: 37
# Processing POINT geometry...
# Feature 37 created in layer: BCNSPP
# Processing feature ID: 38
# Processing POINT geometry...
# Feature 38 created in layer: BCNSPP
# Processing feature ID: 39
# Processing POINT geometry...
# Feature 39 created in layer: BCNSPP
# Processing feature ID: 40
# Processing POINT geometry...
# Feature 40 created in layer: BCNSPP
# Processing feature ID: 41
# Processing POINT geometry...
# Feature 41 created in layer: BCNSPP
# Processing feature ID: 42
# Processing POINT geometry...
# Feature 42 created in layer: BCNSPP
# Processing feature ID: 43
# Processing POINT geometry...
# Feature 43 created in layer: BCNSPP
# Processing feature ID: 44
# Processing POINT geometry...
# Feature 44 created in layer: BCNSPP
# Processing feature ID: 45
# Processing POINT geometry...
# Feature 45 created in layer: BCNSPP
# Processing feature ID: 46
# Processing POINT geometry...
# Feature 46 created in layer: BCNSPP
# Processing feature ID: 47
# Processing POINT geometry...
# Feature 47 created in layer: BCNSPP
# Processing feature ID: 48
# Processing POINT geometry...
# Feature 48 created in layer: BCNSPP
# Processing feature ID: 49
# Processing POINT geometry...
# Feature 49 created in layer: BCNSPP
# Processing feature ID: 50
# Processing POINT geometry...
# Feature 50 created in layer: BCNSPP
# Processing feature ID: 51
# Processing POINT geometry...
# Feature 51 created in layer: BCNSPP
# Processing feature ID: 52
# Processing POINT geometry...
# Feature 52 created in layer: BCNSPP
# Processing feature ID: 53
# Processing POINT geometry...
# Feature 53 created in layer: BCNSPP
# Processing feature ID: 54
# Processing POINT geometry...
# Feature 54 created in layer: BCNSPP
# Processing feature ID: 55
# Processing POINT geometry...
# Feature 55 created in layer: BCNSPP
# Processing feature ID: 56
# Processing POINT geometry...
# Feature 56 created in layer: BCNSPP
# Processing feature ID: 57
# Processing POINT geometry...
# Feature 57 created in layer: BCNSPP
# Processing feature ID: 58
# Processing POINT geometry...
# Feature 58 created in layer: BCNSPP
# Processing feature ID: 59
# Processing POINT geometry...
# Feature 59 created in layer: BCNSPP
# Processing feature ID: 60
# Processing POINT geometry...
# Feature 60 created in layer: BCNSPP
# Processing feature ID: 61
# Processing POINT geometry...
# Feature 61 created in layer: BCNSPP
# Processing feature ID: 62
# Processing POINT geometry...
# Feature 62 created in layer: BCNSPP
# Processing feature ID: 63
# Processing POINT geometry...
# Feature 63 created in layer: BCNSPP
# Processing feature ID: 64
# Processing POINT geometry...
# Feature 64 created in layer: BCNSPP
# Processing feature ID: 65
# Processing POINT geometry...
# Feature 65 created in layer: BCNSPP
# Processing feature ID: 66
# Processing POINT geometry...
# Feature 66 created in layer: BCNSPP
# Processing feature ID: 67
# Processing POINT geometry...
# Feature 67 created in layer: BCNSPP
# Processing feature ID: 68
# Processing POINT geometry...
# Feature 68 created in layer: BCNSPP
# Processing feature ID: 69
# Processing POINT geometry...
# Feature 69 created in layer: BCNSPP
# Processing feature ID: 70
# Processing POINT geometry...
# Feature 70 created in layer: BCNSPP
# Processing feature ID: 71
# Processing POINT geometry...
# Feature 71 created in layer: BCNSPP
# Processing feature ID: 72
# Processing POINT geometry...
# Feature 72 created in layer: BCNSPP
# Processing feature ID: 73
# Processing POINT geometry...
# Feature 73 created in layer: BCNSPP
# Processing feature ID: 74
# Processing POINT geometry...
# Feature 74 created in layer: BCNSPP
# Processing feature ID: 75
# Processing POINT geometry...
# Feature 75 created in layer: BCNSPP
# Processing feature ID: 76
# Processing POINT geometry...
# Feature 76 created in layer: BCNSPP
# Processing feature ID: 77
# Processing POINT geometry...
# Feature 77 created in layer: BCNSPP
# Processing feature ID: 78
# Processing POINT geometry...
# Feature 78 created in layer: BCNSPP
# Processing feature ID: 79
# Processing POINT geometry...
# Feature 79 created in layer: BCNSPP
# Processing feature ID: 80
# Processing POINT geometry...
# Feature 80 created in layer: BCNSPP
# Processing feature ID: 81
# Processing POINT geometry...
# Feature 81 created in layer: BCNSPP
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2, 2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
#
# Processing S-57 layer: BRIDGE in US1GC09M ENC
# Layer 10: BRIDGE
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: BRIDGE
# Number of features in BRIDGE layer: 22
# Processing feature ID: 1751
# Processing LINESTRING geometry...
# Feature 1751 created in layer: BRIDGE
# Processing feature ID: 1752
# Processing LINESTRING geometry...
# Feature 1752 created in layer: BRIDGE
# Processing feature ID: 1753
# Processing LINESTRING geometry...
# Feature 1753 created in layer: BRIDGE
# Processing feature ID: 1754
# Processing LINESTRING geometry...
# Feature 1754 created in layer: BRIDGE
# Processing feature ID: 1755
# Processing LINESTRING geometry...
# Feature 1755 created in layer: BRIDGE
# Processing feature ID: 1756
# Processing LINESTRING geometry...
# Feature 1756 created in layer: BRIDGE
# Processing feature ID: 1757
# Processing LINESTRING geometry...
# Feature 1757 created in layer: BRIDGE
# Processing feature ID: 1758
# Processing LINESTRING geometry...
# Feature 1758 created in layer: BRIDGE
# Processing feature ID: 1759
# Processing LINESTRING geometry...
# Feature 1759 created in layer: BRIDGE
# Processing feature ID: 1760
# Processing LINESTRING geometry...
# Feature 1760 created in layer: BRIDGE
# Processing feature ID: 1761
# Processing LINESTRING geometry...
# Feature 1761 created in layer: BRIDGE
# Processing feature ID: 1762
# Processing LINESTRING geometry...
# Feature 1762 created in layer: BRIDGE
# Processing feature ID: 1763
# Processing LINESTRING geometry...
# Feature 1763 created in layer: BRIDGE
# Processing feature ID: 1764
# Processing LINESTRING geometry...
# Feature 1764 created in layer: BRIDGE
# Processing feature ID: 1765
# Processing LINESTRING geometry...
# Feature 1765 created in layer: BRIDGE
# Processing feature ID: 1766
# Processing LINESTRING geometry...
# Feature 1766 created in layer: BRIDGE
# Processing feature ID: 1767
# Processing LINESTRING geometry...
# Feature 1767 created in layer: BRIDGE
# Processing feature ID: 1768
# Processing LINESTRING geometry...
# Feature 1768 created in layer: BRIDGE
# Processing feature ID: 1769
# Processing LINESTRING geometry...
# Feature 1769 created in layer: BRIDGE
# Processing feature ID: 1770
# Processing LINESTRING geometry...
# Feature 1770 created in layer: BRIDGE
# Processing feature ID: 1771
# Processing LINESTRING geometry...
# Feature 1771 created in layer: BRIDGE
# Processing feature ID: 1772
# Processing LINESTRING geometry...
# Feature 1772 created in layer: BRIDGE
#
# Processing S-57 layer: BUISGL in US1GC09M ENC
# Layer 11: BUISGL
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: BUISGL
# Number of features in BUISGL layer: 6
# Processing feature ID: 1928
# Processing POINT geometry...
# Feature 1928 created in layer: BUISGL
# Processing feature ID: 1929
# Processing POINT geometry...
# Feature 1929 created in layer: BUISGL
# Processing feature ID: 1930
# Processing POINT geometry...
# Feature 1930 created in layer: BUISGL
# Processing feature ID: 1931
# Processing POINT geometry...
# Feature 1931 created in layer: BUISGL
# Processing feature ID: 1932
# Processing POINT geometry...
# Feature 1932 created in layer: BUISGL
# Processing feature ID: 1933
# Processing POINT geometry...
# Feature 1933 created in layer: BUISGL
#
# Processing S-57 layer: BUAARE in US1GC09M ENC
# Layer 12: BUAARE
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: BUAARE
# Number of features in BUAARE layer: 164
# Processing feature ID: 1742
# Processing POLYGON geometry...
# Feature 1742 created in layer: BUAARE
# Processing feature ID: 1743
# Processing POLYGON geometry...
# Feature 1743 created in layer: BUAARE
# Processing feature ID: 1744
# Processing POLYGON geometry...
# Feature 1744 created in layer: BUAARE
# Processing feature ID: 1745
# Processing POLYGON geometry...
# Feature 1745 created in layer: BUAARE
# Processing feature ID: 1746
# Processing POLYGON geometry...
# Feature 1746 created in layer: BUAARE
# Processing feature ID: 1747
# Processing POLYGON geometry...
# Feature 1747 created in layer: BUAARE
# Processing feature ID: 1748
# Processing POLYGON geometry...
# Feature 1748 created in layer: BUAARE
# Processing feature ID: 1749
# Processing POLYGON geometry...
# Feature 1749 created in layer: BUAARE
# Processing feature ID: 1750
# Processing POLYGON geometry...
# Feature 1750 created in layer: BUAARE
# Processing feature ID: 1773
# Processing POINT geometry...
# Feature 1773 created in layer: BUAARE
# Processing feature ID: 1774
# Processing POINT geometry...
# Feature 1774 created in layer: BUAARE
# Processing feature ID: 1775
# Processing POINT geometry...
# Feature 1775 created in layer: BUAARE
# Processing feature ID: 1776
# Processing POINT geometry...
# Feature 1776 created in layer: BUAARE
# Processing feature ID: 1777
# Processing POINT geometry...
# Feature 1777 created in layer: BUAARE
# Processing feature ID: 1778
# Processing POINT geometry...
# Feature 1778 created in layer: BUAARE
# Processing feature ID: 1779
# Processing POINT geometry...
# Feature 1779 created in layer: BUAARE
# Processing feature ID: 1780
# Processing POINT geometry...
# Feature 1780 created in layer: BUAARE
# Processing feature ID: 1781
# Processing POINT geometry...
# Feature 1781 created in layer: BUAARE
# Processing feature ID: 1782
# Processing POINT geometry...
# Feature 1782 created in layer: BUAARE
# Processing feature ID: 1783
# Processing POINT geometry...
# Feature 1783 created in layer: BUAARE
# Processing feature ID: 1784
# Processing POINT geometry...
# Feature 1784 created in layer: BUAARE
# Processing feature ID: 1785
# Processing POINT geometry...
# Feature 1785 created in layer: BUAARE
# Processing feature ID: 1786
# Processing POINT geometry...
# Feature 1786 created in layer: BUAARE
# Processing feature ID: 1787
# Processing POINT geometry...
# Feature 1787 created in layer: BUAARE
# Processing feature ID: 1788
# Processing POINT geometry...
# Feature 1788 created in layer: BUAARE
# Processing feature ID: 1789
# Processing POINT geometry...
# Feature 1789 created in layer: BUAARE
# Processing feature ID: 1790
# Processing POINT geometry...
# Feature 1790 created in layer: BUAARE
# Processing feature ID: 1791
# Processing POINT geometry...
# Feature 1791 created in layer: BUAARE
# Processing feature ID: 1792
# Processing POINT geometry...
# Feature 1792 created in layer: BUAARE
# Processing feature ID: 1793
# Processing POINT geometry...
# Feature 1793 created in layer: BUAARE
# Processing feature ID: 1794
# Processing POINT geometry...
# Feature 1794 created in layer: BUAARE
# Processing feature ID: 1795
# Processing POINT geometry...
# Feature 1795 created in layer: BUAARE
# Processing feature ID: 1796
# Processing POINT geometry...
# Feature 1796 created in layer: BUAARE
# Processing feature ID: 1797
# Processing POINT geometry...
# Feature 1797 created in layer: BUAARE
# Processing feature ID: 1798
# Processing POINT geometry...
# Feature 1798 created in layer: BUAARE
# Processing feature ID: 1799
# Processing POINT geometry...
# Feature 1799 created in layer: BUAARE
# Processing feature ID: 1800
# Processing POINT geometry...
# Feature 1800 created in layer: BUAARE
# Processing feature ID: 1801
# Processing POINT geometry...
# Feature 1801 created in layer: BUAARE
# Processing feature ID: 1802
# Processing POINT geometry...
# Feature 1802 created in layer: BUAARE
# Processing feature ID: 1803
# Processing POINT geometry...
# Feature 1803 created in layer: BUAARE
# Processing feature ID: 1804
# Processing POINT geometry...
# Feature 1804 created in layer: BUAARE
# Processing feature ID: 1805
# Processing POINT geometry...
# Feature 1805 created in layer: BUAARE
# Processing feature ID: 1806
# Processing POINT geometry...
# Feature 1806 created in layer: BUAARE
# Processing feature ID: 1807
# Processing POINT geometry...
# Feature 1807 created in layer: BUAARE
# Processing feature ID: 1808
# Processing POINT geometry...
# Feature 1808 created in layer: BUAARE
# Processing feature ID: 1809
# Processing POINT geometry...
# Feature 1809 created in layer: BUAARE
# Processing feature ID: 1810
# Processing POINT geometry...
# Feature 1810 created in layer: BUAARE
# Processing feature ID: 1811
# Processing POINT geometry...
# Feature 1811 created in layer: BUAARE
# Processing feature ID: 1812
# Processing POINT geometry...
# Feature 1812 created in layer: BUAARE
# Processing feature ID: 1813
# Processing POINT geometry...
# Feature 1813 created in layer: BUAARE
# Processing feature ID: 1814
# Processing POINT geometry...
# Feature 1814 created in layer: BUAARE
# Processing feature ID: 1815
# Processing POINT geometry...
# Feature 1815 created in layer: BUAARE
# Processing feature ID: 1816
# Processing POINT geometry...
# Feature 1816 created in layer: BUAARE
# Processing feature ID: 1817
# Processing POINT geometry...
# Feature 1817 created in layer: BUAARE
# Processing feature ID: 1818
# Processing POINT geometry...
# Feature 1818 created in layer: BUAARE
# Processing feature ID: 1819
# Processing POINT geometry...
# Feature 1819 created in layer: BUAARE
# Processing feature ID: 1820
# Processing POINT geometry...
# Feature 1820 created in layer: BUAARE
# Processing feature ID: 1821
# Processing POINT geometry...
# Feature 1821 created in layer: BUAARE
# Processing feature ID: 1822
# Processing POINT geometry...
# Feature 1822 created in layer: BUAARE
# Processing feature ID: 1823
# Processing POINT geometry...
# Feature 1823 created in layer: BUAARE
# Processing feature ID: 1824
# Processing POINT geometry...
# Feature 1824 created in layer: BUAARE
# Processing feature ID: 1825
# Processing POINT geometry...
# Feature 1825 created in layer: BUAARE
# Processing feature ID: 1826
# Processing POINT geometry...
# Feature 1826 created in layer: BUAARE
# Processing feature ID: 1827
# Processing POINT geometry...
# Feature 1827 created in layer: BUAARE
# Processing feature ID: 1828
# Processing POINT geometry...
# Feature 1828 created in layer: BUAARE
# Processing feature ID: 1829
# Processing POINT geometry...
# Feature 1829 created in layer: BUAARE
# Processing feature ID: 1830
# Processing POINT geometry...
# Feature 1830 created in layer: BUAARE
# Processing feature ID: 1831
# Processing POINT geometry...
# Feature 1831 created in layer: BUAARE
# Processing feature ID: 1832
# Processing POINT geometry...
# Feature 1832 created in layer: BUAARE
# Processing feature ID: 1833
# Processing POINT geometry...
# Feature 1833 created in layer: BUAARE
# Processing feature ID: 1834
# Processing POINT geometry...
# Feature 1834 created in layer: BUAARE
# Processing feature ID: 1835
# Processing POINT geometry...
# Feature 1835 created in layer: BUAARE
# Processing feature ID: 1836
# Processing POINT geometry...
# Feature 1836 created in layer: BUAARE
# Processing feature ID: 1837
# Processing POINT geometry...
# Feature 1837 created in layer: BUAARE
# Processing feature ID: 1838
# Processing POINT geometry...
# Feature 1838 created in layer: BUAARE
# Processing feature ID: 1839
# Processing POINT geometry...
# Feature 1839 created in layer: BUAARE
# Processing feature ID: 1840
# Processing POINT geometry...
# Feature 1840 created in layer: BUAARE
# Processing feature ID: 1841
# Processing POINT geometry...
# Feature 1841 created in layer: BUAARE
# Processing feature ID: 1842
# Processing POINT geometry...
# Feature 1842 created in layer: BUAARE
# Processing feature ID: 1843
# Processing POINT geometry...
# Feature 1843 created in layer: BUAARE
# Processing feature ID: 1844
# Processing POINT geometry...
# Feature 1844 created in layer: BUAARE
# Processing feature ID: 1845
# Processing POINT geometry...
# Feature 1845 created in layer: BUAARE
# Processing feature ID: 1846
# Processing POINT geometry...
# Feature 1846 created in layer: BUAARE
# Processing feature ID: 1847
# Processing POINT geometry...
# Feature 1847 created in layer: BUAARE
# Processing feature ID: 1848
# Processing POINT geometry...
# Feature 1848 created in layer: BUAARE
# Processing feature ID: 1849
# Processing POINT geometry...
# Feature 1849 created in layer: BUAARE
# Processing feature ID: 1850
# Processing POINT geometry...
# Feature 1850 created in layer: BUAARE
# Processing feature ID: 1851
# Processing POINT geometry...
# Feature 1851 created in layer: BUAARE
# Processing feature ID: 1852
# Processing POINT geometry...
# Feature 1852 created in layer: BUAARE
# Processing feature ID: 1853
# Processing POINT geometry...
# Feature 1853 created in layer: BUAARE
# Processing feature ID: 1854
# Processing POINT geometry...
# Feature 1854 created in layer: BUAARE
# Processing feature ID: 1855
# Processing POINT geometry...
# Feature 1855 created in layer: BUAARE
# Processing feature ID: 1856
# Processing POINT geometry...
# Feature 1856 created in layer: BUAARE
# Processing feature ID: 1857
# Processing POINT geometry...
# Feature 1857 created in layer: BUAARE
# Processing feature ID: 1858
# Processing POINT geometry...
# Feature 1858 created in layer: BUAARE
# Processing feature ID: 1859
# Processing POINT geometry...
# Feature 1859 created in layer: BUAARE
# Processing feature ID: 1860
# Processing POINT geometry...
# Feature 1860 created in layer: BUAARE
# Processing feature ID: 1861
# Processing POINT geometry...
# Feature 1861 created in layer: BUAARE
# Processing feature ID: 1862
# Processing POINT geometry...
# Feature 1862 created in layer: BUAARE
# Processing feature ID: 1863
# Processing POINT geometry...
# Feature 1863 created in layer: BUAARE
# Processing feature ID: 1864
# Processing POINT geometry...
# Feature 1864 created in layer: BUAARE
# Processing feature ID: 1865
# Processing POINT geometry...
# Feature 1865 created in layer: BUAARE
# Processing feature ID: 1866
# Processing POINT geometry...
# Feature 1866 created in layer: BUAARE
# Processing feature ID: 1867
# Processing POINT geometry...
# Feature 1867 created in layer: BUAARE
# Processing feature ID: 1868
# Processing POINT geometry...
# Feature 1868 created in layer: BUAARE
# Processing feature ID: 1869
# Processing POINT geometry...
# Feature 1869 created in layer: BUAARE
# Processing feature ID: 1870
# Processing POINT geometry...
# Feature 1870 created in layer: BUAARE
# Processing feature ID: 1871
# Processing POINT geometry...
# Feature 1871 created in layer: BUAARE
# Processing feature ID: 1872
# Processing POINT geometry...
# Feature 1872 created in layer: BUAARE
# Processing feature ID: 1873
# Processing POINT geometry...
# Feature 1873 created in layer: BUAARE
# Processing feature ID: 1874
# Processing POINT geometry...
# Feature 1874 created in layer: BUAARE
# Processing feature ID: 1875
# Processing POINT geometry...
# Feature 1875 created in layer: BUAARE
# Processing feature ID: 1876
# Processing POINT geometry...
# Feature 1876 created in layer: BUAARE
# Processing feature ID: 1877
# Processing POINT geometry...
# Feature 1877 created in layer: BUAARE
# Processing feature ID: 1878
# Processing POINT geometry...
# Feature 1878 created in layer: BUAARE
# Processing feature ID: 1879
# Processing POINT geometry...
# Feature 1879 created in layer: BUAARE
# Processing feature ID: 1880
# Processing POINT geometry...
# Feature 1880 created in layer: BUAARE
# Processing feature ID: 1881
# Processing POINT geometry...
# Feature 1881 created in layer: BUAARE
# Processing feature ID: 1882
# Processing POINT geometry...
# Feature 1882 created in layer: BUAARE
# Processing feature ID: 1883
# Processing POINT geometry...
# Feature 1883 created in layer: BUAARE
# Processing feature ID: 1884
# Processing POINT geometry...
# Feature 1884 created in layer: BUAARE
# Processing feature ID: 1885
# Processing POINT geometry...
# Feature 1885 created in layer: BUAARE
# Processing feature ID: 1886
# Processing POINT geometry...
# Feature 1886 created in layer: BUAARE
# Processing feature ID: 1887
# Processing POINT geometry...
# Feature 1887 created in layer: BUAARE
# Processing feature ID: 1888
# Processing POINT geometry...
# Feature 1888 created in layer: BUAARE
# Processing feature ID: 1889
# Processing POINT geometry...
# Feature 1889 created in layer: BUAARE
# Processing feature ID: 1890
# Processing POINT geometry...
# Feature 1890 created in layer: BUAARE
# Processing feature ID: 1891
# Processing POINT geometry...
# Feature 1891 created in layer: BUAARE
# Processing feature ID: 1892
# Processing POINT geometry...
# Feature 1892 created in layer: BUAARE
# Processing feature ID: 1893
# Processing POINT geometry...
# Feature 1893 created in layer: BUAARE
# Processing feature ID: 1894
# Processing POINT geometry...
# Feature 1894 created in layer: BUAARE
# Processing feature ID: 1895
# Processing POINT geometry...
# Feature 1895 created in layer: BUAARE
# Processing feature ID: 1896
# Processing POINT geometry...
# Feature 1896 created in layer: BUAARE
# Processing feature ID: 1897
# Processing POINT geometry...
# Feature 1897 created in layer: BUAARE
# Processing feature ID: 1898
# Processing POINT geometry...
# Feature 1898 created in layer: BUAARE
# Processing feature ID: 1899
# Processing POINT geometry...
# Feature 1899 created in layer: BUAARE
# Processing feature ID: 1900
# Processing POINT geometry...
# Feature 1900 created in layer: BUAARE
# Processing feature ID: 1901
# Processing POINT geometry...
# Feature 1901 created in layer: BUAARE
# Processing feature ID: 1902
# Processing POINT geometry...
# Feature 1902 created in layer: BUAARE
# Processing feature ID: 1903
# Processing POINT geometry...
# Feature 1903 created in layer: BUAARE
# Processing feature ID: 1904
# Processing POINT geometry...
# Feature 1904 created in layer: BUAARE
# Processing feature ID: 1905
# Processing POINT geometry...
# Feature 1905 created in layer: BUAARE
# Processing feature ID: 1906
# Processing POINT geometry...
# Feature 1906 created in layer: BUAARE
# Processing feature ID: 1907
# Processing POINT geometry...
# Feature 1907 created in layer: BUAARE
# Processing feature ID: 1908
# Processing POINT geometry...
# Feature 1908 created in layer: BUAARE
# Processing feature ID: 1909
# Processing POINT geometry...
# Feature 1909 created in layer: BUAARE
# Processing feature ID: 1910
# Processing POINT geometry...
# Feature 1910 created in layer: BUAARE
# Processing feature ID: 1911
# Processing POINT geometry...
# Feature 1911 created in layer: BUAARE
# Processing feature ID: 1912
# Processing POINT geometry...
# Feature 1912 created in layer: BUAARE
# Processing feature ID: 1913
# Processing POINT geometry...
# Feature 1913 created in layer: BUAARE
# Processing feature ID: 1914
# Processing POINT geometry...
# Feature 1914 created in layer: BUAARE
# Processing feature ID: 1915
# Processing POINT geometry...
# Feature 1915 created in layer: BUAARE
# Processing feature ID: 1916
# Processing POINT geometry...
# Feature 1916 created in layer: BUAARE
# Processing feature ID: 1917
# Processing POINT geometry...
# Feature 1917 created in layer: BUAARE
# Processing feature ID: 1918
# Processing POINT geometry...
# Feature 1918 created in layer: BUAARE
# Processing feature ID: 1919
# Processing POINT geometry...
# Feature 1919 created in layer: BUAARE
# Processing feature ID: 1920
# Processing POINT geometry...
# Feature 1920 created in layer: BUAARE
# Processing feature ID: 1921
# Processing POINT geometry...
# Feature 1921 created in layer: BUAARE
# Processing feature ID: 1922
# Processing POINT geometry...
# Feature 1922 created in layer: BUAARE
# Processing feature ID: 1923
# Processing POINT geometry...
# Feature 1923 created in layer: BUAARE
# Processing feature ID: 1924
# Processing POINT geometry...
# Feature 1924 created in layer: BUAARE
# Processing feature ID: 1925
# Processing POINT geometry...
# Feature 1925 created in layer: BUAARE
# Processing feature ID: 1926
# Processing POINT geometry...
# Feature 1926 created in layer: BUAARE
# Processing feature ID: 1927
# Processing POINT geometry...
# Feature 1927 created in layer: BUAARE
#
# Processing S-57 layer: BOYLAT in US1GC09M ENC
# Layer 13: BOYLAT
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: BOYLAT
# Number of features in BOYLAT layer: 5
# Processing feature ID: 82
# Processing POINT geometry...
# Feature 82 created in layer: BOYLAT
# Processing feature ID: 83
# Processing POINT geometry...
# Feature 83 created in layer: BOYLAT
# Processing feature ID: 84
# Processing POINT geometry...
# Feature 84 created in layer: BOYLAT
# Processing feature ID: 85
# Processing POINT geometry...
# Feature 85 created in layer: BOYLAT
# Processing feature ID: 86
# Processing POINT geometry...
# Feature 86 created in layer: BOYLAT
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
#
# Processing S-57 layer: BOYSAW in US1GC09M ENC
# Layer 14: BOYSAW
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: BOYSAW
# Number of features in BOYSAW layer: 5
# Processing feature ID: 87
# Processing POINT geometry...
# Feature 87 created in layer: BOYSAW
# Processing feature ID: 88
# Processing POINT geometry...
# Feature 88 created in layer: BOYSAW
# Processing feature ID: 89
# Processing POINT geometry...
# Feature 89 created in layer: BOYSAW
# Processing feature ID: 90
# Processing POINT geometry...
# Feature 90 created in layer: BOYSAW
# Processing feature ID: 91
# Processing POINT geometry...
# Feature 91 created in layer: BOYSAW
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2, 2, 2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
#
# Processing S-57 layer: BOYSPP in US1GC09M ENC
# Layer 15: BOYSPP
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: BOYSPP
# Number of features in BOYSPP layer: 50
# Processing feature ID: 92
# Processing POINT geometry...
# Feature 92 created in layer: BOYSPP
# Processing feature ID: 93
# Processing POINT geometry...
# Feature 93 created in layer: BOYSPP
# Processing feature ID: 94
# Processing POINT geometry...
# Feature 94 created in layer: BOYSPP
# Processing feature ID: 95
# Processing POINT geometry...
# Feature 95 created in layer: BOYSPP
# Processing feature ID: 96
# Processing POINT geometry...
# Feature 96 created in layer: BOYSPP
# Processing feature ID: 97
# Processing POINT geometry...
# Feature 97 created in layer: BOYSPP
# Processing feature ID: 98
# Processing POINT geometry...
# Feature 98 created in layer: BOYSPP
# Processing feature ID: 99
# Processing POINT geometry...
# Feature 99 created in layer: BOYSPP
# Processing feature ID: 100
# Processing POINT geometry...
# Feature 100 created in layer: BOYSPP
# Processing feature ID: 101
# Processing POINT geometry...
# Feature 101 created in layer: BOYSPP
# Processing feature ID: 102
# Processing POINT geometry...
# Feature 102 created in layer: BOYSPP
# Processing feature ID: 103
# Processing POINT geometry...
# Feature 103 created in layer: BOYSPP
# Processing feature ID: 104
# Processing POINT geometry...
# Feature 104 created in layer: BOYSPP
# Processing feature ID: 105
# Processing POINT geometry...
# Feature 105 created in layer: BOYSPP
# Processing feature ID: 106
# Processing POINT geometry...
# Feature 106 created in layer: BOYSPP
# Processing feature ID: 107
# Processing POINT geometry...
# Feature 107 created in layer: BOYSPP
# Processing feature ID: 108
# Processing POINT geometry...
# Feature 108 created in layer: BOYSPP
# Processing feature ID: 109
# Processing POINT geometry...
# Feature 109 created in layer: BOYSPP
# Processing feature ID: 110
# Processing POINT geometry...
# Feature 110 created in layer: BOYSPP
# Processing feature ID: 111
# Processing POINT geometry...
# Feature 111 created in layer: BOYSPP
# Processing feature ID: 112
# Processing POINT geometry...
# Feature 112 created in layer: BOYSPP
# Processing feature ID: 113
# Processing POINT geometry...
# Feature 113 created in layer: BOYSPP
# Processing feature ID: 114
# Processing POINT geometry...
# Feature 114 created in layer: BOYSPP
# Processing feature ID: 115
# Processing POINT geometry...
# Feature 115 created in layer: BOYSPP
# Processing feature ID: 116
# Processing POINT geometry...
# Feature 116 created in layer: BOYSPP
# Processing feature ID: 117
# Processing POINT geometry...
# Feature 117 created in layer: BOYSPP
# Processing feature ID: 118
# Processing POINT geometry...
# Feature 118 created in layer: BOYSPP
# Processing feature ID: 119
# Processing POINT geometry...
# Feature 119 created in layer: BOYSPP
# Processing feature ID: 120
# Processing POINT geometry...
# Feature 120 created in layer: BOYSPP
# Processing feature ID: 121
# Processing POINT geometry...
# Feature 121 created in layer: BOYSPP
# Processing feature ID: 122
# Processing POINT geometry...
# Feature 122 created in layer: BOYSPP
# Processing feature ID: 123
# Processing POINT geometry...
# Feature 123 created in layer: BOYSPP
# Processing feature ID: 124
# Processing POINT geometry...
# Feature 124 created in layer: BOYSPP
# Processing feature ID: 125
# Processing POINT geometry...
# Feature 125 created in layer: BOYSPP
# Processing feature ID: 126
# Processing POINT geometry...
# Feature 126 created in layer: BOYSPP
# Processing feature ID: 127
# Processing POINT geometry...
# Feature 127 created in layer: BOYSPP
# Processing feature ID: 128
# Processing POINT geometry...
# Feature 128 created in layer: BOYSPP
# Processing feature ID: 129
# Processing POINT geometry...
# Feature 129 created in layer: BOYSPP
# Processing feature ID: 130
# Processing POINT geometry...
# Feature 130 created in layer: BOYSPP
# Processing feature ID: 131
# Processing POINT geometry...
# Feature 131 created in layer: BOYSPP
# Processing feature ID: 132
# Processing POINT geometry...
# Feature 132 created in layer: BOYSPP
# Processing feature ID: 133
# Processing POINT geometry...
# Feature 133 created in layer: BOYSPP
# Processing feature ID: 134
# Processing POINT geometry...
# Feature 134 created in layer: BOYSPP
# Processing feature ID: 135
# Processing POINT geometry...
# Feature 135 created in layer: BOYSPP
# Processing feature ID: 136
# Processing POINT geometry...
# Feature 136 created in layer: BOYSPP
# Processing feature ID: 137
# Processing POINT geometry...
# Feature 137 created in layer: BOYSPP
# Processing feature ID: 138
# Processing POINT geometry...
# Feature 138 created in layer: BOYSPP
# Processing feature ID: 139
# Processing POINT geometry...
# Feature 139 created in layer: BOYSPP
# Processing feature ID: 140
# Processing POINT geometry...
# Feature 140 created in layer: BOYSPP
# Processing feature ID: 141
# Processing POINT geometry...
# Feature 141 created in layer: BOYSPP
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
# Mismatch in FFPT_RIND (1): S-57 [2], GeoPackage None
#
# Processing S-57 layer: CBLARE in US1GC09M ENC
# Layer 16: CBLARE
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: CBLARE
# Number of features in CBLARE layer: 1
# Processing feature ID: 4635
# Processing POLYGON geometry...
# Feature 4635 created in layer: CBLARE
#
# Processing S-57 layer: CBLSUB in US1GC09M ENC
# Layer 17: CBLSUB
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: CBLSUB
# Number of features in CBLSUB layer: 79
# Processing feature ID: 4636
# Processing LINESTRING geometry...
# Feature 4636 created in layer: CBLSUB
# Processing feature ID: 4637
# Processing LINESTRING geometry...
# Feature 4637 created in layer: CBLSUB
# Processing feature ID: 4638
# Processing LINESTRING geometry...
# Feature 4638 created in layer: CBLSUB
# Processing feature ID: 4639
# Processing LINESTRING geometry...
# Feature 4639 created in layer: CBLSUB
# Processing feature ID: 4640
# Processing LINESTRING geometry...
# Feature 4640 created in layer: CBLSUB
# Processing feature ID: 4641
# Processing LINESTRING geometry...
# Feature 4641 created in layer: CBLSUB
# Processing feature ID: 4642
# Processing LINESTRING geometry...
# Feature 4642 created in layer: CBLSUB
# Processing feature ID: 4643
# Processing LINESTRING geometry...
# Feature 4643 created in layer: CBLSUB
# Processing feature ID: 4644
# Processing LINESTRING geometry...
# ...
# Processing feature ID: 2335
# Processing POINT geometry...
# Feature 2335 created in layer: WRECKS
# Processing feature ID: 2336
# Processing POINT geometry...
# Feature 2336 created in layer: WRECKS
# Processing feature ID: 2337
# Processing POINT geometry...
# Feature 2337 created in layer: WRECKS
# Processing feature ID: 2338
# Processing POINT geometry...
# Feature 2338 created in layer: WRECKS
# Processing feature ID: 2339
# Processing POINT geometry...
# Feature 2339 created in layer: WRECKS
# Processing feature ID: 2340
# Processing POINT geometry...
# Feature 2340 created in layer: WRECKS
# Processing feature ID: 2341
# Processing POINT geometry...
# Feature 2341 created in layer: WRECKS
# Processing feature ID: 2342
# Processing POINT geometry...
# Feature 2342 created in layer: WRECKS
# Processing feature ID: 2343
# Processing POINT geometry...
# Feature 2343 created in layer: WRECKS
# Processing feature ID: 2344
# Processing POINT geometry...
# Feature 2344 created in layer: WRECKS
# Processing feature ID: 2345
# Processing POINT geometry...
# Feature 2345 created in layer: WRECKS
# Processing feature ID: 2346
# Processing POINT geometry...
# Feature 2346 created in layer: WRECKS
# Processing feature ID: 2347
# Processing POINT geometry...
# Feature 2347 created in layer: WRECKS
# Processing feature ID: 2348
# Processing POINT geometry...
# Feature 2348 created in layer: WRECKS
# Processing feature ID: 2349
# Processing POINT geometry...
# Feature 2349 created in layer: WRECKS
# Processing feature ID: 2350
# Processing POINT geometry...
# Feature 2350 created in layer: WRECKS
# Processing feature ID: 2351
# Processing POINT geometry...
# Feature 2351 created in layer: WRECKS
# Processing feature ID: 2352
# Processing POINT geometry...
# Feature 2352 created in layer: WRECKS
# Processing feature ID: 2353
# Processing POINT geometry...
# Feature 2353 created in layer: WRECKS
# Processing feature ID: 2354
# Processing POINT geometry...
# Feature 2354 created in layer: WRECKS
# Processing feature ID: 2355
# Processing POINT geometry...
# Feature 2355 created in layer: WRECKS
# Processing feature ID: 2356
# Processing POINT geometry...
# Feature 2356 created in layer: WRECKS
# Processing feature ID: 2357
# Processing POINT geometry...
# Feature 2357 created in layer: WRECKS
# Processing feature ID: 2358
# Processing POINT geometry...
# Feature 2358 created in layer: WRECKS
# Processing feature ID: 2359
# Processing POINT geometry...
# Feature 2359 created in layer: WRECKS
# Processing feature ID: 2360
# Processing POINT geometry...
# Feature 2360 created in layer: WRECKS
# Processing feature ID: 2361
# Processing POINT geometry...
# Feature 2361 created in layer: WRECKS
# Processing feature ID: 2362
# Processing POINT geometry...
# Feature 2362 created in layer: WRECKS
# Processing feature ID: 2363
# Processing POINT geometry...
# Feature 2363 created in layer: WRECKS
# Processing feature ID: 2364
# Processing POINT geometry...
# Feature 2364 created in layer: WRECKS
# Processing feature ID: 2365
# Processing POINT geometry...
# Feature 2365 created in layer: WRECKS
# Processing feature ID: 2366
# Processing POINT geometry...
# Feature 2366 created in layer: WRECKS
# Processing feature ID: 2367
# Processing POINT geometry...
# Feature 2367 created in layer: WRECKS
# Processing feature ID: 2368
# Processing POINT geometry...
# Feature 2368 created in layer: WRECKS
# Processing feature ID: 2369
# Processing POINT geometry...
# Feature 2369 created in layer: WRECKS
# Processing feature ID: 2370
# Processing POINT geometry...
# Feature 2370 created in layer: WRECKS
# Processing feature ID: 2371
# Processing POINT geometry...
# Feature 2371 created in layer: WRECKS
# Processing feature ID: 2372
# Processing POINT geometry...
# Feature 2372 created in layer: WRECKS
# Processing feature ID: 2373
# Processing POINT geometry...
# Feature 2373 created in layer: WRECKS
# Processing feature ID: 2374
# Processing POINT geometry...
# Feature 2374 created in layer: WRECKS
# Processing feature ID: 2375
# Processing POINT geometry...
# Feature 2375 created in layer: WRECKS
# Processing feature ID: 2376
# Processing POINT geometry...
# Feature 2376 created in layer: WRECKS
# Processing feature ID: 2377
# Processing POINT geometry...
# Feature 2377 created in layer: WRECKS
# Processing feature ID: 2378
# Processing POINT geometry...
# Feature 2378 created in layer: WRECKS
# Processing feature ID: 2379
# Processing POINT geometry...
# Feature 2379 created in layer: WRECKS
# Processing feature ID: 2380
# Processing POINT geometry...
# Feature 2380 created in layer: WRECKS
# Processing feature ID: 2381
# Processing POINT geometry...
# Feature 2381 created in layer: WRECKS
# Processing feature ID: 2382
# Processing POINT geometry...
# Feature 2382 created in layer: WRECKS
# Processing feature ID: 2383
# Processing POINT geometry...
# Feature 2383 created in layer: WRECKS
# Processing feature ID: 2384
# Processing POINT geometry...
# Feature 2384 created in layer: WRECKS
# Processing feature ID: 2385
# Processing POINT geometry...
# Feature 2385 created in layer: WRECKS
# Processing feature ID: 2386
# Processing POINT geometry...
# Feature 2386 created in layer: WRECKS
# Processing feature ID: 2387
# Processing POINT geometry...
# Feature 2387 created in layer: WRECKS
# Processing feature ID: 2388
# Processing POINT geometry...
# Feature 2388 created in layer: WRECKS
# Processing feature ID: 2389
# Processing POINT geometry...
# Feature 2389 created in layer: WRECKS
# Processing feature ID: 2390
# Processing POINT geometry...
# Feature 2390 created in layer: WRECKS
# Processing feature ID: 2391
# Processing POINT geometry...
# Feature 2391 created in layer: WRECKS
# Processing feature ID: 2392
# Processing POINT geometry...
# Feature 2392 created in layer: WRECKS
# Processing feature ID: 2393
# Processing POINT geometry...
# Feature 2393 created in layer: WRECKS
# Processing feature ID: 2394
# Processing POINT geometry...
# Feature 2394 created in layer: WRECKS
# Processing feature ID: 2395
# Processing POINT geometry...
# Feature 2395 created in layer: WRECKS
# Processing feature ID: 2396
# Processing POINT geometry...
# Feature 2396 created in layer: WRECKS
# Processing feature ID: 2397
# Processing POINT geometry...
# Feature 2397 created in layer: WRECKS
# Processing feature ID: 2398
# Processing POINT geometry...
# Feature 2398 created in layer: WRECKS
# Processing feature ID: 2399
# Processing POINT geometry...
# Feature 2399 created in layer: WRECKS
# Processing feature ID: 2400
# Processing POINT geometry...
# Feature 2400 created in layer: WRECKS
# Processing feature ID: 2401
# Processing POINT geometry...
# Feature 2401 created in layer: WRECKS
# Processing feature ID: 2402
# Processing POINT geometry...
# Feature 2402 created in layer: WRECKS
# Processing feature ID: 2403
# Processing POINT geometry...
# Feature 2403 created in layer: WRECKS
# Processing feature ID: 2404
# Processing POINT geometry...
# Feature 2404 created in layer: WRECKS
# Processing feature ID: 2405
# Processing POINT geometry...
# Feature 2405 created in layer: WRECKS
# Processing feature ID: 2406
# Processing POINT geometry...
# Feature 2406 created in layer: WRECKS
# Processing feature ID: 2407
# Processing POINT geometry...
# Feature 2407 created in layer: WRECKS
# Processing feature ID: 2408
# Processing POINT geometry...
# Feature 2408 created in layer: WRECKS
# Processing feature ID: 2409
# Processing POINT geometry...
# Feature 2409 created in layer: WRECKS
# Processing feature ID: 2410
# Processing POINT geometry...
# Feature 2410 created in layer: WRECKS
# Processing feature ID: 2411
# Processing POINT geometry...
# Feature 2411 created in layer: WRECKS
# Processing feature ID: 2412
# Processing POINT geometry...
# Feature 2412 created in layer: WRECKS
# Processing feature ID: 2413
# Processing POINT geometry...
# Feature 2413 created in layer: WRECKS
# Processing feature ID: 2414
# Processing POINT geometry...
# Feature 2414 created in layer: WRECKS
# Processing feature ID: 2415
# Processing POINT geometry...
# Feature 2415 created in layer: WRECKS
# Processing feature ID: 2416
# Processing POINT geometry...
# Feature 2416 created in layer: WRECKS
# Processing feature ID: 2417
# Processing POINT geometry...
# Feature 2417 created in layer: WRECKS
# Processing feature ID: 2418
# Processing POINT geometry...
# Feature 2418 created in layer: WRECKS
# Processing feature ID: 2419
# Processing POINT geometry...
# Feature 2419 created in layer: WRECKS
# Processing feature ID: 2420
# Processing POINT geometry...
# Feature 2420 created in layer: WRECKS
# Processing feature ID: 2421
# Processing POINT geometry...
# Feature 2421 created in layer: WRECKS
# Processing feature ID: 2422
# Processing POINT geometry...
# Feature 2422 created in layer: WRECKS
# Processing feature ID: 2423
# Processing POINT geometry...
# Feature 2423 created in layer: WRECKS
# Processing feature ID: 2424
# Processing POINT geometry...
# Feature 2424 created in layer: WRECKS
# Processing feature ID: 2425
# Processing POINT geometry...
# Feature 2425 created in layer: WRECKS
# Processing feature ID: 2426
# Processing POINT geometry...
# Feature 2426 created in layer: WRECKS
# Processing feature ID: 2427
# Processing POINT geometry...
# Feature 2427 created in layer: WRECKS
# Processing feature ID: 2428
# Processing POINT geometry...
# Feature 2428 created in layer: WRECKS
# Processing feature ID: 2429
# Processing POINT geometry...
# Feature 2429 created in layer: WRECKS
# Processing feature ID: 2430
# Processing POINT geometry...
# Feature 2430 created in layer: WRECKS
# Processing feature ID: 2431
# Processing POINT geometry...
# Feature 2431 created in layer: WRECKS
# Processing feature ID: 2432
# Processing POINT geometry...
# Feature 2432 created in layer: WRECKS
# Processing feature ID: 2433
# Processing POINT geometry...
# Feature 2433 created in layer: WRECKS
# Processing feature ID: 2434
# Processing POINT geometry...
# Feature 2434 created in layer: WRECKS
# Processing feature ID: 2435
# Processing POINT geometry...
# Feature 2435 created in layer: WRECKS
# Processing feature ID: 2436
# Processing POINT geometry...
# Feature 2436 created in layer: WRECKS
# Processing feature ID: 2437
# Processing POINT geometry...
# Feature 2437 created in layer: WRECKS
# Processing feature ID: 2438
# Processing POINT geometry...
# Feature 2438 created in layer: WRECKS
# Processing feature ID: 2439
# Processing POINT geometry...
# Feature 2439 created in layer: WRECKS
# Processing feature ID: 2440
# Processing POINT geometry...
# Feature 2440 created in layer: WRECKS
# Processing feature ID: 2441
# Processing POINT geometry...
# Feature 2441 created in layer: WRECKS
# Processing feature ID: 2442
# Processing POINT geometry...
# Feature 2442 created in layer: WRECKS
# Processing feature ID: 2443
# Processing POINT geometry...
# Feature 2443 created in layer: WRECKS
# Processing feature ID: 2444
# Processing POINT geometry...
# Feature 2444 created in layer: WRECKS
# Processing feature ID: 2445
# Processing POINT geometry...
# Feature 2445 created in layer: WRECKS
# Processing feature ID: 2446
# Processing POINT geometry...
# Feature 2446 created in layer: WRECKS
# Processing feature ID: 2447
# Processing POINT geometry...
# Feature 2447 created in layer: WRECKS
# Processing feature ID: 2448
# Processing POINT geometry...
# Feature 2448 created in layer: WRECKS
# Processing feature ID: 2449
# Processing POINT geometry...
# Feature 2449 created in layer: WRECKS
# Processing feature ID: 2450
# Processing POINT geometry...
# Feature 2450 created in layer: WRECKS
# Processing feature ID: 2451
# Processing POINT geometry...
# Feature 2451 created in layer: WRECKS
# Processing feature ID: 2452
# Processing POINT geometry...
# Feature 2452 created in layer: WRECKS
# Processing feature ID: 2453
# Processing POINT geometry...
# Feature 2453 created in layer: WRECKS
#
# Processing S-57 layer: M_COVR in US1GC09M ENC
# Layer 61: M_COVR
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: M_COVR
# Number of features in M_COVR layer: 2
# Processing feature ID: 5329
# Processing POLYGON geometry...
# Feature 5329 created in layer: M_COVR
# Processing feature ID: 5330
# Processing POLYGON geometry...
# Feature 5330 created in layer: M_COVR
#
# Processing S-57 layer: M_NPUB in US1GC09M ENC
# Layer 62: M_NPUB
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: M_NPUB
# Number of features in M_NPUB layer: 2
# Processing feature ID: 2917
# Processing POLYGON geometry...
# Feature 2917 created in layer: M_NPUB
# Processing feature ID: 2918
# Processing POLYGON geometry...
# Feature 2918 created in layer: M_NPUB
#
# Processing S-57 layer: M_NSYS in US1GC09M ENC
# Layer 63: M_NSYS
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: M_NSYS
# Number of features in M_NSYS layer: 2
# Processing feature ID: 2919
# Processing POLYGON geometry...
# Feature 2919 created in layer: M_NSYS
# Processing feature ID: 2920
# Processing POLYGON geometry...
# Feature 2920 created in layer: M_NSYS
#
# Processing S-57 layer: M_QUAL in US1GC09M ENC
# Layer 64: M_QUAL
# EPSG Code: 4326
# Datum: WGS_1984
# Projection: Not specified
# Units: degree
# GeoPackage layer created: M_QUAL
# Number of features in M_QUAL layer: 4
# Processing feature ID: 2921
# Processing POLYGON geometry...
# Feature 2921 created in layer: M_QUAL
# Processing feature ID: 2922
# Processing POLYGON geometry...
# Feature 2922 created in layer: M_QUAL
# Processing feature ID: 2923
# Processing POLYGON geometry...
# Feature 2923 created in layer: M_QUAL
# Processing feature ID: 2924
# Processing POLYGON geometry...
# Feature 2924 created in layer: M_QUAL
#
# Processing S-57 layer: C_AGGR in US1GC09M ENC
#
# Layer 65: C_AGGR
# No spatial reference system defined
# GeoPackage layer created: C_AGGR
# Number of features in C_AGGR layer: 4
# Processing feature ID: 4736
# Feature 4736 has no geometry, skipping
# Processing feature ID: 4737
# Feature 4737 has no geometry, skipping
# Processing feature ID: 4738
# Feature 4738 has no geometry, skipping
# Processing feature ID: 4739
# Feature 4739 has no geometry, skipping
#
# Processing S-57 layer: C_ASSO in US1GC09M ENC
#
# Layer 66: C_ASSO
# No spatial reference system defined
# GeoPackage layer created: C_ASSO
# Number of features in C_ASSO layer: 17
# Processing feature ID: 4740
# Feature 4740 has no geometry, skipping
# Processing feature ID: 4741
# Feature 4741 has no geometry, skipping
# Processing feature ID: 4742
# Feature 4742 has no geometry, skipping
# Processing feature ID: 4743
# Feature 4743 has no geometry, skipping
# Processing feature ID: 4744
# Feature 4744 has no geometry, skipping
# Processing feature ID: 4745
# Feature 4745 has no geometry, skipping
# Processing feature ID: 4746
# Feature 4746 has no geometry, skipping
# Processing feature ID: 4747
# Feature 4747 has no geometry, skipping
# Processing feature ID: 4748
# Feature 4748 has no geometry, skipping
# Processing feature ID: 4749
# Feature 4749 has no geometry, skipping
# Processing feature ID: 4750
# Feature 4750 has no geometry, skipping
# Processing feature ID: 4751
# Feature 4751 has no geometry, skipping
# Processing feature ID: 4752
# Feature 4752 has no geometry, skipping
# Processing feature ID: 4753
# Feature 4753 has no geometry, skipping
# Processing feature ID: 4754
# Feature 4754 has no geometry, skipping
# Processing feature ID: 4755
# Feature 4755 has no geometry, skipping
# Processing feature ID: 4756
# Feature 4756 has no geometry, skipping
#
# Processing S-57 file: GIS_files\07CGD_ENCs\ENC_ROOT\US1GC09M\US1GC09M.001
# Attempting to create GeoPackage at: GIS_export/ENC2/US1GC09M.gpkg
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 227
#     225 s57_folder = "GIS_files/07CGD_ENCs/ENC_ROOT"
#     226 geopackage_export_folder = 'GIS_export/ENC2/'
# --> 227 process_enc_folder(s57_folder, geopackage_export_folder)
#
# Cell In[5], line 222, in process_enc_folder(enc_folder_path, geopackage_export_folder)
#     220 for s57_file in s57_files:
#     221     print(f"\nProcessing S-57 file: {s57_file}")
# --> 222     convert_s57_to_geopackage(s57_file, geopackage_export_folder)
#
# Cell In[5], line 45, in convert_s57_to_geopackage(s57_file_path, geopackage_export_folder)
#      43 s57 = s57_driver.Open(s57_file_path)
#      44 if s57 is None:
# ---> 45     raise RuntimeError(f"Could not open S-57 file: {s57_file_path}")
#      46 else:
#      47     print(f"S-57 file opened: {s57_file_path}")
#
# RuntimeError: Could not open S-57 file: GIS_files\07CGD_ENCs\ENC_ROOT\US1GC09M\US1GC09M.001

# %% [markdown]
# Check GeoPackage Fields

# %%
# Check GeoPackage data

def  get_field_data(geopackage_export_folder, enc_name, layer_name, field_name):

    geopackage_path  = os.path.join(geopackage_export_folder, f"{enc_name}.gpkg")

    # Check if the GeoPackage file exists
    if not os.path.exists(geopackage_path):
        raise FileNotFoundError(f"GeoPackage with {enc_name} name, not found in {geopackage_export_folder}")

    # Register the GeoPackage driver
    ogr.RegisterAll()
    gpkg_driver = ogr.GetDriverByName('GPKG')

    # Open the GeoPackage file
    gpkg = gpkg_driver.Open(geopackage_path)
    if gpkg is None:
        raise RuntimeError(f"Could not open GeoPackage: {geopackage_path}")
    else:
        print(f"GeoPackage opened: {geopackage_path}")

    # Get the layer by name
    layer = gpkg.GetLayerByName(layer_name)
    if layer is None:
        raise RuntimeError(f"Layer not found: {layer_name}")
    else:
        print(f"Layer found: {layer_name} with {layer.GetFeatureCount()} features")

    # Loop through the features in the layer
    for feature in layer:
        # Get the field value
        field_value = feature.GetField(field_name)
        print(f"Field: {field_name}, Value: {field_value}")

    # Close the dataset
    gpkg = None

# Example usage
#get_field_data(geopackage_export_folder, "US1WC01M",'BCNLAT','FFPT_RIND')
