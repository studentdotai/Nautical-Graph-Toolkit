# %% [markdown]
# # Weights

# %% [markdown]
# ## Load Graph

# %%
import os
import sys
from pathlib import Path
import plotly.graph_objects as go
import plotly.io as pio
from dotenv import load_dotenv

# Add the src directory to the Python path
project_root = Path.cwd().parent.parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.maritime_module.utils.port_utils import Boundaries
from src.maritime_module.utils.plot_utils import PlotlyChart
from src.maritime_module.utils.geometry_utils import Buffer
import geopandas as gpd
from shapely.geometry import shape, LineString, MultiPolygon, Point, Polygon, box


from src.maritime_module.core.graph import H3Graph, Weights
from src.maritime_module.core.s57_data import ENCDataFactory

# Load environment variables from .env file at the project root
load_dotenv(project_root / ".env")
pio.renderers.default = "notebook_connected"

output_dir = Path.cwd() / 'output'
output_dir.mkdir(exist_ok=True)

db_params = {
    'dbname': os.getenv('DB_NAME'),
    'user': os.getenv('DB_USER'),
    'password': os.getenv('DB_PASSWORD'),
    'host': os.getenv('DB_HOST'),
    'port': os.getenv('DB_PORT')
}

factory = ENCDataFactory(source=db_params, schema="us_enc_all")
h3 = H3Graph(data_factory=factory,
             route_schema_name="routes",
             graph_schema_name="graph")
# Out:
# 2025-10-09 13:06:04,447 - src.maritime_module.core.s57_data - INFO - Source is a dictionary, initializing PostGISManager.
# 2025-10-09 13:06:04,478 - src.maritime_module.core.s57_data - INFO - Successfully connected to database 'ENC_db'

# %%
from src.maritime_module.utils.db_utils import PostGISConnector

pg = PostGISConnector(db_params=db_params, schema="graph")
# pg.drop_columns(schema_name="graph",
#                 table_name="fine_graph_01_opt_edges",
#                 columns=["final_weight", "static_weight_factor"])

# %%
graph_name = "h3_graph_PG_6_11"
# Initialize the Weights manager with the same data factory
weights_manager = Weights(data_factory=factory)
weights_manager.clean_graph_postgis(graph_name)
# Out:
# 2025-10-09 13:06:04,587 - src.maritime_module.core.graph - INFO - Weights manager initialized with default S57 classifier
# 2025-10-09 13:06:04,588 - src.maritime_module.core.graph - INFO - Default static layers from config: 9 layers
# 2025-10-09 13:06:04,588 - src.maritime_module.core.graph - INFO - === Cleaning PostGIS Graph ===
# 2025-10-09 13:06:04,589 - src.maritime_module.core.graph - INFO - Table: graph.h3_graph_PG_6_11_edges
# 2025-10-09 13:06:04,646 - src.maritime_module.core.graph - INFO - Dropping 19 columns...
# 2025-10-09 13:06:04,708 - src.maritime_module.core.graph - INFO - === PostGIS Graph Cleaned ===
# 2025-10-09 13:06:04,709 - src.maritime_module.core.graph - INFO - Dropped 19 columns
# 2025-10-09 13:06:04,709 - src.maritime_module.core.graph - INFO - Kept 9 columns (including weight, geom)
# {'columns_dropped': 19,
#  'columns_kept': ['id',
#   'source_str',
#   'target_str',
#   'source_x',
#   'source_y',
#   'target_x',
#   'target_y',
#   'weight',
#   'geometry'],
#  'columns_removed': ['base_weight',
#   'adjusted_weight',
#   'blocking_factor',
#   'penalty_factor',
#   'bonus_factor',
#   'ukc_meters',
#   'ft_depth_sources',
#   'ft_hor_clearance',
#   'ft_hor_clearance_sources',
#   'ft_ver_clearance',
#   'ft_ver_clearance_sources',
#   'ft_depth',
#   'ft_sounding',
#   'ft_sounding_sources',
#   'ft_sounding_point',
#   'ft_sounding_point_sources',
#   'wt_static_blocking',
#   'wt_static_penalty',
#   'wt_static_bonus']}

# %%
# Load a pre-existing graph from PostGIS
# This assumes a graph was previously saved with a prefix like 'fine_graph_01'

try:
    G = h3.load_graph_from_postgis(table_prefix=graph_name)
    print(f"Successfully loaded graph with {G.number_of_nodes():,} nodes and {G.number_of_edges():,} edges.")
except Exception as e:
    print(f"Could not load graph. Please ensure a graph has been saved to PostGIS first. Error: {e}")
    G = None

# 1. Get the boundary of the graph itself
nodes_df = gpd.GeoDataFrame(geometry=[Point(n) for n in G.nodes()], crs="EPSG:4326")
graph_boundary = nodes_df.union_all().convex_hull
# Out:
# 2025-10-09 13:06:04,744 - src.maritime_module.core.graph - INFO - Loading graph from PostGIS schema 'graph' tables: h3_graph_PG_6_11_nodes, h3_graph_PG_6_11_edges
# 2025-10-09 13:06:51,076 - src.maritime_module.core.graph - INFO - Loaded and processed 931,149 nodes in 46.330s
# 2025-10-09 13:11:25,104 - src.maritime_module.core.graph - INFO - Loaded and processed 2,784,887 edges in 274.027s
# 2025-10-09 13:11:26,109 - src.maritime_module.core.graph - INFO - Graph loaded from PostGIS: 931,149 nodes, 2,784,887 edges in 320.863s
# 2025-10-09 13:11:26,110 - src.maritime_module.core.graph - INFO - === PostGIS Graph Load Operation Performance Summary ===
# 2025-10-09 13:11:26,111 - src.maritime_module.core.graph - INFO - Timing Metrics:
# 2025-10-09 13:11:26,112 - src.maritime_module.core.graph - INFO -   nodes_load_time: 7.289s
# 2025-10-09 13:11:26,112 - src.maritime_module.core.graph - INFO -   nodes_processing_time: 39.041s
# 2025-10-09 13:11:26,112 - src.maritime_module.core.graph - INFO -   edges_load_time: 33.597s
# 2025-10-09 13:11:26,113 - src.maritime_module.core.graph - INFO -   edges_processing_time: 240.431s
# 2025-10-09 13:11:26,113 - src.maritime_module.core.graph - INFO - Count Metrics:
# 2025-10-09 13:11:26,114 - src.maritime_module.core.graph - INFO -   nodes_loaded: 931,149
# 2025-10-09 13:11:26,114 - src.maritime_module.core.graph - INFO -   edges_loaded: 2,784,887
# 2025-10-09 13:11:26,115 - src.maritime_module.core.graph - INFO -   final_nodes: 931,149
# 2025-10-09 13:11:26,115 - src.maritime_module.core.graph - INFO -   final_edges: 2,784,887
# 2025-10-09 13:11:26,116 - src.maritime_module.core.graph - INFO - Other Metrics:
# 2025-10-09 13:11:26,116 - src.maritime_module.core.graph - INFO -   table_prefix: h3_graph_PG_6_11
# 2025-10-09 13:11:26,117 - src.maritime_module.core.graph - INFO -   schema: graph
# 2025-10-09 13:11:26,117 - src.maritime_module.core.graph - INFO -   load_graph_postgis_total: 320.86329161699996
# 2025-10-09 13:11:26,118 - src.maritime_module.core.graph - INFO - ======================================================
# Successfully loaded graph with 931,149 nodes and 2,784,887 edges.

# %% [markdown]
#  ## Initialize Weights Class

# %% [markdown]
#  ## Apply Static Feature Weights

# %%
# 2. Get the list of ENCs intersecting this boundary
enc_list = factory.get_encs_by_boundary(graph_boundary)
print(f"Found {len(enc_list)} ENCs intersecting with the graph boundary.")

ft_weights = weights_manager.get_feature_layers_from_classifier()

ft_weights
# Out:
# 2025-10-09 13:11:32,014 - src.maritime_module.core.s57_data - INFO - Factory: Filtering ENCs by boundary...
# 2025-10-09 13:11:32,015 - src.maritime_module.core.s57_data - INFO - Factory: Getting ENC summary...
# 2025-10-09 13:11:32,034 - src.maritime_module.core.s57_data - INFO - Factory: Getting bounding boxes for 6369 ENCs...
# Found 19 ENCs intersecting with the graph boundary.
# 2025-10-09 13:11:32,409 - src.maritime_module.core.graph - INFO - Generated 21 feature layer configs from classifier
# {'canals': {'column': 'ft_hor_clearance',
#   'attributes': ['horclr'],
#   'aggregation': 'min'},
#  'convyr': {'column': 'ft_ver_clearance',
#   'attributes': ['verclr'],
#   'aggregation': 'min'},
#  'depare': {'column': 'ft_depth',
#   'attributes': ['drval1'],
#   'aggregation': 'min'},
#  'swpare': {'column': 'ft_depth',
#   'attributes': ['drval1'],
#   'aggregation': 'min'},
#  'drgare': {'column': 'ft_depth',
#   'attributes': ['drval1'],
#   'aggregation': 'min'},
#  'docare': {'column': 'ft_hor_clearance',
#   'attributes': ['horclr'],
#   'aggregation': 'min'},
#  'marcul': {'column': 'ft_sounding',
#   'attributes': ['valsou'],
#   'aggregation': 'min'},
#  'cblohd': {'column': 'ft_ver_clearance',
#   'attributes': ['verclr', 'vercsa'],
#   'aggregation': 'min'},
#  'pipohd': {'column': 'ft_ver_clearance',
#   'attributes': ['verclr'],
#   'aggregation': 'min'},
#  'flodoc': {'column': 'ft_hor_clearance',
#   'attributes': ['horclr'],
#   'aggregation': 'min'},
#  'cranes': {'column': 'ft_ver_clearance',
#   'attributes': ['verclr'],
#   'aggregation': 'min'},
#  'lokbsn': {'column': 'ft_hor_clearance',
#   'attributes': ['horclr'],
#   'aggregation': 'min'},
#  'uwtroc': {'column': 'ft_sounding',
#   'attributes': ['valsou'],
#   'aggregation': 'min'},
#  'obstrn': {'column': 'ft_sounding',
#   'attributes': ['valsou'],
#   'aggregation': 'min'},
#  'wrecks': {'column': 'ft_sounding',
#   'attributes': ['valsou'],
#   'aggregation': 'min'},
#  'soundg': {'column': 'ft_sounding_point',
#   'attributes': ['depth'],
#   'aggregation': 'min'},
#  'bridge': {'column': 'ft_ver_clearance',
#   'attributes': ['verclr'],
#   'aggregation': 'min'},
#  'gatcon': {'column': 'ft_ver_clearance',
#   'attributes': ['verclr'],
#   'aggregation': 'min'},
#  'tunnel': {'column': 'ft_ver_clearance',
#   'attributes': ['verclr'],
#   'aggregation': 'min'},
#  'slcons': {'column': 'ft_hor_clearance',
#   'attributes': ['horclr'],
#   'aggregation': 'min'},
#  'drydoc': {'column': 'ft_hor_clearance',
#   'attributes': ['horclr'],
#   'aggregation': 'min'}}

# %%
# 3. Apply weights from static layers (e.g., land, fairways, obstructions)
summary = weights_manager.enrich_edges_with_features_postgis(enc_names= enc_list,
                                                               schema_name="graph",
                                                               graph_name=graph_name,
                                                               enc_schema="us_enc_all",
                                                               feature_layers=ft_weights
                                                             )



summary
# Out:
# 2025-10-09 13:11:32,419 - src.maritime_module.core.graph - INFO - Generated 21 feature layer configs from classifier
# 2025-10-09 13:11:32,420 - src.maritime_module.core.graph - INFO - === PostGIS Feature Enrichment (Server-Side) ===
# 2025-10-09 13:11:32,421 - src.maritime_module.core.graph - INFO - Edges table: graph.h3_graph_PG_6_11_edges
# 2025-10-09 13:11:32,421 - src.maritime_module.core.graph - INFO - Layers schema: us_enc_all
# 2025-10-09 13:11:32,422 - src.maritime_module.core.graph - INFO - Processing 21 feature layers
# 2025-10-09 13:11:32,422 - src.maritime_module.core.graph - INFO - Initializing weight calculation columns
# 2025-10-09 13:11:32,428 - src.maritime_module.core.graph - INFO - Added column 'base_weight' to h3_graph_PG_6_11_edges
# 2025-10-09 13:11:32,434 - src.maritime_module.core.graph - INFO - Added column 'adjusted_weight' to h3_graph_PG_6_11_edges
# 2025-10-09 13:11:32,440 - src.maritime_module.core.graph - INFO - Added column 'blocking_factor' to h3_graph_PG_6_11_edges
# 2025-10-09 13:11:32,446 - src.maritime_module.core.graph - INFO - Added column 'penalty_factor' to h3_graph_PG_6_11_edges
# 2025-10-09 13:11:32,451 - src.maritime_module.core.graph - INFO - Added column 'bonus_factor' to h3_graph_PG_6_11_edges
# 2025-10-09 13:11:32,455 - src.maritime_module.core.graph - INFO - Added column 'ukc_meters' to h3_graph_PG_6_11_edges
# 2025-10-09 13:11:32,459 - src.maritime_module.core.graph - INFO - Added column 'ft_depth_sources' to h3_graph_PG_6_11_edges
# 2025-10-09 13:12:27,125 - src.maritime_module.core.graph - INFO - Initialized weight calculation columns with default values
# 2025-10-09 13:12:27,134 - src.maritime_module.core.graph - INFO - Added column 'ft_hor_clearance' to h3_graph_PG_6_11_edges
# 2025-10-09 13:12:27,138 - src.maritime_module.core.graph - INFO - Added column 'ft_hor_clearance_sources' (JSONB) to h3_graph_PG_6_11_edges
# 2025-10-09 13:12:27,142 - src.maritime_module.core.graph - INFO - Added column 'ft_ver_clearance' to h3_graph_PG_6_11_edges
# 2025-10-09 13:12:27,146 - src.maritime_module.core.graph - INFO - Added column 'ft_ver_clearance_sources' (JSONB) to h3_graph_PG_6_11_edges
# 2025-10-09 13:12:27,150 - src.maritime_module.core.graph - INFO - Added column 'ft_depth' to h3_graph_PG_6_11_edges
# 2025-10-09 13:12:27,161 - src.maritime_module.core.graph - INFO - Added column 'ft_sounding' to h3_graph_PG_6_11_edges
# 2025-10-09 13:12:27,165 - src.maritime_module.core.graph - INFO - Added column 'ft_sounding_sources' (JSONB) to h3_graph_PG_6_11_edges
# 2025-10-09 13:12:27,186 - src.maritime_module.core.graph - INFO - Added column 'ft_sounding_point' to h3_graph_PG_6_11_edges
# 2025-10-09 13:12:27,190 - src.maritime_module.core.graph - INFO - Added column 'ft_sounding_point_sources' (JSONB) to h3_graph_PG_6_11_edges
# 2025-10-09 13:12:27,200 - src.maritime_module.core.graph - INFO - Processing 'canals' -> ft_hor_clearance (attributes: ['horclr'], agg: min)
# 2025-10-09 13:12:27,234 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_hor_clearance from 'canals'
# 2025-10-09 13:12:27,235 - src.maritime_module.core.graph - INFO - Processing 'convyr' -> ft_ver_clearance (attributes: ['verclr'], agg: min)
# 2025-10-09 13:12:27,242 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_ver_clearance from 'convyr'
# 2025-10-09 13:12:27,243 - src.maritime_module.core.graph - INFO - Processing 'depare' -> ft_depth (attributes: ['drval1'], agg: min)
# 2025-10-09 13:18:54,126 - src.maritime_module.core.graph - INFO - Enriched 2,784,738 edges with ft_depth from 'depare'
# 2025-10-09 13:18:54,127 - src.maritime_module.core.graph - INFO - Processing 'swpare' -> ft_depth (attributes: ['drval1'], agg: min)
# 2025-10-09 13:18:54,167 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_depth from 'swpare'
# 2025-10-09 13:18:54,168 - src.maritime_module.core.graph - INFO - Processing 'drgare' -> ft_depth (attributes: ['drval1'], agg: min)
# 2025-10-09 13:19:00,786 - src.maritime_module.core.graph - INFO - Enriched 28,842 edges with ft_depth from 'drgare'
# 2025-10-09 13:19:00,787 - src.maritime_module.core.graph - INFO - Processing 'docare' -> ft_hor_clearance (attributes: ['horclr'], agg: min)
# 2025-10-09 13:19:00,818 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_hor_clearance from 'docare'
# 2025-10-09 13:19:00,819 - src.maritime_module.core.graph - INFO - Processing 'marcul' -> ft_sounding (attributes: ['valsou'], agg: min)
# 2025-10-09 13:19:00,828 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_sounding from 'marcul'
# 2025-10-09 13:19:00,829 - src.maritime_module.core.graph - INFO - Processing 'cblohd' -> ft_ver_clearance (attributes: ['verclr', 'vercsa'], agg: min)
# 2025-10-09 13:19:01,557 - src.maritime_module.core.graph - INFO - Enriched 559 edges with ft_ver_clearance from 'cblohd'
# 2025-10-09 13:19:01,558 - src.maritime_module.core.graph - INFO - Processing 'pipohd' -> ft_ver_clearance (attributes: ['verclr'], agg: min)
# 2025-10-09 13:19:01,566 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_ver_clearance from 'pipohd'
# 2025-10-09 13:19:01,566 - src.maritime_module.core.graph - INFO - Processing 'flodoc' -> ft_hor_clearance (attributes: ['horclr'], agg: min)
# 2025-10-09 13:19:01,601 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_hor_clearance from 'flodoc'
# 2025-10-09 13:19:01,602 - src.maritime_module.core.graph - INFO - Processing 'cranes' -> ft_ver_clearance (attributes: ['verclr'], agg: min)
# 2025-10-09 13:19:01,636 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_ver_clearance from 'cranes'
# 2025-10-09 13:19:01,637 - src.maritime_module.core.graph - INFO - Processing 'lokbsn' -> ft_hor_clearance (attributes: ['horclr'], agg: min)
# 2025-10-09 13:19:01,670 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_hor_clearance from 'lokbsn'
# 2025-10-09 13:19:01,671 - src.maritime_module.core.graph - INFO - Processing 'uwtroc' -> ft_sounding (attributes: ['valsou'], agg: min)
# 2025-10-09 13:19:02,293 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_sounding from 'uwtroc'
# 2025-10-09 13:19:02,293 - src.maritime_module.core.graph - INFO - Processing 'obstrn' -> ft_sounding (attributes: ['valsou'], agg: min)
# 2025-10-09 13:19:04,970 - src.maritime_module.core.graph - INFO - Enriched 11 edges with ft_sounding from 'obstrn'
# 2025-10-09 13:19:04,970 - src.maritime_module.core.graph - INFO - Processing 'wrecks' -> ft_sounding (attributes: ['valsou'], agg: min)
# 2025-10-09 13:19:05,047 - src.maritime_module.core.graph - INFO - Enriched 771 edges with ft_sounding from 'wrecks'
# 2025-10-09 13:19:05,048 - src.maritime_module.core.graph - INFO - Processing 'soundg' -> ft_sounding_point (attributes: ['depth'], agg: min)
# 2025-10-09 13:19:07,241 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_sounding_point from 'soundg'
# 2025-10-09 13:19:07,241 - src.maritime_module.core.graph - INFO - Processing 'bridge' -> ft_ver_clearance (attributes: ['verclr'], agg: min)
# 2025-10-09 13:19:07,895 - src.maritime_module.core.graph - INFO - Enriched 1,560 edges with ft_ver_clearance from 'bridge'
# 2025-10-09 13:19:07,896 - src.maritime_module.core.graph - INFO - Processing 'gatcon' -> ft_ver_clearance (attributes: ['verclr'], agg: min)
# 2025-10-09 13:19:07,905 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_ver_clearance from 'gatcon'
# 2025-10-09 13:19:07,906 - src.maritime_module.core.graph - INFO - Processing 'tunnel' -> ft_ver_clearance (attributes: ['verclr'], agg: min)
# 2025-10-09 13:19:07,912 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_ver_clearance from 'tunnel'
# 2025-10-09 13:19:07,913 - src.maritime_module.core.graph - INFO - Processing 'slcons' -> ft_hor_clearance (attributes: ['horclr'], agg: min)
# 2025-10-09 13:19:08,054 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_hor_clearance from 'slcons'
# 2025-10-09 13:19:08,055 - src.maritime_module.core.graph - INFO - Processing 'drydoc' -> ft_hor_clearance (attributes: ['horclr'], agg: min)
# 2025-10-09 13:19:08,093 - src.maritime_module.core.graph - INFO - Enriched 0 edges with ft_hor_clearance from 'drydoc'
# 2025-10-09 13:19:08,093 - src.maritime_module.core.graph - INFO - === PostGIS Feature Enrichment Complete ===
# 2025-10-09 13:19:08,094 - src.maritime_module.core.graph - INFO - Total edge updates: 2,816,481
# 2025-10-09 13:19:08,094 - src.maritime_module.core.graph - INFO - Columns enriched: 3
# 2025-10-09 13:19:08,094 - src.maritime_module.core.graph - INFO -   ft_depth: 2,813,580 edges
# 2025-10-09 13:19:08,095 - src.maritime_module.core.graph - INFO -   ft_sounding: 782 edges
# 2025-10-09 13:19:08,095 - src.maritime_module.core.graph - INFO -   ft_ver_clearance: 2,119 edges
# {'ft_hor_clearance': 0,
#  'ft_ver_clearance': 2119,
#  'ft_depth': 2813580,
#  'ft_sounding': 782,
#  'ft_sounding_point': 0}

# %%
pg.get_table(table_name=f"{graph_name}_edges",
             schema_name="graph")
# Out:
# 2025-10-09 13:19:08,176 - src.maritime_module.utils.db_utils - INFO - Successfully connected to database 'ENC_db' for schema management.
# 2025-10-09 13:20:29,019 - src.maritime_module.utils.db_utils - INFO - Loaded 2784887 rows from 'graph.h3_graph_PG_6_11_edges'
#               id                                 source_str  \
# 0          36653   (-122.70442528145516, 37.29290314155771)
# 1        2558810   (-122.34777821998698, 37.72649185682434)
# 2        2440968   (-122.62412206689525, 37.76971930322309)
# 3        1350547  (-122.33270390719495, 37.760578187631054)
# 4        2456818   (-122.28730231963732, 37.79145427435659)
# ...          ...                                        ...
# 2784882  2223941   (-122.6538318318921, 37.559457571019436)
# 2784883   325045   (-122.44243385016007, 37.90171951332442)
# 2784884  2328169     (-122.7904630686994, 37.9305951305571)
# 2784885  1366157   (-122.88425853358922, 37.87650408249214)
# 2784886  1586607  (-122.73194111756014, 37.407902892540584)
#
#                                         target_str    source_x   source_y  \
# 0         (-122.70105009172504, 37.29477183788321) -122.704425  37.292903
# 1         (-122.34826442428414, 37.72622623378993) -122.347778  37.726492
# 2         (-122.62414982824414, 37.77017429088422) -122.624122  37.769719
# 3        (-122.33321689246519, 37.760768150009845) -122.332704  37.760578
# 4         (-122.28681546396929, 37.79171966556907) -122.287302  37.791454
# ...                                            ...         ...        ...
# 2784882   (-122.65434334046668, 37.55964657678767) -122.653832  37.559458
# 2784883   (-122.44194736091958, 37.90198535289974) -122.442434  37.901720
# 2784884   (-122.7899784467906, 37.930862081351414) -122.790463  37.930595
# 2784885   (-122.88474235412144, 37.87623680277327) -122.884259  37.876504
# 2784886  (-122.73196923341584, 37.408358990939554) -122.731941  37.407903
#
#            target_x   target_y    weight  \
# 0       -122.701050  37.294772  0.196414
# 1       -122.348264  37.726226  0.028062
# 2       -122.624150  37.770174  0.027349
# 3       -122.333217  37.760768  0.026888
# 4       -122.286815  37.791720  0.028062
# ...             ...        ...       ...
# 2784882 -122.654343  37.559647  0.026860
# 2784883 -122.441947  37.901985  0.028035
# 2784884 -122.789978  37.930862  0.027993
# 2784885 -122.884742  37.876237  0.027987
# 2784886 -122.731969  37.408359  0.027417
#
#                                                   geometry  base_weight  ...  \
# 0        LINESTRING (-122.70443 37.2929, -122.70105 37....     0.196414  ...
# 1        LINESTRING (-122.34778 37.72649, -122.34826 37...     0.028062  ...
# 2        LINESTRING (-122.62412 37.76972, -122.62415 37...     0.027349  ...
# 3        LINESTRING (-122.3327 37.76058, -122.33322 37....     0.026888  ...
# 4        LINESTRING (-122.2873 37.79145, -122.28682 37....     0.028062  ...
# ...                                                    ...          ...  ...
# 2784882  LINESTRING (-122.65383 37.55946, -122.65434 37...     0.026860  ...
# 2784883  LINESTRING (-122.44243 37.90172, -122.44195 37...     0.028035  ...
# 2784884  LINESTRING (-122.79046 37.9306, -122.78998 37....     0.027993  ...
# 2784885  LINESTRING (-122.88426 37.8765, -122.88474 37....     0.027987  ...
# 2784886  LINESTRING (-122.73194 37.4079, -122.73197 37....     0.027417  ...
#
#                                           ft_depth_sources  ft_hor_clearance  \
# 0        {'US1WC01M_depare': {'value': 30, 'usage_band'...              None
# 1        {'US1WC01M_depare': {'value': 0, 'usage_band':...              None
# 2        {'US1WC01M_depare': {'value': 0, 'usage_band':...              None
# 3        {'US1WC01M_depare': {'value': 0, 'usage_band':...              None
# 4        {'US5CA13M_drgare': {'value': 14.5, 'usage_ban...              None
# ...                                                    ...               ...
# 2784882  {'US1WC01M_depare': {'value': 30, 'usage_band'...              None
# 2784883  {'US1WC01M_depare': {'value': 0, 'usage_band':...              None
# 2784884  {'US1WC01M_depare': {'value': 30, 'usage_band'...              None
# 2784885  {'US1WC01M_depare': {'value': 30, 'usage_band'...              None
# 2784886  {'US1WC01M_depare': {'value': 30, 'usage_band'...              None
#
#          ft_hor_clearance_sources  ft_ver_clearance  ft_ver_clearance_sources  \
# 0                            None               NaN                      None
# 1                            None               NaN                      None
# 2                            None               NaN                      None
# 3                            None               NaN                      None
# 4                            None               NaN                      None
# ...                           ...               ...                       ...
# 2784882                      None               NaN                      None
# 2784883                      None               NaN                      None
# 2784884                      None               NaN                      None
# 2784885                      None               NaN                      None
# 2784886                      None               NaN                      None
#
#         ft_depth ft_sounding ft_sounding_sources  ft_sounding_point  \
# 0           91.4         NaN                None               None
# 1           18.2         NaN                None               None
# 2           15.4         NaN                None               None
# 3            9.1         NaN                None               None
# 4           14.5         NaN                None               None
# ...          ...         ...                 ...                ...
# 2784882     36.5         NaN                None               None
# 2784883      9.1         NaN                None               None
# 2784884     18.2         NaN                None               None
# 2784885     54.8         NaN                None               None
# 2784886     73.1         NaN                None               None
#
#         ft_sounding_point_sources
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
# ...                           ...
# 2784882                      None
# 2784883                      None
# 2784884                      None
# 2784885                      None
# 2784886                      None
#
# [2784887 rows x 25 columns]

# %%
config = weights_manager._load_config()

# %%
weights_manager.apply_static_weights_postgis(graph_name=graph_name,
                                             enc_names=enc_list,
                                             schema_name="graph",
                                             enc_schema="us_enc_all",
                                             static_layers=config["weight_settings"]["static_layers"],
                                             usage_bands=[3,4,5])

print("Static weights applied.")
# Out:
# 2025-10-09 13:20:30,945 - src.maritime_module.core.graph - INFO - Filtered 19 ENCs to 16 based on usage bands [3, 4, 5]
# 2025-10-09 13:20:30,946 - src.maritime_module.core.graph - INFO - === PostGIS Static Weights Application (Three-Tier System) ===
# 2025-10-09 13:20:30,946 - src.maritime_module.core.graph - INFO - Edges table: graph.h3_graph_PG_6_11_edges
# 2025-10-09 13:20:30,947 - src.maritime_module.core.graph - INFO - Layers schema: us_enc_all
# 2025-10-09 13:20:30,947 - src.maritime_module.core.graph - INFO - Processing 9 layers
# 2025-10-09 13:20:30,947 - src.maritime_module.core.graph - INFO - Ensuring three-tier weight columns exist...
# 2025-10-09 13:20:31,953 - src.maritime_module.core.graph - INFO - Added 'wt_static_blocking' column to h3_graph_PG_6_11_edges
# 2025-10-09 13:20:31,955 - src.maritime_module.core.graph - INFO - Added 'wt_static_penalty' column to h3_graph_PG_6_11_edges
# 2025-10-09 13:20:31,957 - src.maritime_module.core.graph - INFO - Added 'wt_static_bonus' column to h3_graph_PG_6_11_edges
# 2025-10-09 13:21:46,127 - src.maritime_module.core.graph - INFO - Reset three-tier columns to neutral (1.0)
# 2025-10-09 13:21:46,130 - src.maritime_module.core.graph - INFO - Using edges geometry column: 'geometry'
# 2025-10-09 13:21:46,130 - src.maritime_module.core.graph - INFO - Processing layer 'lndare': DANGEROUS, factor=100, buffer=0m
# 2025-10-09 13:22:24,008 - src.maritime_module.core.graph - INFO - Applied lndare: 25292 blocking, 0 penalty, 0 bonus edges
# 2025-10-09 13:22:24,009 - src.maritime_module.core.graph - INFO - Processing layer 'uwtroc': DANGEROUS, factor=100.0, buffer=500m
# 2025-10-09 13:22:24,182 - src.maritime_module.core.graph - INFO - Applied uwtroc: 1068 blocking, 0 penalty, 0 bonus edges
# 2025-10-09 13:22:24,183 - src.maritime_module.core.graph - INFO - Processing layer 'slcons': DANGEROUS, factor=90.0, buffer=400m
# 2025-10-09 13:22:28,343 - src.maritime_module.core.graph - INFO - Applied slcons: 75071 blocking, 0 penalty, 0 bonus edges
# 2025-10-09 13:22:28,344 - src.maritime_module.core.graph - INFO - Processing layer 'fairwy': SAFE, factor=0.5, buffer=0m
# 2025-10-09 13:22:30,904 - src.maritime_module.core.graph - INFO - Applied fairwy: 0 blocking, 0 penalty, 39675 bonus edges
# 2025-10-09 13:22:30,905 - src.maritime_module.core.graph - INFO - Processing layer 'tsslpt': CAUTION, factor=2.5, buffer=50m
# 2025-10-09 13:23:06,013 - src.maritime_module.core.graph - INFO - Applied tsslpt: 387679 blocking, 0 penalty, 0 bonus edges
# 2025-10-09 13:23:06,014 - src.maritime_module.core.graph - INFO - Processing layer 'drgare': SAFE, factor=0.9, buffer=0m
# 2025-10-09 13:23:11,312 - src.maritime_module.core.graph - INFO - Applied drgare: 0 blocking, 0 penalty, 28842 bonus edges
# 2025-10-09 13:23:11,313 - src.maritime_module.core.graph - INFO - Processing layer 'prcare': SAFE, factor=0.9, buffer=0m
# 2025-10-09 13:23:23,873 - src.maritime_module.core.graph - INFO - Applied prcare: 0 blocking, 0 penalty, 239880 bonus edges
# 2025-10-09 13:23:23,874 - src.maritime_module.core.graph - INFO - Processing layer 'rectrc': SAFE, factor=0.5, buffer=0m
# 2025-10-09 13:23:24,197 - src.maritime_module.core.graph - INFO - Applied rectrc: 0 blocking, 0 penalty, 978 bonus edges
# 2025-10-09 13:23:24,198 - src.maritime_module.core.graph - INFO - Processing layer 'dwrtcl': SAFE, factor=0.5, buffer=0m
# 2025-10-09 13:23:24,204 - src.maritime_module.core.graph - INFO - === PostGIS Static Weights Complete (Three-Tier System) ===
# 2025-10-09 13:23:24,204 - src.maritime_module.core.graph - INFO - Layers processed: 9
# 2025-10-09 13:23:24,205 - src.maritime_module.core.graph - INFO - Layers applied: 8
# 2025-10-09 13:23:24,205 - src.maritime_module.core.graph - INFO - Total edge updates: 798,485 (blocking: 489,110, penalty: 0, bonus: 309,375)
# 2025-10-09 13:23:24,206 - src.maritime_module.core.graph - INFO -   drgare: blocking=0, penalty=0, bonus=28842
# 2025-10-09 13:23:24,206 - src.maritime_module.core.graph - INFO -   fairwy: blocking=0, penalty=0, bonus=39675
# 2025-10-09 13:23:24,207 - src.maritime_module.core.graph - INFO -   lndare: blocking=25292, penalty=0, bonus=0
# 2025-10-09 13:23:24,207 - src.maritime_module.core.graph - INFO -   prcare: blocking=0, penalty=0, bonus=239880
# 2025-10-09 13:23:24,207 - src.maritime_module.core.graph - INFO -   rectrc: blocking=0, penalty=0, bonus=978
# 2025-10-09 13:23:24,208 - src.maritime_module.core.graph - INFO -   slcons: blocking=75071, penalty=0, bonus=0
# 2025-10-09 13:23:24,208 - src.maritime_module.core.graph - INFO -   tsslpt: blocking=387679, penalty=0, bonus=0
# 2025-10-09 13:23:24,209 - src.maritime_module.core.graph - INFO -   uwtroc: blocking=1068, penalty=0, bonus=0
# Static weights applied.

# %%
pg.get_table(table_name=f"{graph_name}_edges",
             schema_name="graph")
# Out:
# 2025-10-09 13:24:32,947 - src.maritime_module.utils.db_utils - INFO - Loaded 2784887 rows from 'graph.h3_graph_PG_6_11_edges'
#               id                                 source_str  \
# 0          36653   (-122.70442528145516, 37.29290314155771)
# 1        2558810   (-122.34777821998698, 37.72649185682434)
# 2        2440968   (-122.62412206689525, 37.76971930322309)
# 3        2456818   (-122.28730231963732, 37.79145427435659)
# 4        1350547  (-122.33270390719495, 37.760578187631054)
# ...          ...                                        ...
# 2784882  2223941   (-122.6538318318921, 37.559457571019436)
# 2784883  2328169     (-122.7904630686994, 37.9305951305571)
# 2784884   325045   (-122.44243385016007, 37.90171951332442)
# 2784885  1366157   (-122.88425853358922, 37.87650408249214)
# 2784886  1586607  (-122.73194111756014, 37.407902892540584)
#
#                                         target_str    source_x   source_y  \
# 0         (-122.70105009172504, 37.29477183788321) -122.704425  37.292903
# 1         (-122.34826442428414, 37.72622623378993) -122.347778  37.726492
# 2         (-122.62414982824414, 37.77017429088422) -122.624122  37.769719
# 3         (-122.28681546396929, 37.79171966556907) -122.287302  37.791454
# 4        (-122.33321689246519, 37.760768150009845) -122.332704  37.760578
# ...                                            ...         ...        ...
# 2784882   (-122.65434334046668, 37.55964657678767) -122.653832  37.559458
# 2784883   (-122.7899784467906, 37.930862081351414) -122.790463  37.930595
# 2784884   (-122.44194736091958, 37.90198535289974) -122.442434  37.901720
# 2784885   (-122.88474235412144, 37.87623680277327) -122.884259  37.876504
# 2784886  (-122.73196923341584, 37.408358990939554) -122.731941  37.407903
#
#            target_x   target_y    weight  \
# 0       -122.701050  37.294772  0.196414
# 1       -122.348264  37.726226  0.028062
# 2       -122.624150  37.770174  0.027349
# 3       -122.286815  37.791720  0.028062
# 4       -122.333217  37.760768  0.026888
# ...             ...        ...       ...
# 2784882 -122.654343  37.559647  0.026860
# 2784883 -122.789978  37.930862  0.027993
# 2784884 -122.441947  37.901985  0.028035
# 2784885 -122.884742  37.876237  0.027987
# 2784886 -122.731969  37.408359  0.027417
#
#                                                   geometry  base_weight  ...  \
# 0        LINESTRING (-122.70443 37.2929, -122.70105 37....     0.196414  ...
# 1        LINESTRING (-122.34778 37.72649, -122.34826 37...     0.028062  ...
# 2        LINESTRING (-122.62412 37.76972, -122.62415 37...     0.027349  ...
# 3        LINESTRING (-122.2873 37.79145, -122.28682 37....     0.028062  ...
# 4        LINESTRING (-122.3327 37.76058, -122.33322 37....     0.026888  ...
# ...                                                    ...          ...  ...
# 2784882  LINESTRING (-122.65383 37.55946, -122.65434 37...     0.026860  ...
# 2784883  LINESTRING (-122.79046 37.9306, -122.78998 37....     0.027993  ...
# 2784884  LINESTRING (-122.44243 37.90172, -122.44195 37...     0.028035  ...
# 2784885  LINESTRING (-122.88426 37.8765, -122.88474 37....     0.027987  ...
# 2784886  LINESTRING (-122.73194 37.4079, -122.73197 37....     0.027417  ...
#
#          ft_ver_clearance  ft_ver_clearance_sources  ft_depth  ft_sounding  \
# 0                     NaN                      None      91.4          NaN
# 1                     NaN                      None      18.2          NaN
# 2                     NaN                      None      15.4          NaN
# 3                     NaN                      None      14.5          NaN
# 4                     NaN                      None       9.1          NaN
# ...                   ...                       ...       ...          ...
# 2784882               NaN                      None      36.5          NaN
# 2784883               NaN                      None      18.2          NaN
# 2784884               NaN                      None       9.1          NaN
# 2784885               NaN                      None      54.8          NaN
# 2784886               NaN                      None      73.1          NaN
#
#          ft_sounding_sources ft_sounding_point ft_sounding_point_sources  \
# 0                       None              None                      None
# 1                       None              None                      None
# 2                       None              None                      None
# 3                       None              None                      None
# 4                       None              None                      None
# ...                      ...               ...                       ...
# 2784882                 None              None                      None
# 2784883                 None              None                      None
# 2784884                 None              None                      None
# 2784885                 None              None                      None
# 2784886                 None              None                      None
#
#         wt_static_blocking  wt_static_penalty wt_static_bonus
# 0                      1.0                1.0            1.00
# 1                      1.0                1.0            1.00
# 2                      5.0                1.0            0.45
# 3                    180.0                1.0            0.45
# 4                      1.0                1.0            1.00
# ...                    ...                ...             ...
# 2784882                5.0                1.0            1.00
# 2784883                1.0                1.0            1.00
# 2784884                1.0                1.0            0.50
# 2784885                1.0                1.0            1.00
# 2784886                5.0                1.0            1.00
#
# [2784887 rows x 28 columns]

# %%
ply = PlotlyChart()
ply_fig = ply.create_base_map(mapbox_token="pk.eyJ1Ijoidmlrb250IiwiYSI6ImNtNHljdzQwbjBybWIybHNkZzhleXhqYXUifQ.Jz0cR4J6PdAnLutVBqj2WA")
ply.plotly_base_config(ply_fig)
# Out:
# {'displayModeBar': 'hover',
#  'responsive': True,
#  'scrollZoom': True,
#  'displaylogo': False,
#  'modeBarButtonsToRemove': ['zoomIn',
#   'zoomOut',
#   'pan',
#   'select',
#   'lassoSelect'],
#  'modeBarButtonsToAdd': ['autoScale', 'hoverCompareCartesian']}

# %% [markdown]
#  ## Calculate Dynamic Weights

# %%
# Define vessel parameters for dynamic weight calculation
vessel_params = {
 'draft': 7.5,           # meters
 'height': 30.0,         # meters (for overhead clearance)
 'safety_margin': 2.0,   # meters (for under-keel clearance)
 'vessel_type': 'cargo'
}

# Define environmental conditions (optional)
env_conditions = {
 'weather_factor': 1.2,      # 1.0=good, >1.0=poor
 'visibility_factor': 1.1,   # 1.0=good, >1.0=poor
 'time_of_day': 'day'        # 'day' or 'night'
}

# Calculate the final weights
# This function uses the three-tier system: Blocking, Penalties, and Bonuses
weights_manager.calculate_dynamic_weights_postgis(
 graph_name=graph_name,
 schema_name="graph",
 vessel_parameters=vessel_params,
 environmental_conditions=env_conditions,
)

print("Dynamic weights calculated.")
# Out:
# 2025-10-09 13:24:34,442 - src.maritime_module.core.graph - INFO - === Dynamic Weight Calculation (PostGIS - Three-Tier System) ===
# 2025-10-09 13:24:34,443 - src.maritime_module.core.graph - INFO - Vessel: type=cargo, draft=7.5m, height=30.0m
# 2025-10-09 13:24:34,444 - src.maritime_module.core.graph - INFO - Safety margin: 2.0m → 2.64m (adjusted)
# 2025-10-09 13:24:34,444 - src.maritime_module.core.graph - INFO - Environment: weather=1.2, visibility=1.1, time=day
# 2025-10-09 13:24:34,444 - src.maritime_module.core.graph - INFO - Max penalty cap: 50.0
# 2025-10-09 13:26:14,806 - src.maritime_module.core.graph - INFO - Tier 1: Calculating blocking factors...
# 2025-10-09 13:27:09,783 - src.maritime_module.core.graph - INFO - Tier 2: Calculating penalty factors...
# 2025-10-09 13:27:44,792 - src.maritime_module.core.graph - INFO - Tier 3: Calculating bonus factors...
# 2025-10-09 13:28:43,339 - src.maritime_module.core.graph - INFO - Calculating adjusted weights...
# 2025-10-09 13:30:16,578 - src.maritime_module.core.graph - INFO - NOTE: 'weight' column preserved as original distance. Use 'adjusted_weight' for pathfinding.
# 2025-10-09 13:30:24,898 - src.maritime_module.core.graph - INFO - === Dynamic Weight Calculation Complete (PostGIS) ===
# 2025-10-09 13:30:24,899 - src.maritime_module.core.graph - INFO - Total edges: 2,784,887
# 2025-10-09 13:30:24,900 - src.maritime_module.core.graph - INFO - Blocked edges: 1,133,019 (40.7%)
# 2025-10-09 13:30:24,900 - src.maritime_module.core.graph - INFO - Penalized edges: 405,682 (14.6%)
# 2025-10-09 13:30:24,900 - src.maritime_module.core.graph - INFO - Bonus edges: 1,298,944 (46.6%)
# Dynamic weights calculated.

# %% [markdown]
# ## Inspect Weighted Graph

# %%
pg.get_table(table_name=f"{graph_name}_edges",
             schema_name="graph")
# Out:
# 2025-10-09 13:31:41,501 - src.maritime_module.utils.db_utils - INFO - Loaded 2784887 rows from 'graph.h3_graph_PG_6_11_edges'
#               id                                 source_str  \
# 0          36653   (-122.70442528145516, 37.29290314155771)
# 1        2558810   (-122.34777821998698, 37.72649185682434)
# 2        2456818   (-122.28730231963732, 37.79145427435659)
# 3        2440968   (-122.62412206689525, 37.76971930322309)
# 4        1350547  (-122.33270390719495, 37.760578187631054)
# ...          ...                                        ...
# 2784882  2223941   (-122.6538318318921, 37.559457571019436)
# 2784883  2328169     (-122.7904630686994, 37.9305951305571)
# 2784884   325045   (-122.44243385016007, 37.90171951332442)
# 2784885  1366157   (-122.88425853358922, 37.87650408249214)
# 2784886  1586607  (-122.73194111756014, 37.407902892540584)
#
#                                         target_str    source_x   source_y  \
# 0         (-122.70105009172504, 37.29477183788321) -122.704425  37.292903
# 1         (-122.34826442428414, 37.72622623378993) -122.347778  37.726492
# 2         (-122.28681546396929, 37.79171966556907) -122.287302  37.791454
# 3         (-122.62414982824414, 37.77017429088422) -122.624122  37.769719
# 4        (-122.33321689246519, 37.760768150009845) -122.332704  37.760578
# ...                                            ...         ...        ...
# 2784882   (-122.65434334046668, 37.55964657678767) -122.653832  37.559458
# 2784883   (-122.7899784467906, 37.930862081351414) -122.790463  37.930595
# 2784884   (-122.44194736091958, 37.90198535289974) -122.442434  37.901720
# 2784885   (-122.88474235412144, 37.87623680277327) -122.884259  37.876504
# 2784886  (-122.73196923341584, 37.408358990939554) -122.731941  37.407903
#
#            target_x   target_y    weight  \
# 0       -122.701050  37.294772  0.196414
# 1       -122.348264  37.726226  0.028062
# 2       -122.286815  37.791720  0.028062
# 3       -122.624150  37.770174  0.027349
# 4       -122.333217  37.760768  0.026888
# ...             ...        ...       ...
# 2784882 -122.654343  37.559647  0.026860
# 2784883 -122.789978  37.930862  0.027993
# 2784884 -122.441947  37.901985  0.028035
# 2784885 -122.884742  37.876237  0.027987
# 2784886 -122.731969  37.408359  0.027417
#
#                                                   geometry  base_weight  ...  \
# 0        LINESTRING (-122.70443 37.2929, -122.70105 37....     0.196414  ...
# 1        LINESTRING (-122.34778 37.72649, -122.34826 37...     0.028062  ...
# 2        LINESTRING (-122.2873 37.79145, -122.28682 37....     0.028062  ...
# 3        LINESTRING (-122.62412 37.76972, -122.62415 37...     0.027349  ...
# 4        LINESTRING (-122.3327 37.76058, -122.33322 37....     0.026888  ...
# ...                                                    ...          ...  ...
# 2784882  LINESTRING (-122.65383 37.55946, -122.65434 37...     0.026860  ...
# 2784883  LINESTRING (-122.79046 37.9306, -122.78998 37....     0.027993  ...
# 2784884  LINESTRING (-122.44243 37.90172, -122.44195 37...     0.028035  ...
# 2784885  LINESTRING (-122.88426 37.8765, -122.88474 37....     0.027987  ...
# 2784886  LINESTRING (-122.73194 37.4079, -122.73197 37....     0.027417  ...
#
#          ft_ver_clearance  ft_ver_clearance_sources  ft_depth  ft_sounding  \
# 0                     NaN                      None      91.4          NaN
# 1                     NaN                      None      18.2          NaN
# 2                     NaN                      None      14.5          NaN
# 3                     NaN                      None      15.4          NaN
# 4                     NaN                      None       9.1          NaN
# ...                   ...                       ...       ...          ...
# 2784882               NaN                      None      36.5          NaN
# 2784883               NaN                      None      18.2          NaN
# 2784884               NaN                      None       9.1          NaN
# 2784885               NaN                      None      54.8          NaN
# 2784886               NaN                      None      73.1          NaN
#
#          ft_sounding_sources ft_sounding_point ft_sounding_point_sources  \
# 0                       None              None                      None
# 1                       None              None                      None
# 2                       None              None                      None
# 3                       None              None                      None
# 4                       None              None                      None
# ...                      ...               ...                       ...
# 2784882                 None              None                      None
# 2784883                 None              None                      None
# 2784884                 None              None                      None
# 2784885                 None              None                      None
# 2784886                 None              None                      None
#
#         wt_static_blocking  wt_static_penalty wt_static_bonus
# 0                      1.0                1.0            1.00
# 1                      1.0                1.0            1.00
# 2                    180.0                1.0            0.45
# 3                      5.0                1.0            0.45
# 4                      1.0                1.0            1.00
# ...                    ...                ...             ...
# 2784882                5.0                1.0            1.00
# 2784883                1.0                1.0            1.00
# 2784884                1.0                1.0            0.50
# 2784885                1.0                1.0            1.00
# 2784886                5.0                1.0            1.00
#
# [2784887 rows x 28 columns]

# %% [markdown]
#  ## Save the Weighted Graph

# %%
output_path = output_dir / "weighted_graph_new5.gpkg"
h3.export_postgis_to_gpkg(schema_name="graph",
                          graph_name=graph_name,
                            output_path=str(output_path))
# Out:
# 2025-10-09 13:31:42,928 - src.maritime_module.core.graph - INFO - === Exporting PostGIS to GeoPackage ===
# 2025-10-09 13:31:42,928 - src.maritime_module.core.graph - INFO - Source: graph.h3_graph_PG_6_11_nodes, graph.h3_graph_PG_6_11_edges
# 2025-10-09 13:31:42,928 - src.maritime_module.core.graph - INFO - Target: /home/vikont_tux/python_projects_wsl2/1_MaritimeModule_V1/docs/notebooks/output/weighted_graph_new5.gpkg
# 2025-10-09 13:31:42,929 - src.maritime_module.core.graph - INFO - Exporting nodes table...
# 2025-10-09 13:31:49,134 - src.maritime_module.core.graph - INFO - Nodes exported in 6.205s
# 2025-10-09 13:31:49,135 - src.maritime_module.core.graph - INFO - Exporting edges table...
# 2025-10-09 13:32:36,299 - src.maritime_module.core.graph - INFO - Edges exported in 47.164s
# 2025-10-09 13:32:37,493 - src.maritime_module.core.graph - INFO - === Export Complete ===
# 2025-10-09 13:32:37,495 - src.maritime_module.core.graph - INFO - Exported 931,149 nodes, 2,784,887 edges
# 2025-10-09 13:32:37,495 - src.maritime_module.core.graph - INFO - Total time: 54.566s
# 2025-10-09 13:32:37,495 - src.maritime_module.core.graph - INFO - Output: /home/vikont_tux/python_projects_wsl2/1_MaritimeModule_V1/docs/notebooks/output/weighted_graph_new5.gpkg
# {'node_count': 931149,
#  'edge_count': 2784887,
#  'output_path': '/home/vikont_tux/python_projects_wsl2/1_MaritimeModule_V1/docs/notebooks/output/weighted_graph_new5.gpkg',
#  'total_time': 54.56614867999997}

# %%
# import geopandas as gpd
# from typing import List
# layer_name = "drgare"
# layer = factory.get_layer(layer_name=layer_name,
#                           filter_by_enc=enc_list)
# layer_path = output_dir / f"layer_{layer_name}.gpkg"
# layer.to_file(layer_path, driver="GPKG", engine="fiona")

# %%
# def save_layer_by_usage_band(factory, layer_name: str, enc_list: List[str], output_path: str):
# 		"""
# 		Fetches a layer and saves it to a GeoPackage, with each usage band as a separate layer.
#
# 		This is useful for inspecting how different navigational scale data (e.g., overview vs. harbour)
# 		is represented for a given S-57 feature.
#
# 		Args:
# 			factory: An initialized ENCDataFactory instance.
# 			layer_name (str): The name of the S-57 layer to process (e.g., 'depare', 'obstrn').
# 			enc_list (List[str]): A list of ENC names to filter the data.
# 			output_path (str): The path for the output GeoPackage file.
#
# 		Example:
# 			ply = PlotlyChart()
# 			output_file = output_dir / "depare_by_band.gpkg"
# 			ply.save_layer_by_usage_band(
# 				factory=pg_factory,
# 				layer_name="depare",
# 				enc_list=enc_list,
# 				output_path=str(output_file)
# 			)
# 		"""
# 		print(f"--- Saving layer '{layer_name}' to '{output_path}' by usage band ---")
#
# 		# Fetch the entire layer for the given ENCs first to avoid multiple DB calls
# 		try:
# 			full_layer_gdf = factory.get_layer(layer_name=layer_name, filter_by_enc=enc_list)
# 			if full_layer_gdf.empty:
# 				print(f"Layer '{layer_name}' is empty or not found for the given ENCs. No file created.")
# 				return
# 		except Exception as e:
# 			print(f"Error fetching layer '{layer_name}': {e}")
# 			return
#
# 		# Iterate through usage bands 1 to 6
# 		for i in range(1, 7):
# 			band_encs = [enc for enc in enc_list if len(enc) > 2 and enc[2] == str(i)]
# 			if not band_encs:
# 				continue
#
# 			# Filter the GeoDataFrame in memory
# 			band_gdf = full_layer_gdf[full_layer_gdf['dsid_dsnm'].isin(band_encs)]
#
# 			if not band_gdf.empty:
# 				band_layer_name = f"{layer_name}_band_{i}"
# 				# Use mode 'a' (append) for subsequent layers
# 				mode = 'w' if i == 1 else 'a'
# 				band_gdf.to_file(output_path, layer=band_layer_name, driver="GPKG", mode=mode)
# 				print(f"Saved {len(band_gdf)} features to layer '{band_layer_name}'")

# %%
# layer_path = output_dir / f"layer_{layer_name}_multi.gpkg"
# save_layer_by_usage_band(factory=factory,
#                          layer_name="depare",
#                          enc_list=enc_list,
#                          output_path=str(layer_path))
