# %% [markdown]
# # Test 1: Data Integrity and Unit Testing
#
# This section runs the complete unit test suite for `ENCDataFactory` to validate:
# - Data integrity across conversions
# - Correct NOAA version tracking
# - Proper layer enumeration and summarization
# - Edge cases and error handling
#
# The tests use actual S-57 data and real database backends to ensure end-to-end reliability.

# %% [markdown]
# # ENCDataFactory Testing and Exploration
#
# This notebook provides a comprehensive guide to testing and exploring the `ENCDataFactory` class,
# which provides a unified interface for accessing S-57 Electronic Navigational Chart (ENC) data
# from different backends (PostGIS, GeoPackage, SpatiaLite).
#
# ## What You'll Learn
# - How to initialize the `ENCDataFactory` for different data sources
# - How to query ENC metadata (edition, update numbers, NOAA versions)
# - How to retrieve and analyze layer information across your ENC database
# - How to filter ENCs by usage band (scale categories)
# - How to obtain bounding boxes for geographic analysis
#
# ## Prerequisites
# - S-57 data converted to GeoPackage, SpatiaLite, or PostGIS format
# - Environment variables configured (.env file) for database connections
# - Access to internet for NOAA database validation (optional)
#
# ## Architecture
# The `ENCDataFactory` abstracts away the differences between backend systems:
# - **PostGIS**: Enterprise database for multi-user access
# - **GeoPackage**: Single-file format for portability
# - **SpatiaLite**: SQLite-based spatial database, self-contained
#
# Choose your backend based on your use case and infrastructure.

# %% [markdown]
# ## Step 1: Setup and Imports

# %%
import sys
import os
from pathlib import Path
import unittest
from dotenv import load_dotenv


# --- Setup Project Path ---
# This ensures you can import your own modules like 's57_data'
project_root = Path.cwd().parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# --- Load Environment Variables ---
# This loads your DB_USER, DB_PASSWORD, etc., from the .env file
load_dotenv(project_root / ".env")

# --- Import the Test Class ---
# Now you can import the test case you created
from tests.core__real_data.test_enc_factory import TestENCDataFactory

print(f"Project Root: {project_root}")
print("Setup complete. Test class 'TestENCDataFactory' is ready to be used.")
# Out:
# Project Root: /home/vikont_tux/python_projects_wsl2/1_MaritimeModule_V1
# Setup complete. Test class 'TestENCDataFactory' is ready to be used.

# %% [markdown]
# ## Step 2: Run the Test Suite

# %%
# --- Run the Unittest Suite in the Notebook ---

# 1. Create a TestLoader to find the tests in your class
loader = unittest.TestLoader()
suite = loader.loadTestsFromTestCase(TestENCDataFactory)

# 2. Create a TextTestRunner to execute the tests
# verbosity=2 provides detailed output for each test run
runner = unittest.TextTestRunner(verbosity=2)
result = runner.run(suite)

# The output will appear below this cell, showing the setup, test execution, and teardown logs.
# Out:
# --- Setting up test environment for ENCDataFactory ---
# Creating PostGIS data source...
# 2025-09-15 22:04:29,097 - src.maritime_module.core.s57_data - INFO - Found 6 S-57 file(s).
# 2025-09-15 22:04:29,097 - src.maritime_module.core.s57_data - INFO - --- Starting optimized 'by_layer' conversion ---
# 2025-09-15 22:04:29,097 - src.maritime_module.core.s57_data - INFO - Files to process: 6, Batch size: 3
# 2025-09-15 22:04:29,098 - src.maritime_module.core.s57_data - INFO - Pre-processing files to extract schemas and ENC names...
# 2025-09-15 22:04:29,234 - src.maritime_module.core.s57_data - INFO - Built unified schemas for 86 layers
# 2025-09-15 22:04:29,367 - src.maritime_module.utils.db_utils - INFO - Successfully connected to database 'ENC_db' for schema management.
# 2025-09-15 22:04:29,382 - src.maritime_module.utils.db_utils - WARNING - Overwrite is enabled. Dropping and recreating schema 'factory_test_schema'...
# 2025-09-15 22:04:29,388 - src.maritime_module.utils.db_utils - INFO - Schema 'factory_test_schema' is ready.
# 2025-09-15 22:04:29,388 - src.maritime_module.core.s57_data - INFO - Processing layer: DSID
# 2025-09-15 22:04:29,682 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'DSID' with 6 files
# 2025-09-15 22:04:29,683 - src.maritime_module.core.s57_data - INFO - Processing layer: IsolatedNode
# 2025-09-15 22:04:30,052 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'IsolatedNode' with 6 files
# 2025-09-15 22:04:30,053 - src.maritime_module.core.s57_data - INFO - Processing layer: ConnectedNode
# 2025-09-15 22:04:29,388 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'ConnectedNode' with 6 files
# 2025-09-15 22:04:29,389 - src.maritime_module.core.s57_data - INFO - Processing layer: Edge
# 2025-09-15 22:04:29,614 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'Edge' with 6 files
# 2025-09-15 22:04:29,615 - src.maritime_module.core.s57_data - INFO - Processing layer: Face
# 2025-09-15 22:04:29,840 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'Face' with 6 files
# 2025-09-15 22:04:29,841 - src.maritime_module.core.s57_data - INFO - Processing layer: ADMARE
# 2025-09-15 22:04:30,158 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'ADMARE' with 6 files
# 2025-09-15 22:04:30,159 - src.maritime_module.core.s57_data - INFO - Processing layer: AIRARE
# 2025-09-15 22:04:30,259 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'AIRARE' with 2 files
# 2025-09-15 22:04:30,260 - src.maritime_module.core.s57_data - INFO - Processing layer: BCNLAT
# 2025-09-15 22:04:30,400 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'BCNLAT' with 3 files
# 2025-09-15 22:04:30,401 - src.maritime_module.core.s57_data - INFO - Processing layer: BCNSPP
# 2025-09-15 22:04:30,562 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'BCNSPP' with 3 files
# 2025-09-15 22:04:30,563 - src.maritime_module.core.s57_data - INFO - Processing layer: BRIDGE
# 2025-09-15 22:04:30,714 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'BRIDGE' with 3 files
# 2025-09-15 22:04:30,715 - src.maritime_module.core.s57_data - INFO - Processing layer: BUISGL
# 2025-09-15 22:04:30,848 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'BUISGL' with 3 files
# 2025-09-15 22:04:30,849 - src.maritime_module.core.s57_data - INFO - Processing layer: BUAARE
# 2025-09-15 22:04:31,039 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'BUAARE' with 3 files
# 2025-09-15 22:04:31,040 - src.maritime_module.core.s57_data - INFO - Processing layer: BOYLAT
# 2025-09-15 22:04:31,182 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'BOYLAT' with 3 files
# 2025-09-15 22:04:31,183 - src.maritime_module.core.s57_data - INFO - Processing layer: BOYSAW
# 2025-09-15 22:04:31,319 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'BOYSAW' with 3 files
# 2025-09-15 22:04:31,320 - src.maritime_module.core.s57_data - INFO - Processing layer: BOYSPP
# 2025-09-15 22:04:31,557 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'BOYSPP' with 5 files
# 2025-09-15 22:04:31,558 - src.maritime_module.core.s57_data - INFO - Processing layer: CBLSUB
# 2025-09-15 22:04:31,765 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CBLSUB' with 4 files
# 2025-09-15 22:04:31,766 - src.maritime_module.core.s57_data - INFO - Processing layer: CTNARE
# 2025-09-15 22:04:32,011 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CTNARE' with 3 files
# 2025-09-15 22:04:32,012 - src.maritime_module.core.s57_data - INFO - Processing layer: CGUSTA
# 2025-09-15 22:04:32,067 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CGUSTA' with 1 files
# 2025-09-15 22:04:32,068 - src.maritime_module.core.s57_data - INFO - Processing layer: COALNE
# 2025-09-15 22:04:32,743 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'COALNE' with 5 files
# 2025-09-15 22:04:32,744 - src.maritime_module.core.s57_data - INFO - Processing layer: CONZNE
# 2025-09-15 22:04:32,946 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CONZNE' with 4 files
# 2025-09-15 22:04:32,946 - src.maritime_module.core.s57_data - INFO - Processing layer: DAYMAR
# 2025-09-15 22:04:33,088 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'DAYMAR' with 3 files
# 2025-09-15 22:04:33,089 - src.maritime_module.core.s57_data - INFO - Processing layer: DEPARE
# 2025-09-15 22:04:33,726 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'DEPARE' with 6 files
# 2025-09-15 22:04:33,727 - src.maritime_module.core.s57_data - INFO - Processing layer: DEPCNT
# 2025-09-15 22:04:34,256 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'DEPCNT' with 6 files
# 2025-09-15 22:04:34,257 - src.maritime_module.core.s57_data - INFO - Processing layer: DMPGRD
# 2025-09-15 22:04:34,401 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'DMPGRD' with 3 files
# 2025-09-15 22:04:34,402 - src.maritime_module.core.s57_data - INFO - Processing layer: EXEZNE
# 2025-09-15 22:04:34,652 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'EXEZNE' with 6 files
# 2025-09-15 22:04:34,653 - src.maritime_module.core.s57_data - INFO - Processing layer: FOGSIG
# 2025-09-15 22:04:34,794 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'FOGSIG' with 3 files
# 2025-09-15 22:04:34,795 - src.maritime_module.core.s57_data - INFO - Processing layer: HRBFAC
# 2025-09-15 22:04:34,852 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'HRBFAC' with 1 files
# 2025-09-15 22:04:34,853 - src.maritime_module.core.s57_data - INFO - Processing layer: LAKARE
# 2025-09-15 22:04:34,999 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LAKARE' with 3 files
# 2025-09-15 22:04:35,000 - src.maritime_module.core.s57_data - INFO - Processing layer: LNDARE
# 2025-09-15 22:04:35,692 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LNDARE' with 5 files
# 2025-09-15 22:04:35,693 - src.maritime_module.core.s57_data - INFO - Processing layer: LNDELV
# 2025-09-15 22:04:35,904 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LNDELV' with 4 files
# 2025-09-15 22:04:35,905 - src.maritime_module.core.s57_data - INFO - Processing layer: LNDRGN
# 2025-09-15 22:04:36,106 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LNDRGN' with 3 files
# 2025-09-15 22:04:36,107 - src.maritime_module.core.s57_data - INFO - Processing layer: LNDMRK
# 2025-09-15 22:04:36,406 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LNDMRK' with 4 files
# 2025-09-15 22:04:36,406 - src.maritime_module.core.s57_data - INFO - Processing layer: LIGHTS
# 2025-09-15 22:04:36,779 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LIGHTS' with 5 files
# 2025-09-15 22:04:36,780 - src.maritime_module.core.s57_data - INFO - Processing layer: MAGVAR
# 2025-09-15 22:04:37,095 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'MAGVAR' with 6 files
# 2025-09-15 22:04:37,096 - src.maritime_module.core.s57_data - INFO - Processing layer: MIPARE
# 2025-09-15 22:04:37,281 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'MIPARE' with 4 files
# 2025-09-15 22:04:37,282 - src.maritime_module.core.s57_data - INFO - Processing layer: OBSTRN
# 2025-09-15 22:04:37,579 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'OBSTRN' with 5 files
# 2025-09-15 22:04:37,580 - src.maritime_module.core.s57_data - INFO - Processing layer: PIPSOL
# 2025-09-15 22:04:37,724 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PIPSOL' with 3 files
# 2025-09-15 22:04:37,725 - src.maritime_module.core.s57_data - INFO - Processing layer: RDOCAL
# 2025-09-15 22:04:37,786 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RDOCAL' with 1 files
# 2025-09-15 22:04:37,786 - src.maritime_module.core.s57_data - INFO - Processing layer: RDOSTA
# 2025-09-15 22:04:37,967 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RDOSTA' with 4 files
# 2025-09-15 22:04:37,968 - src.maritime_module.core.s57_data - INFO - Processing layer: RECTRC
# 2025-09-15 22:04:38,063 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RECTRC' with 2 files
# 2025-09-15 22:04:38,063 - src.maritime_module.core.s57_data - INFO - Processing layer: RESARE
# 2025-09-15 22:04:38,281 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RESARE' with 5 files
# 2025-09-15 22:04:38,282 - src.maritime_module.core.s57_data - INFO - Processing layer: RIVERS
# 2025-09-15 22:04:38,510 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RIVERS' with 4 files
# 2025-09-15 22:04:38,511 - src.maritime_module.core.s57_data - INFO - Processing layer: SEAARE
# 2025-09-15 22:04:38,880 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SEAARE' with 6 files
# 2025-09-15 22:04:38,881 - src.maritime_module.core.s57_data - INFO - Processing layer: SBDARE
# 2025-09-15 22:04:39,272 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SBDARE' with 5 files
# 2025-09-15 22:04:39,273 - src.maritime_module.core.s57_data - INFO - Processing layer: SLCONS
# 2025-09-15 22:04:39,626 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SLCONS' with 4 files
# 2025-09-15 22:04:39,627 - src.maritime_module.core.s57_data - INFO - Processing layer: SILTNK
# 2025-09-15 22:04:39,764 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SILTNK' with 3 files
# 2025-09-15 22:04:39,765 - src.maritime_module.core.s57_data - INFO - Processing layer: SLOGRD
# 2025-09-15 22:04:39,877 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SLOGRD' with 2 files
# 2025-09-15 22:04:39,878 - src.maritime_module.core.s57_data - INFO - Processing layer: SOUNDG
# 2025-09-15 22:04:42,651 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SOUNDG' with 6 files
# 2025-09-15 22:04:42,652 - src.maritime_module.core.s57_data - INFO - Processing layer: TESARE
# 2025-09-15 22:04:42,775 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'TESARE' with 2 files
# 2025-09-15 22:04:42,776 - src.maritime_module.core.s57_data - INFO - Processing layer: TOPMAR
# 2025-09-15 22:04:42,885 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'TOPMAR' with 2 files
# 2025-09-15 22:04:42,885 - src.maritime_module.core.s57_data - INFO - Processing layer: TSSBND
# 2025-09-15 22:04:43,035 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'TSSBND' with 3 files
# 2025-09-15 22:04:43,036 - src.maritime_module.core.s57_data - INFO - Processing layer: TSSLPT
# 2025-09-15 22:04:43,181 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'TSSLPT' with 3 files
# 2025-09-15 22:04:43,182 - src.maritime_module.core.s57_data - INFO - Processing layer: TSEZNE
# 2025-09-15 22:04:43,275 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'TSEZNE' with 2 files
# 2025-09-15 22:04:43,276 - src.maritime_module.core.s57_data - INFO - Processing layer: UWTROC
# 2025-09-15 22:04:43,613 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'UWTROC' with 4 files
# 2025-09-15 22:04:43,613 - src.maritime_module.core.s57_data - INFO - Processing layer: WATTUR
# 2025-09-15 22:04:43,680 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'WATTUR' with 1 files
# 2025-09-15 22:04:43,681 - src.maritime_module.core.s57_data - INFO - Processing layer: WEDKLP
# 2025-09-15 22:04:43,822 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'WEDKLP' with 2 files
# 2025-09-15 22:04:43,823 - src.maritime_module.core.s57_data - INFO - Processing layer: WRECKS
# 2025-09-15 22:04:44,026 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'WRECKS' with 3 files
# 2025-09-15 22:04:44,027 - src.maritime_module.core.s57_data - INFO - Processing layer: M_COVR
# 2025-09-15 22:04:44,271 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'M_COVR' with 6 files
# 2025-09-15 22:04:44,272 - src.maritime_module.core.s57_data - INFO - Processing layer: M_NPUB
# 2025-09-15 22:04:44,512 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'M_NPUB' with 6 files
# 2025-09-15 22:04:44,513 - src.maritime_module.core.s57_data - INFO - Processing layer: M_NSYS
# 2025-09-15 22:04:44,757 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'M_NSYS' with 6 files
# 2025-09-15 22:04:44,758 - src.maritime_module.core.s57_data - INFO - Processing layer: M_QUAL
# 2025-09-15 22:04:45,089 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'M_QUAL' with 6 files
# 2025-09-15 22:04:45,090 - src.maritime_module.core.s57_data - INFO - Processing layer: C_AGGR
# 2025-09-15 22:04:45,214 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'C_AGGR' with 3 files
# 2025-09-15 22:04:45,215 - src.maritime_module.core.s57_data - INFO - Processing layer: C_ASSO
# 2025-09-15 22:04:45,342 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'C_ASSO' with 3 files
# 2025-09-15 22:04:45,342 - src.maritime_module.core.s57_data - INFO - Processing layer: FSHZNE
# 2025-09-15 22:04:45,399 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'FSHZNE' with 1 files
# 2025-09-15 22:04:45,399 - src.maritime_module.core.s57_data - INFO - Processing layer: ACHARE
# 2025-09-15 22:04:45,491 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'ACHARE' with 2 files
# 2025-09-15 22:04:45,492 - src.maritime_module.core.s57_data - INFO - Processing layer: CBLARE
# 2025-09-15 22:04:45,586 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CBLARE' with 2 files
# 2025-09-15 22:04:45,587 - src.maritime_module.core.s57_data - INFO - Processing layer: CBLOHD
# 2025-09-15 22:04:45,642 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CBLOHD' with 1 files
# 2025-09-15 22:04:45,643 - src.maritime_module.core.s57_data - INFO - Processing layer: DAMCON
# 2025-09-15 22:04:45,700 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'DAMCON' with 1 files
# 2025-09-15 22:04:45,700 - src.maritime_module.core.s57_data - INFO - Processing layer: FAIRWY
# 2025-09-15 22:04:45,768 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'FAIRWY' with 1 files
# 2025-09-15 22:04:45,769 - src.maritime_module.core.s57_data - INFO - Processing layer: FERYRT
# 2025-09-15 22:04:45,832 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'FERYRT' with 1 files
# 2025-09-15 22:04:45,832 - src.maritime_module.core.s57_data - INFO - Processing layer: MARCUL
# 2025-09-15 22:04:45,895 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'MARCUL' with 1 files
# 2025-09-15 22:04:45,896 - src.maritime_module.core.s57_data - INFO - Processing layer: MORFAC
# 2025-09-15 22:04:46,004 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'MORFAC' with 2 files
# 2025-09-15 22:04:46,005 - src.maritime_module.core.s57_data - INFO - Processing layer: NAVLNE
# 2025-09-15 22:04:46,066 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'NAVLNE' with 1 files
# 2025-09-15 22:04:46,067 - src.maritime_module.core.s57_data - INFO - Processing layer: OFSPLF
# 2025-09-15 22:04:46,183 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'OFSPLF' with 2 files
# 2025-09-15 22:04:46,184 - src.maritime_module.core.s57_data - INFO - Processing layer: PILPNT
# 2025-09-15 22:04:46,291 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PILPNT' with 2 files
# 2025-09-15 22:04:46,291 - src.maritime_module.core.s57_data - INFO - Processing layer: PILBOP
# 2025-09-15 22:04:46,353 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PILBOP' with 1 files
# 2025-09-15 22:04:46,354 - src.maritime_module.core.s57_data - INFO - Processing layer: PIPARE
# 2025-09-15 22:04:46,419 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PIPARE' with 1 files
# 2025-09-15 22:04:46,420 - src.maritime_module.core.s57_data - INFO - Processing layer: PONTON
# 2025-09-15 22:04:46,484 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PONTON' with 1 files
# 2025-09-15 22:04:46,484 - src.maritime_module.core.s57_data - INFO - Processing layer: PRCARE
# 2025-09-15 22:04:46,547 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PRCARE' with 1 files
# 2025-09-15 22:04:46,548 - src.maritime_module.core.s57_data - INFO - Processing layer: RTPBCN
# 2025-09-15 22:04:46,660 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RTPBCN' with 2 files
# 2025-09-15 22:04:46,661 - src.maritime_module.core.s57_data - INFO - Processing layer: SPLARE
# 2025-09-15 22:04:46,725 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SPLARE' with 1 files
# 2025-09-15 22:04:46,726 - src.maritime_module.core.s57_data - INFO - Processing layer: SLOTOP
# 2025-09-15 22:04:46,843 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SLOTOP' with 2 files
# 2025-09-15 22:04:46,844 - src.maritime_module.core.s57_data - INFO - Processing layer: UNSARE
# 2025-09-15 22:04:46,951 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'UNSARE' with 2 files
# 2025-09-15 22:04:46,951 - src.maritime_module.core.s57_data - INFO - Processing layer: CANALS
# 2025-09-15 22:04:47,010 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CANALS' with 1 files
# 2025-09-15 22:04:47,010 - src.maritime_module.core.s57_data - INFO - Processing layer: CTSARE
# 2025-09-15 22:04:47,067 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CTSARE' with 1 files
# 2025-09-15 22:04:47,068 - src.maritime_module.core.s57_data - INFO - Processing layer: CURENT
# 2025-09-15 22:04:47,131 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CURENT' with 1 files
# Creating GeoPackage data source...
# 2025-09-15 22:04:47,137 - src.maritime_module.core.s57_data - INFO - Found 6 S-57 file(s).
# 2025-09-15 22:04:47,137 - src.maritime_module.core.s57_data - INFO - --- Starting optimized 'by_layer' conversion ---
# 2025-09-15 22:04:47,137 - src.maritime_module.core.s57_data - INFO - Files to process: 6, Batch size: 3
# 2025-09-15 22:04:47,138 - src.maritime_module.core.s57_data - INFO - Pre-processing files to extract schemas and ENC names...
# 2025-09-15 22:04:47,193 - src.maritime_module.core.s57_data - INFO - Built unified schemas for 86 layers
# 2025-09-15 22:04:47,194 - src.maritime_module.utils.db_utils - INFO - Output destination '/home/vikont_tux/python_projects_wsl2/1_MaritimeModule_V1/tests/core__real_data/test_output/temp_factory_output/factory_test.gpkg' is ready.
# 2025-09-15 22:04:47,194 - src.maritime_module.core.s57_data - INFO - Processing layer: DSID
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# 2025-09-15 22:04:47,495 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'DSID' with 6 files
# 2025-09-15 22:04:47,496 - src.maritime_module.core.s57_data - INFO - Processing layer: IsolatedNode
# 2025-09-15 22:04:47,607 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'IsolatedNode' with 6 files
# 2025-09-15 22:04:47,608 - src.maritime_module.core.s57_data - INFO - Processing layer: ConnectedNode
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# 2025-09-15 22:04:47,701 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'ConnectedNode' with 6 files
# 2025-09-15 22:04:47,702 - src.maritime_module.core.s57_data - INFO - Processing layer: Edge
# 2025-09-15 22:04:47,788 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'Edge' with 6 files
# 2025-09-15 22:04:47,789 - src.maritime_module.core.s57_data - INFO - Processing layer: Face
# 2025-09-15 22:04:47,884 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'Face' with 6 files
# 2025-09-15 22:04:47,885 - src.maritime_module.core.s57_data - INFO - Processing layer: ADMARE
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: The output driver does not seem to natively support StringList type for field LNAM_REFS. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support IntegerList type for field FFPT_RIND. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# 2025-09-15 22:04:48,307 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'ADMARE' with 6 files
# 2025-09-15 22:04:48,308 - src.maritime_module.core.s57_data - INFO - Processing layer: AIRARE
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# 2025-09-15 22:04:48,464 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'AIRARE' with 2 files
# 2025-09-15 22:04:48,465 - src.maritime_module.core.s57_data - INFO - Processing layer: BCNLAT
# Warning 1: The output driver does not seem to natively support StringList type for field LNAM_REFS. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support IntegerList type for field FFPT_RIND. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field CATAIR. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field STATUS. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: The output driver does not seem to natively support StringList type for field LNAM_REFS. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support IntegerList type for field FFPT_RIND. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field COLOUR. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field COLPAT. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field NATCON. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field STATUS. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: Value of field 'LNAM_REFS' has 62 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 11 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# 2025-09-15 22:04:48,686 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'BCNLAT' with 3 files
# 2025-09-15 22:04:48,687 - src.maritime_module.core.s57_data - INFO - Processing layer: BCNSPP
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Value of field 'LNAM_REFS' has 62 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 11 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 62 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 11 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 62 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 11 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 62 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 11 characters, whereas maximum allowed is 1.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: The output driver does not seem to natively support StringList type for field LNAM_REFS. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support IntegerList type for field FFPT_RIND. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field CATSPM. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field COLOUR. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field COLPAT. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field NATCON. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: The output driver does not seem to natively support StringList type for field STATUS. Converting it to String(JSON) instead. -mapFieldType can be used to control field type conversion.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# 2025-09-15 22:04:48,922 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'BCNSPP' with 3 files
# 2025-09-15 22:04:48,922 - src.maritime_module.core.s57_data - INFO - Processing layer: BRIDGE
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 82 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 14 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 62 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 11 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Layer creation options ignored since an existing layer is
#          being appended to.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 82 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 14 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 62 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 11 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 8 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 22 characters, whereas maximum allowed is 16.
# Warning 1: Value of field 'FFPT_RIND' has 5 characters, whereas maximum allowed is 1.
# Warning 1: Value of field 'LNAM_REFS' has 42 characters, whereas maximum allowed is 16.
# ...
# 2025-09-15 22:05:09,769 - src.maritime_module.core.s57_data - INFO - Processing layer: EXEZNE
# 2025-09-15 22:05:09,866 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'EXEZNE' with 6 files
# 2025-09-15 22:05:09,867 - src.maritime_module.core.s57_data - INFO - Processing layer: FOGSIG
# 2025-09-15 22:05:09,919 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'FOGSIG' with 3 files
# 2025-09-15 22:05:09,920 - src.maritime_module.core.s57_data - INFO - Processing layer: HRBFAC
# 2025-09-15 22:05:09,940 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'HRBFAC' with 1 files
# 2025-09-15 22:05:09,941 - src.maritime_module.core.s57_data - INFO - Processing layer: LAKARE
# 2025-09-15 22:05:09,996 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LAKARE' with 3 files
# 2025-09-15 22:05:09,997 - src.maritime_module.core.s57_data - INFO - Processing layer: LNDARE
# 2025-09-15 22:05:10,243 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LNDARE' with 5 files
# 2025-09-15 22:05:10,244 - src.maritime_module.core.s57_data - INFO - Processing layer: LNDELV
# 2025-09-15 22:05:10,313 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LNDELV' with 4 files
# 2025-09-15 22:05:10,314 - src.maritime_module.core.s57_data - INFO - Processing layer: LNDRGN
# 2025-09-15 22:05:10,384 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LNDRGN' with 3 files
# 2025-09-15 22:05:10,385 - src.maritime_module.core.s57_data - INFO - Processing layer: LNDMRK
# 2025-09-15 22:05:10,478 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LNDMRK' with 4 files
# 2025-09-15 22:05:10,479 - src.maritime_module.core.s57_data - INFO - Processing layer: LIGHTS
# 2025-09-15 22:05:10,610 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'LIGHTS' with 5 files
# 2025-09-15 22:05:10,612 - src.maritime_module.core.s57_data - INFO - Processing layer: MAGVAR
# 2025-09-15 22:05:10,727 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'MAGVAR' with 6 files
# 2025-09-15 22:05:10,728 - src.maritime_module.core.s57_data - INFO - Processing layer: MIPARE
# 2025-09-15 22:05:10,796 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'MIPARE' with 4 files
# 2025-09-15 22:05:10,797 - src.maritime_module.core.s57_data - INFO - Processing layer: OBSTRN
# 2025-09-15 22:05:10,911 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'OBSTRN' with 5 files
# 2025-09-15 22:05:10,912 - src.maritime_module.core.s57_data - INFO - Processing layer: PIPSOL
# 2025-09-15 22:05:10,969 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PIPSOL' with 3 files
# 2025-09-15 22:05:10,970 - src.maritime_module.core.s57_data - INFO - Processing layer: RDOCAL
# 2025-09-15 22:05:10,993 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RDOCAL' with 1 files
# 2025-09-15 22:05:10,994 - src.maritime_module.core.s57_data - INFO - Processing layer: RDOSTA
# 2025-09-15 22:05:11,064 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RDOSTA' with 4 files
# 2025-09-15 22:05:11,065 - src.maritime_module.core.s57_data - INFO - Processing layer: RECTRC
# 2025-09-15 22:05:11,102 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RECTRC' with 2 files
# 2025-09-15 22:05:11,103 - src.maritime_module.core.s57_data - INFO - Processing layer: RESARE
# 2025-09-15 22:05:11,187 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RESARE' with 5 files
# 2025-09-15 22:05:11,188 - src.maritime_module.core.s57_data - INFO - Processing layer: RIVERS
# 2025-09-15 22:05:11,274 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RIVERS' with 4 files
# 2025-09-15 22:05:11,274 - src.maritime_module.core.s57_data - INFO - Processing layer: SEAARE
# 2025-09-15 22:05:11,410 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SEAARE' with 6 files
# 2025-09-15 22:05:11,411 - src.maritime_module.core.s57_data - INFO - Processing layer: SBDARE
# 2025-09-15 22:05:11,571 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SBDARE' with 5 files
# 2025-09-15 22:05:11,572 - src.maritime_module.core.s57_data - INFO - Processing layer: SLCONS
# 2025-09-15 22:05:11,711 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SLCONS' with 4 files
# 2025-09-15 22:05:11,711 - src.maritime_module.core.s57_data - INFO - Processing layer: SILTNK
# 2025-09-15 22:05:11,763 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SILTNK' with 3 files
# 2025-09-15 22:05:11,764 - src.maritime_module.core.s57_data - INFO - Processing layer: SLOGRD
# 2025-09-15 22:05:11,811 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SLOGRD' with 2 files
# 2025-09-15 22:05:11,812 - src.maritime_module.core.s57_data - INFO - Processing layer: SOUNDG
# 2025-09-15 22:05:12,858 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SOUNDG' with 6 files
# 2025-09-15 22:05:12,858 - src.maritime_module.core.s57_data - INFO - Processing layer: TESARE
# 2025-09-15 22:05:12,912 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'TESARE' with 2 files
# 2025-09-15 22:05:12,913 - src.maritime_module.core.s57_data - INFO - Processing layer: TOPMAR
# 2025-09-15 22:05:12,951 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'TOPMAR' with 2 files
# 2025-09-15 22:05:12,952 - src.maritime_module.core.s57_data - INFO - Processing layer: TSSBND
# 2025-09-15 22:05:13,004 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'TSSBND' with 3 files
# 2025-09-15 22:05:13,004 - src.maritime_module.core.s57_data - INFO - Processing layer: TSSLPT
# 2025-09-15 22:05:13,063 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'TSSLPT' with 3 files
# 2025-09-15 22:05:13,064 - src.maritime_module.core.s57_data - INFO - Processing layer: TSEZNE
# 2025-09-15 22:05:13,102 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'TSEZNE' with 2 files
# 2025-09-15 22:05:13,103 - src.maritime_module.core.s57_data - INFO - Processing layer: UWTROC
# 2025-09-15 22:05:13,249 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'UWTROC' with 4 files
# 2025-09-15 22:05:13,250 - src.maritime_module.core.s57_data - INFO - Processing layer: WATTUR
# 2025-09-15 22:05:13,276 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'WATTUR' with 1 files
# 2025-09-15 22:05:13,277 - src.maritime_module.core.s57_data - INFO - Processing layer: WEDKLP
# 2025-09-15 22:05:13,333 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'WEDKLP' with 2 files
# 2025-09-15 22:05:13,334 - src.maritime_module.core.s57_data - INFO - Processing layer: WRECKS
# 2025-09-15 22:05:13,417 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'WRECKS' with 3 files
# 2025-09-15 22:05:13,418 - src.maritime_module.core.s57_data - INFO - Processing layer: M_COVR
# 2025-09-15 22:05:13,531 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'M_COVR' with 6 files
# 2025-09-15 22:05:13,532 - src.maritime_module.core.s57_data - INFO - Processing layer: M_NPUB
# 2025-09-15 22:05:13,649 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'M_NPUB' with 6 files
# 2025-09-15 22:05:13,649 - src.maritime_module.core.s57_data - INFO - Processing layer: M_NSYS
# 2025-09-15 22:05:13,759 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'M_NSYS' with 6 files
# 2025-09-15 22:05:13,759 - src.maritime_module.core.s57_data - INFO - Processing layer: M_QUAL
# 2025-09-15 22:05:13,894 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'M_QUAL' with 6 files
# 2025-09-15 22:05:13,894 - src.maritime_module.core.s57_data - INFO - Processing layer: C_AGGR
# 2025-09-15 22:05:13,948 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'C_AGGR' with 3 files
# 2025-09-15 22:05:13,949 - src.maritime_module.core.s57_data - INFO - Processing layer: C_ASSO
# 2025-09-15 22:05:14,006 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'C_ASSO' with 3 files
# 2025-09-15 22:05:14,007 - src.maritime_module.core.s57_data - INFO - Processing layer: FSHZNE
# 2025-09-15 22:05:14,035 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'FSHZNE' with 1 files
# 2025-09-15 22:05:14,036 - src.maritime_module.core.s57_data - INFO - Processing layer: ACHARE
# 2025-09-15 22:05:14,078 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'ACHARE' with 2 files
# 2025-09-15 22:05:14,079 - src.maritime_module.core.s57_data - INFO - Processing layer: CBLARE
# 2025-09-15 22:05:14,121 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CBLARE' with 2 files
# 2025-09-15 22:05:14,122 - src.maritime_module.core.s57_data - INFO - Processing layer: CBLOHD
# 2025-09-15 22:05:14,151 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CBLOHD' with 1 files
# 2025-09-15 22:05:14,152 - src.maritime_module.core.s57_data - INFO - Processing layer: DAMCON
# 2025-09-15 22:05:14,181 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'DAMCON' with 1 files
# 2025-09-15 22:05:14,182 - src.maritime_module.core.s57_data - INFO - Processing layer: FAIRWY
# 2025-09-15 22:05:14,213 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'FAIRWY' with 1 files
# 2025-09-15 22:05:14,213 - src.maritime_module.core.s57_data - INFO - Processing layer: FERYRT
# 2025-09-15 22:05:14,246 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'FERYRT' with 1 files
# 2025-09-15 22:05:14,247 - src.maritime_module.core.s57_data - INFO - Processing layer: MARCUL
# 2025-09-15 22:05:14,278 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'MARCUL' with 1 files
# 2025-09-15 22:05:14,279 - src.maritime_module.core.s57_data - INFO - Processing layer: MORFAC
# 2025-09-15 22:05:14,324 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'MORFAC' with 2 files
# 2025-09-15 22:05:14,325 - src.maritime_module.core.s57_data - INFO - Processing layer: NAVLNE
# 2025-09-15 22:05:14,355 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'NAVLNE' with 1 files
# 2025-09-15 22:05:14,356 - src.maritime_module.core.s57_data - INFO - Processing layer: OFSPLF
# 2025-09-15 22:05:14,408 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'OFSPLF' with 2 files
# 2025-09-15 22:05:14,409 - src.maritime_module.core.s57_data - INFO - Processing layer: PILPNT
# 2025-09-15 22:05:14,454 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PILPNT' with 2 files
# 2025-09-15 22:05:14,454 - src.maritime_module.core.s57_data - INFO - Processing layer: PILBOP
# 2025-09-15 22:05:14,485 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PILBOP' with 1 files
# 2025-09-15 22:05:14,486 - src.maritime_module.core.s57_data - INFO - Processing layer: PIPARE
# 2025-09-15 22:05:14,518 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PIPARE' with 1 files
# 2025-09-15 22:05:14,519 - src.maritime_module.core.s57_data - INFO - Processing layer: PONTON
# 2025-09-15 22:05:14,555 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PONTON' with 1 files
# 2025-09-15 22:05:14,556 - src.maritime_module.core.s57_data - INFO - Processing layer: PRCARE
# 2025-09-15 22:05:14,594 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'PRCARE' with 1 files
# 2025-09-15 22:05:14,595 - src.maritime_module.core.s57_data - INFO - Processing layer: RTPBCN
# 2025-09-15 22:05:14,656 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'RTPBCN' with 2 files
# 2025-09-15 22:05:14,657 - src.maritime_module.core.s57_data - INFO - Processing layer: SPLARE
# 2025-09-15 22:05:14,690 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SPLARE' with 1 files
# 2025-09-15 22:05:14,690 - src.maritime_module.core.s57_data - INFO - Processing layer: SLOTOP
# 2025-09-15 22:05:14,744 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'SLOTOP' with 2 files
# 2025-09-15 22:05:14,745 - src.maritime_module.core.s57_data - INFO - Processing layer: UNSARE
# 2025-09-15 22:05:14,794 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'UNSARE' with 2 files
# 2025-09-15 22:05:14,795 - src.maritime_module.core.s57_data - INFO - Processing layer: CANALS
# 2025-09-15 22:05:14,831 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CANALS' with 1 files
# 2025-09-15 22:05:14,832 - src.maritime_module.core.s57_data - INFO - Processing layer: CTSARE
# 2025-09-15 22:05:14,867 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CTSARE' with 1 files
# 2025-09-15 22:05:14,868 - src.maritime_module.core.s57_data - INFO - Processing layer: CURENT
# 2025-09-15 22:05:14,909 - src.maritime_module.core.s57_data - INFO - -> Successfully processed layer 'CURENT' with 1 files
# test_unanimous_output_across_formats (tests.core__real_data.test_enc_factory.TestENCDataFactory.test_unanimous_output_across_formats)
# Core test: Validates that ENCDataFactory produces consistent GeoDataFrames ...
# Using default layer: ['lndmrk']
# --- Test setup complete ---
#
# --- Running test: Unanimous Output Across Formats ---
# Testing 1 layer(s): ['lndmrk']
# Initializing factories for PostGIS, GPKG, and SpatiaLite...
# 2025-09-15 22:05:14,915 - src.maritime_module.core.s57_data - INFO - Source is a dictionary, initializing PostGISManager.
# 2025-09-15 22:05:14,916 - src.maritime_module.core.s57_data - INFO - Successfully connected to database 'ENC_db'
# 2025-09-15 22:05:14,916 - src.maritime_module.core.s57_data - INFO - Source is a .gpkg file, initializing GPKGManager.
# 2025-09-15 22:05:14,924 - src.maritime_module.core.s57_data - INFO - Successfully connected to GeoPackage 'factory_test.gpkg'
# 2025-09-15 22:05:14,924 - src.maritime_module.core.s57_data - INFO - Source is a .sqlite file, initializing SpatiaLiteManager.
# 2025-09-15 22:05:14,925 - src.maritime_module.core.s57_data - INFO - Successfully connected to SpatiaLite database 'factory_test.sqlite'
#
#   Testing layer: 'lndmrk'
#     Fetching layer 'lndmrk' from all sources...
# 2025-09-15 22:05:14,926 - src.maritime_module.core.s57_data - INFO - Factory: Getting layer 'lndmrk'...
# 2025-09-15 22:05:15,027 - src.maritime_module.core.s57_data - INFO - Factory: Getting layer 'lndmrk'...
# 2025-09-15 22:05:15,174 - src.maritime_module.core.s57_data - INFO - Factory: Getting layer 'lndmrk'...
# 2025-09-15 22:05:15,181 - fiona.ogrext - WARNING - Skipping field ffpt_rind: invalid type (1, 0)
# ok
#     Feature counts match: 251 features
#     ✅ Passed: Schema and content match
#
# === TEST RESULTS SUMMARY ===
# Total layers tested: 1
# ✅ Passed: 1
# ❌ Failed: 0
# ⏭️  Skipped: 0
#
# ✅ Passed layers (1):
#   - lndmrk
#
# --- Tearing down test environment ---
# Removed temporary directory: /home/vikont_tux/python_projects_wsl2/1_MaritimeModule_V1/tests/core__real_data/test_output/temp_factory_output
# 2025-09-15 22:05:15,271 - src.maritime_module.utils.db_utils - INFO - Successfully connected to database 'ENC_db' for schema management.
# 2025-09-15 22:05:15,355 - src.maritime_module.utils.db_utils - INFO - Successfully dropped schema 'factory_test_schema'
# ----------------------------------------------------------------------
# Ran 1 test in 48.040s
#
# OK
# Dropped PostGIS schema: factory_test_schema

# %% [markdown]
# # Test 2: Functional Testing and Data Exploration
#
# This section demonstrates the key functions of `ENCDataFactory`:
#
# 1. **ENC Summary**: Retrieve metadata for all ENCs in your database, including version information
# 2. **Layer Summary**: Examine all available S-57 object classes and their feature counts
# 3. **Usage Band Filtering**: Select ENCs by their usage band (scale category)
# 4. **Bounding Box Retrieval**: Get geographic extents for spatial analysis
#
# Each function works transparently across all supported backends.

# %% [markdown]
# ## 1. Database Summary
#
# Retrieve a comprehensive summary of all ENC datasets in your database, including:
# - Current edition and update numbers stored locally
# - Latest available versions from NOAA (with internet access)
# - Status comparison: whether your data is current or outdated
# - Count of outdated editions vs. outdated updates
#
# **Note**: Setting `check_noaa=True` requires internet access and may take a few seconds
# as it scrapes the official NOAA ENC database for comparison.

# %% [markdown]
# ### PostGIS

# %%
# Define database parameters from environment variables
db_params = {
    'dbname': os.getenv('DB_NAME'),
    'user': os.getenv('DB_USER'),
    'password': os.getenv('DB_PASSWORD'),
    'host': os.getenv('DB_HOST'),
    'port': os.getenv('DB_PORT')
}

from src.nautical_graph_toolkit.core.s57_data import ENCDataFactory

pg_factory = ENCDataFactory(source=db_params, schema="s57_advanced")
pg_factory.get_enc_summary(check_noaa=True)
# Out:
# 2025-09-16 12:54:45,562 - src.maritime_module.core.s57_data - INFO - Source is a dictionary, initializing PostGISManager.
# 2025-09-16 12:54:45,664 - src.maritime_module.core.s57_data - INFO - Successfully connected to database 'ENC_db'
# 2025-09-16 12:54:45,665 - src.maritime_module.core.s57_data - INFO - Factory: Getting ENC summary...
# 2025-09-16 12:54:45,682 - src.maritime_module.core.s57_data - INFO - Checking against NOAA database for latest versions...
# 2025-09-16 12:54:45,684 - src.maritime_module.utils.s57_utils - INFO - Fetching ENC data from https://www.charts.noaa.gov/ENCs/ENCsIndv.shtml
# 2025-09-16 12:54:47,844 - src.maritime_module.utils.s57_utils - INFO - Successfully scraped and parsed NOAA ENC data.
# 2025-09-16 12:54:47,856 - src.maritime_module.utils.s57_utils - INFO - Successfully saved NOAA ENC data to /home/vikont_tux/python_projects_wsl2/1_MaritimeModule_V1/src/maritime_module/data/noaa_database.csv
#        enc_name  db_edition  db_update  noaa_edition  noaa_update  \
# 0  US3CA52M.000          31          0            31            7
# 1  US1EEZ1M.000           9          0             9            0
# 2  US2WC12M.000          27          8            27           12
# 3  US1PO02M.000          21          1            21            1
# 4  US4CA60M.000          37          6            38            2
# 5  US1GC09M.000          65          5            73            0
#
#   noaa_update_date              status  is_outdated
# 0       06/11/2024   Outdated (Update)         True
# 1       06/13/2023          Up-to-date        False
# 2       10/28/2021   Outdated (Update)         True
# 3       03/06/2019          Up-to-date        False
# 4       03/19/2025  Outdated (Edition)         True
# 5       08/18/2025  Outdated (Edition)         True

# %% [markdown]
# ### File-based DB

# %%
file_path = Path.cwd() / 'output' / 's57_advanced.gpkg'

file_factory = ENCDataFactory(source=file_path)
file_factory.get_enc_summary(check_noaa=True)
# Out:
# 2025-09-15 22:19:14,358 - src.maritime_module.core.s57_data - INFO - Source is a .gpkg file, initializing GPKGManager.
# 2025-09-15 22:19:14,364 - src.maritime_module.core.s57_data - INFO - Successfully connected to GeoPackage 's57_advanced.gpkg'
# 2025-09-15 22:19:14,364 - src.maritime_module.core.s57_data - INFO - Factory: Getting ENC summary...
# 2025-09-15 22:19:14,382 - src.maritime_module.core.s57_data - INFO - Checking against NOAA database for latest versions...
# 2025-09-15 22:19:14,383 - src.maritime_module.utils.s57_utils - INFO - Fetching ENC data from https://www.charts.noaa.gov/ENCs/ENCsIndv.shtml
# 2025-09-15 22:19:16,535 - src.maritime_module.utils.s57_utils - INFO - Successfully scraped and parsed NOAA ENC data.
#        enc_name  db_edition  db_update  noaa_edition  noaa_update  \
# 0  US3CA52M.000          31          0            31            7
# 1  US1EEZ1M.000           9          0             9            0
# 2  US2WC12M.000          27          8            27           12
# 3  US1PO02M.000          21          1            21            1
# 4  US4CA60M.000          37          6            38            2
# 5  US1GC09M.000          65          5            73            0
#
#   noaa_update_date              status  is_outdated
# 0       06/11/2024   Outdated (Update)         True
# 1       06/13/2023          Up-to-date        False
# 2       10/28/2021   Outdated (Update)         True
# 3       03/06/2019          Up-to-date        False
# 4       03/19/2025  Outdated (Edition)         True
# 5       08/18/2025  Outdated (Edition)         True

# %% [markdown]
# ## 2. Layer Summary
#
# Examine the structure of your S-57 database by retrieving a summary of all layers:
# - **LayerName**: Full English name of the S-57 object class (e.g., 'Sounding', 'Land area')
# - **Acronym**: 6-letter S-57 code (e.g., 'soundg', 'lndare')
# - **FeatureCount**: Number of features of this type in your database
#
# This helps you understand what data is available and plan your analysis accordingly.
# For example, if 'soundg' has many features, you have good depth data for routing.

# %% [markdown]
# ### PostGIS

# %%
pg_factory.get_layers_summary()
# Out:
# 2025-09-15 22:05:20,847 - src.maritime_module.core.s57_data - INFO - Factory: Getting layers summary...
# 2025-09-15 22:05:20,848 - src.maritime_module.core.s57_data - INFO - Fetching layer summary for schema 's57_advanced'...
# 2025-09-15 22:05:20,853 - src.maritime_module.utils.s57_utils - WARNING - Object Class acronym 'dsid' not found.
#                  LayerName Acronym  FeatureCount
# 0                 Sounding  soundg         10592
# 1                Land area  lndare          1917
# 2                Coastline  coalne          1604
# 3              Seabed area  sbdare           846
# 4            Depth contour  depcnt           790
# ..                     ...     ...           ...
# 77     Marine farm/culture  marcul             1
# 78                 Pontoon  ponton             1
# 79           Pipeline area  pipare             1
# 80  Sea-plane landing area  splare             1
# 81      Precautionary area  prcare             1
#
# [82 rows x 3 columns]

# %% [markdown]
# ### File-based DB

# %%
file_factory.get_layers_summary()
# Out:
# 2025-09-15 22:05:21,315 - src.maritime_module.core.s57_data - INFO - Factory: Getting layers summary...
# 2025-09-15 22:05:21,316 - src.maritime_module.core.s57_data - INFO - Fetching layer summary for GeoPackage 's57_advanced.gpkg'...
# 2025-09-15 22:05:21,383 - src.maritime_module.utils.s57_utils - WARNING - Object Class acronym 'dsid' not found.
#                  LayerName Acronym  FeatureCount
# 0                 Sounding  soundg         10592
# 1                Land area  lndare          1917
# 2                Coastline  coalne          1604
# 3              Seabed area  sbdare           846
# 4            Depth contour  depcnt           790
# ..                     ...     ...           ...
# 77      Precautionary area  prcare             1
# 78                 Pontoon  ponton             1
# 79           Pipeline area  pipare             1
# 80  Sea-plane landing area  splare             1
# 81        Water turbulence  wattur             1
#
# [82 rows x 3 columns]

# %% [markdown]
# ## 3. Filter ENC by Usage Band
#
# S-57 charts are classified into **usage bands** representing different map scales and detail levels:
#
# | Band | Name | Scale Range | Use Case |
# |------|------|-------------|----------|
# | 1 | Overview | < 1:10M | Ocean passages, planning |
# | 2 | General | 1:4M - 1:10M | Coastal routing |
# | 3 | Coastal | 1:1.2M - 1:3M | Approach planning |
# | 4 | Approach | 1:350K - 1:1.2M | Harbor entrance |
# | 5 | Harbor | 1:90K - 1:350K | Port operations |
# | 6 | Berthing | < 1:90K | Detailed maneuvering |
#
# Filter by one or multiple bands to select appropriate charts for your operational area.

# %% [markdown]
# ### PostGIS

# %%
pg_factory.get_encs_by_usage_band(1)
# Out:
# 2025-09-15 22:05:21,832 - src.maritime_module.core.s57_data - INFO - Factory: Getting ENCs for usage band 1...
# ['US1EEZ1M', 'US1GC09M', 'US1PO02M']

# %%
pg_factory.get_encs_by_usage_band([1,3])
# Out:
# 2025-09-15 22:17:45,283 - src.maritime_module.core.s57_data - INFO - Factory: Getting ENCs for usage band [1, 3]...
# ['US1EEZ1M', 'US1GC09M', 'US1PO02M', 'US3CA52M']

# %% [markdown]
# ### File-based DB

# %%
file_factory.get_encs_by_usage_band(1)
# Out:
# 2025-09-15 22:05:55,403 - src.maritime_module.core.s57_data - INFO - Factory: Getting ENCs for usage band 1...
# ['US1EEZ1M', 'US1GC09M', 'US1PO02M']

# %%
file_factory.get_encs_by_usage_band([1,3])
# Out:
# 2025-09-15 22:17:41,024 - src.maritime_module.core.s57_data - INFO - Factory: Getting ENCs for usage band [1, 3]...
# ['US1EEZ1M', 'US1GC09M', 'US1PO02M', 'US3CA52M']

# %% [markdown]
# ## 4. ENC Bounding Box Retrieval
#
# Obtain the geographic extent (bounding box) of selected ENCs for:
# - Spatial filtering: Select data covering a specific region
# - Visualization: Display ENC coverage on maps
# - Analysis: Determine data availability for an area of interest
#
# The output includes the `dsid_dsnm` field (ENC name) to associate each polygon with its source.

# %%
pg_factory.get_enc_bounding_boxes(['US1EEZ1M', 'US1GC09M', 'US1PO02M', 'US3CA52M'])
# Out:
# 2025-09-15 22:19:22,038 - src.maritime_module.core.s57_data - INFO - Factory: Getting bounding boxes for 4 ENCs...
#   dsid_dsnm                                       wkb_geometry
# 0  US1EEZ1M  POLYGON ((150 20.08069, 150 18, 150.81976 18, ...
# 1  US1GC09M  POLYGON ((-76.1 23.65076, -76.1 23.76423, -76....
# 2  US1PO02M  POLYGON ((-154 15.97454, -154 15, -144.05474 1...
# 3  US1PO02M  POLYGON ((-158.27177 61.25, -157.6668 61.25, -...
# 4  US3CA52M  POLYGON ((-123.50108 36.41847, -123.50108 36.1...

# %%
file_factory.get_enc_bounding_boxes(['US1EEZ1M', 'US1GC09M', 'US1PO02M', 'US3CA52M'])
# Out:
# 2025-09-15 22:19:24,320 - src.maritime_module.core.s57_data - INFO - Factory: Getting bounding boxes for 4 ENCs...
#   dsid_dsnm                                           geometry
# 0  US1EEZ1M  POLYGON ((150 20.08069, 150 18, 150.81976 18, ...
# 1  US1GC09M  POLYGON ((-76.1 23.65076, -76.1 23.76423, -76....
# 2  US1PO02M  POLYGON ((-154 15.97454, -154 15, -144.05474 1...
# 3  US1PO02M  POLYGON ((-158.27177 61.25, -157.6668 61.25, -...
# 4  US3CA52M  POLYGON ((-123.50108 36.41847, -123.50108 36.1...
