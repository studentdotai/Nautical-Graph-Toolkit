# %% [markdown]
# # S-57 Reference Data and Utilities
#
# This notebook demonstrates the `S57Utils` class for accessing S-57 reference data and working with object classes, attributes, and property enumerations.
#
# #### Purpose
#
# - **Object Reference**: 217 object types (buoys, lights, soundings, etc.)
# - **Attribute Lookup**: 304 standard attributes for S-57 objects
# - **Property Conversions**: 1400+ coded values mapped to human-readable meanings
# - **Data Validation**: Understanding and validating ENC database contents
#
# #### Workflow Overview
#
# 1. **Setup** - Import S57Utils and connect to data source
# 2. **Object Catalog** - Browse 217 S-57 object classes (layers)
# 3. **Attribute Reference** - Explore 304 standard attributes
# 4. **Property Values** - Convert coded values to meanings
# 5. **Data Conversion** - Apply conversions to real ENC data
# 6. **NOAA Database** - Query live chart catalog for latest versions
#
# #### Data Flow
#
# ```
# S-57 Reference → Object/Attribute Catalog → Property Lookup → ENC Data Conversion → Human-Readable Output
# ```
#
# #### Expected Outputs
#
# - **Reference Tables**: Object classes, attributes, and property enumerations
# - **Converted Data**: ENC layers with acronyms and properties converted
# - **NOAA Catalog**: Latest chart editions and update numbers
#
# #### Required Data
#
# This notebook requires:
# 1. **ENC Data**: S-57 charts converted to PostGIS or GeoPackage format (for examples)
# 2. **Internet Connection** (optional): For live NOAA chart database queries
#
# **Setup Instructions:** See `docs/SETUP.md`
# **Troubleshooting:** See `docs/TROUBLESHOOTING.md`

# %% [markdown]
# ## 1. Configuration
#
# Centralized parameter configuration for S-57 utilities and reference data access.

# %%
# =============================================================================
# NOTEBOOK CONFIGURATION
# =============================================================================

# --- Database Backend (for examples) ---
db_schema = "enc_west"  # Change to your schema name

# --- Layer Examples ---
example_layer = "boyspp"  # Layer to demonstrate conversions (buoys in special position)

# --- File-Based Example ---
example_gpkg = "enc_west.gpkg"  # GeoPackage file for file-based examples



# =============================================================================
# CONFIGURATION SUMMARY
# =============================================================================

print("=" * 70)
print("✓ Configuration loaded")
print("=" * 70)
print(f"Database schema: {db_schema}")
print(f"Example layer: {example_layer}")
print(f"Example file: {example_gpkg}")
print("=" * 70)

# %% [markdown]
# ### 1.1 Imports & Environment Setup
#
# Import required libraries and set up environment variables.

# %%
import sys
import os
from pathlib import Path

# --- Environment Setup ---
from dotenv import load_dotenv

# --- Fix PROJ_LIB Path (Common Conda/Jupyter Issue) ---
# Ensure GDAL/PROJ can find the coordinate database
conda_prefix = sys.prefix
possible_proj_lib = os.path.join(conda_prefix, 'share', 'proj')
if os.path.exists(possible_proj_lib):
    os.environ['PROJ_LIB'] = possible_proj_lib

# --- Project Setup ---
project_root = Path.cwd().parent.parent
assert (project_root / "src" / "nautical_graph_toolkit").exists()

file_path = project_root / 'data' / example_gpkg

# Load environment variables
load_dotenv(project_root / '.env')

# --- Project Imports ---
from nautical_graph_toolkit.utils.s57_utils import S57Utils, NoaaDatabase
from nautical_graph_toolkit.core.s57_data import ENCDataFactory, S57AdvancedConfig, S57Advanced

print("=" * 70)
print("✓ All imports loaded successfully")
print("=" * 70)

# %% [markdown]
# ### 1.2 Initialize Utils Class

# %%
# --- Initialize S57Utils ---
utils = S57Utils()

print("=" * 70)
print("✓ S57Utils initialized successfully")
print("=" * 70)

# %% [markdown]
# ### 1.3 Workflow Context
#
#   This notebook serves as a **reference guide and diagnostic tool** for understanding S-57 data structures. Use it to explore the complete S-57 object and attribute catalog (217 object types, 304 attributes, 1400+ property mappings), convert coded values to human-readable meanings, and validate ENC data contents. This understanding is essential
#   before running conversion workflows—knowing what features and attributes are available helps you make informed choices about which layers to include in your graphs and routing networks.
#
#   **When to Use This Notebook**
#
#   1. **Before `import_s57.ipynb`** - Understand which S-57 layers and attributes are available so you can make informed conversion decisions
#   2. **Understanding data quality** - Verify that converted ENCs contain expected object types and attributes
#   3. **Debugging conversions** - Validate that acronym and property conversions worked correctly
#   4. **Exploring NOAA catalog** - Check the latest chart editions and update numbers before importing
#
#   **Typical Workflow**
#
#   1. Explore S-57 reference data (This notebook) ↓ Understand available features
#   2. Plan conversion strategy (identify layers to include/exclude)
#   3. Run conversion (import_s57.ipynb) ↓ Convert selected ENCs
#   4. Validate converted data (use this notebook to verify) ↓ Check layer contents
#   5. Build graphs with validated data (graph_*_v2.ipynb) ↓ Create routing networks

# %% [markdown]
# ## 2. S-57 Reference Catalog
#
# Access the complete S-57 object and attribute catalog used throughout the nautical_graph_toolkit.

# %% [markdown]
# ### 2.1 Object Classes (Layers)
#
# S-57 defines 217 object classes representing maritime features. Each has code, name, acronym, and primitives.

# %%
utils.get_objects_df()

# %% [markdown]
# ### 2.2 Attributes
#
# Properties that can be attached to S-57 objects, including code, name, type, and class.

# %%
utils.get_attributes_df()

# %% [markdown]
# ### 2.3 Property Values (Enumerations)
#
# For enumerated attributes, codes map to human-readable meanings (e.g., 1 = 'stake, pole, perch, post').

# %%
utils.get_properties_df()

# %% [markdown]
# ### 2.4 Data Conversion Overview
#
# Demonstrate how to load ENC data and apply S-57 conversions for analysis.
#
# **Conversion Options:**
# - **convert_acronyms=True**: Replace 6-letter codes with full English names
# - **convert_properties=True**: Replace enumerated codes with their meanings
# - **prop_mixed=True**: Keep both codes and meanings in output

# %% [markdown]
# ## 3. Practical Examples: Data Conversion
#
# Demonstrate conversion features with real ENC data using different backends.

# %%
db_params = {
    'dbname': os.getenv('DB_NAME'),
    'user': os.getenv('DB_USER'),
    'password': os.getenv('DB_PASSWORD'),
    'host': os.getenv('DB_HOST'),
    'port': os.getenv('DB_PORT')
}

# Validate database parameters
required_params = ['dbname', 'user', 'password', 'host', 'port']
missing_params = [p for p in required_params if not db_params[p]]

if missing_params:
    print(f"❌ Missing database parameters: {', '.join(missing_params)}")
    print("   Please configure your .env file with database credentials")
    raise ValueError("Cannot proceed without database configuration")

print("\n--- Running test: Importing Dataset ---")
try:
    pg_factory = ENCDataFactory(source=db_params, schema=db_schema)
    print(f"✓ Connected to database '{db_params['dbname']}'")
except Exception as e:
    print(f"❌ Failed to connect to database: {e}")
    print("   Please verify your database credentials and connection")
    raise

print("\n--- Running test: Acronym and Property Conversion ---")
layer_name = example_layer

# 1. Get raw data
try:
    gdf_raw = pg_factory.get_layer(layer_name)
    print(f"    ✅ Fetched raw data successfully ({len(gdf_raw)} features).")
except Exception as e:
    print(f"    ❌ Failed to fetch layer '{layer_name}': {e}")
    raise

gdf_raw

# %% [markdown]
# ### 3.1 PostGIS Backend
#
# Demonstrate conversions with PostGIS database connection.

# %% [markdown]
# #### 2. Get data with converted acronyms (Column Names)

# %%
# 2. Get data with converted acronyms
gdf_acronyms = pg_factory.get_layer(layer_name, convert_acronyms=True, prop_mixed=False)

print("    ✅ Converted acronyms successfully.")
gdf_acronyms

# %% [markdown]
# #### 3. Get data with converted properties (Encoded cell data)

# %%
# 3. Get data with converted properties
gdf_props = pg_factory.get_layer(layer_name, convert_acronyms=True, convert_properties=True, prop_mixed=True)

# Verify property conversion succeeded
if 'Buoy shape (boyspp)' in gdf_props.columns or any('shape' in str(c).lower() for c in gdf_props.columns):
    print("    ✅ Converted properties successfully.")
else:
    print("    ⚠️  Property conversion completed but attribute not found in output")

gdf_props

# %% [markdown]
# ### 3.2 GeoPackage Backend
#
# Demonstrate conversions with GeoPackage file-based database.

# %%
# Validate file exists
if not file_path.exists():
    print(f"❌ File not found: {file_path}")
    print("   Please ensure the GeoPackage file has been created via import_s57.ipynb")
    raise FileNotFoundError(f"Cannot proceed without {file_path}")

print("\n--- Running test: Importing Dataset ---")
try:
    file_factory = ENCDataFactory(source=file_path)
    print(f"✓ Connected to GeoPackage '{example_gpkg}'")
except Exception as e:
    print(f"❌ Failed to open GeoPackage: {e}")
    raise

print("\n--- Running test: Acronym and Property Conversion ---")
layer_name = example_layer

# 1. Get raw data
try:
    gdf_raw = file_factory.get_layer(layer_name)
    print(f"    ✅ Fetched raw data successfully ({len(gdf_raw)} features).")
except Exception as e:
    print(f"    ❌ Failed to fetch layer '{layer_name}': {e}")
    raise

gdf_raw

# %% [markdown]
# #### 2. Get data with converted acronyms

# %%
gdf_acronyms = file_factory.get_layer(layer_name, convert_acronyms=True, prop_mixed=False)

print("    ✅ Converted acronyms successfully.")
gdf_acronyms

# %% [markdown]
# #### 3. Get data with converted properties

# %%
gdf_props = file_factory.get_layer(layer_name, convert_acronyms=True, convert_properties=True, prop_mixed=True)

print("    ✅ Converted properties successfully.")
gdf_props

# %% [markdown]
# ## 4. NOAA Chart Database
#
# Access the live NOAA ENC database to check for latest chart versions. Requires internet connection.

# %%
print("\n--- Running test: NOAA ENC Database ---")
try:
    noaa_db = NoaaDatabase()
    noaa_charts = noaa_db.get_charts(force_refresh=True, as_dataframe=True)
    
    if noaa_charts is None or noaa_charts.empty:
        print("⚠️  No chart data retrieved from NOAA")
    else:
        print(f"✓ Successfully retrieved {len(noaa_charts)} charts from NOAA database")
        print(f"  Latest update: {noaa_charts['issue_date'].max()}")
    
    display(noaa_charts)
    
except Exception as e:
    print(f"❌ Failed to fetch NOAA data: {e}")
    print("   This typically indicates:")
    print("   - No internet connection")
    print("   - NOAA website is unavailable")
    print("   - Network firewall/proxy issues")
    print("   Attempting to use cached data if available...")
    try:
        noaa_db = NoaaDatabase()
        noaa_charts = noaa_db.get_charts(as_dataframe=True)
        if noaa_charts is not None:
            print(f"✓ Using cached data ({len(noaa_charts)} charts)")
        else:
            print("⚠️  No cached data available")
    except:
        print("⚠️  Unable to retrieve NOAA data (online or cached)")
