# %% [markdown]
# # S57 Utils

# %% [markdown]
# ## 1. Attributes and Objects

# %%
import sys
import os
from distutils.command.config import config
from pathlib import Path


# Add the src directory to the Python path
project_root = Path.cwd().parent.parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.maritime_module.utils.s57_utils import S57Utils
utils = S57Utils()
# Out:
# /tmp/ipykernel_3140/2712652327.py:3: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   from distutils.command.config import config

# %% [markdown]
# ### S57 Objects / Layers

# %%
utils.get_objects_df()
# Out:
#           code                     objectclass  \
# acronym
# admare       1     Administration area (Named)
# airare       2              Airport / airfield
# achbrt       3                    Anchor berth
# achpnt    1003                          Anchor
# achare       4                  Anchorage area
# ...        ...                             ...
# lg_vsp   18002  Maximum permitted vessel speed
# annota   22001                      Annotation
# restrc   22009                Generic Boundary
# trflne   22010                    Traffic Line
# gennav   22011                  Generic NavAid
#
#                                                attribute_a  \
# acronym
# admare                        JRSDTN;NATION;NOBJNM;OBJNAM;
# airare          CATAIR;CONDTN;CONVIS;NOBJNM;OBJNAM;STATUS;
# achbrt   CATACH;DATEND;DATSTA;NOBJNM;OBJNAM;PEREND;PERS...
# achpnt                                                 NaN
# achare   CATACH;DATEND;DATSTA;NOBJNM;OBJNAM;PEREND;PERS...
# ...                                                    ...
# lg_vsp                                                 NaN
# annota   ANATR1;ANATR2;ANATR3;ANLYR1;ANATR5;ANATR4;ANAT...
# restrc   DATEND;DATSTA;NOBJNM;OBJNAM;PEREND;PERSTA;STATUS;
# trflne   DATEND;DATSTA;NOBJNM;OBJNAM;PEREND;PERSTA;STATUS;
# gennav   DATEND;DATSTA;NOBJNM;OBJNAM;PEREND;PERSTA;STATUS;
#
#                                                attribute_b  \
# acronym
# admare   INFORM;NINFOM;NTXTDS;PICREP;SCAMAX;SCAMIN;TXTDSC;
# airare   INFORM;NINFOM;NTXTDS;PICREP;SCAMAX;SCAMIN;TXTDSC;
# achbrt          INFORM;NINFOM;NTXTDS;SCAMAX;SCAMIN;TXTDSC;
# achpnt                                                 NaN
# achare          INFORM;NINFOM;NTXTDS;SCAMAX;SCAMIN;TXTDSC;
# ...                                                    ...
# lg_vsp   lg_rel;lg_des;lc_csi;lc_cse;lc_asi;lc_ase;lc_c...
# annota          INFORM;NINFOM;NTXTDS;SCAMAX;SCAMIN;TXTDSC;
# restrc          INFORM;NINFOM;NTXTDS;SCAMAX;SCAMIN;TXTDSC;
# trflne          INFORM;NINFOM;NTXTDS;SCAMAX;SCAMIN;TXTDSC;
# gennav          INFORM;NINFOM;NTXTDS;SCAMAX;SCAMIN;TXTDSC;
#
#                           attribute_c class   primitives
# acronym
# admare   RECDAT;RECIND;SORDAT;SORIND;     G        Area;
# airare   RECDAT;RECIND;SORDAT;SORIND;     G  Point;Area;
# achbrt   RECDAT;RECIND;SORDAT;SORIND;     G  Point;Area;
# achpnt                            NaN   NaN          NaN
# achare   RECDAT;RECIND;SORDAT;SORIND;     G  Point;Area;
# ...                               ...   ...          ...
# lg_vsp                 SORDAT;SORIND;     G        Area;
# annota   RECDAT;RECIND;SORDAT;SORIND;     G       Point;
# restrc   RECDAT;RECIND;SORDAT;SORIND;     G        Line;
# trflne   RECDAT;RECIND;SORDAT;SORIND;     G        Line;
# gennav   RECDAT;RECIND;SORDAT;SORIND;     G       Point;
#
# [217 rows x 7 columns]

# %% [markdown]
# ### S57 Attributes / Properties

# %%
utils.get_attributes_df()
# Out:
#             code                           attribute attributetype class
# acronym
# agency       1.0   Agency responsible for production             A     F
# bcnshp       2.0                        Beacon shape             E     F
# buishp       3.0                      Building shape             E     F
# boyshp       4.0                          Buoy shape             E     F
# burdep       5.0                        Buried depth             F     F
# ...          ...                                 ...           ...   ...
# agen         NaN                 Numeric agency code             I   NaN
# fidn         NaN       Feature identification number             I   NaN
# fids         NaN  Feature identification subdivision             I   NaN
# rcid         NaN                   Record identifier             I   NaN
# prim     50001.0          Object geometric primitive             I   NaN
#
# [304 rows x 4 columns]

# %% [markdown]
# ### S57 Property Code Meaning

# %%
utils.get_properties_df()
# Out:
#          Code                   Attribute Acronym Attributetype     ID  \
# 1         2.0                Beacon shape  BCNSHP             E    1.0
# 2         2.0                Beacon shape  BCNSHP             E    2.0
# 3         2.0                Beacon shape  BCNSHP             E    3.0
# 4         2.0                Beacon shape  BCNSHP             E    4.0
# 5         2.0                Beacon shape  BCNSHP             E    5.0
# ...       ...                         ...     ...           ...    ...
# 1622  33066.0                Type of Ship  shptyp             E   15.0
# 1636  50001.0  Object geometric primitive    PRIM             I    1.0
# 1637  50001.0  Object geometric primitive    PRIM             I    2.0
# 1638  50001.0  Object geometric primitive    PRIM             I    3.0
# 1639  50001.0  Object geometric primitive    PRIM             I  255.0
#
#                        Meaning
# 1     stake, pole, perch, post
# 2                        whity
# 3                 beacon tower
# 4               lattice beacon
# 5                  pile beacon
# ...                        ...
# 1622                      boat
# 1636                     Point
# 1637                      Line
# 1638                      Area
# 1639                       Any
#
# [1471 rows x 6 columns]

# %% [markdown]
# ## 2. Convertion Example

# %% [markdown]
# Tests the new conversion features in ENCDataFactory.get_layer.

# %% [markdown]
# ### PostGIS

# %%
from dotenv import load_dotenv
load_dotenv(project_root / '.env')

from src.maritime_module.core.s57_data import ENCDataFactory

db_params = {
    'dbname': os.getenv('DB_NAME'),
    'user': os.getenv('DB_USER'),
    'password': os.getenv('DB_PASSWORD'),
    'host': os.getenv('DB_HOST'),
    'port': os.getenv('DB_PORT')
}

print("\n--- Running test: Importing Dataset ---")
pg_factory = ENCDataFactory(source=db_params, schema="s57_advanced")

print("\n--- Running test: Acronym and Property Conversion ---")
layer_name = 'boyspp' # A good layer with enumerated properties like BOYSHP

# 1. Get raw data
gdf_raw = pg_factory.get_layer(layer_name)

print("    ✅ Fetched raw data successfully.")
gdf_raw
# Out:
# --- Running test: Importing Dataset ---
# 2025-09-15 21:00:50,141 - src.maritime_module.core.s57_data - INFO - Source is a dictionary, initializing PostGISManager.
# 2025-09-15 21:00:50,142 - src.maritime_module.core.s57_data - INFO - Successfully connected to database 'ENC_db'
#
# --- Running test: Acronym and Property Conversion ---
# 2025-09-15 21:00:50,143 - src.maritime_module.core.s57_data - INFO - Factory: Getting layer 'boyspp'...
#     ✅ Fetched raw data successfully.
#     ogc_fid  rcid  prim  grup  objl  rver  agen       fidn   fids  \
# 0        13     1     1     2    19     3   550   29321383     50
# 1        18     1     1     2    19     2   550  175268243  12345
# 2        14     2     1     2    19     2   550   29321359     50
# 3        15     3     1     2    19     4   550   29321392     50
# 4        16     4     1     2    19     2   550   29321390     50
# ..      ...   ...   ...   ...   ...   ...   ...        ...    ...
# 73      138   140     1     2    19     1   550  709558700   8673
# 74      139   141     1     2    19     1   550   33957153     50
# 75      140   142     1     2    19     1   550  253936858   4044
# 76       27  3711     1     2    19     1   550  706997113   7312
# 77       28  3713     1     2    19     1   550  781363483   7312
#
#                 lnam  ... catvtr lg_spr  lg_rel lg_fnc lc_csi lc_cse  lc_asi  \
# 0   022601BF68A70032  ...     []     []      []     []     []     []      []
# 1   02260A7261933039  ...     []     []      []     []     []     []      []
# 2   022601BF688F0032  ...     []     []      []     []     []     []      []
# 3   022601BF68B00032  ...     []     []      []     []     []     []      []
# 4   022601BF68AE0032  ...     []     []      []     []     []     []      []
# ..               ...  ...    ...    ...     ...    ...    ...    ...     ...
# 73  02262A4B01AC21E1  ...     []     []      []     []     []     []      []
# 74  0226020625210032  ...     []     []      []     []     []     []      []
# 75  02260F22C4DA0FCC  ...     []     []      []     []     []     []      []
# 76  02262A23EB791C90  ...     []     []      []     []     []     []      []
# 77  02262E92A91B1C90  ...     []     []      []     []     []     []      []
#
#    lc_ase lc_cci  lc_cce
# 0      []     []      []
# 1      []     []      []
# 2      []     []      []
# 3      []     []      []
# 4      []     []      []
# ..    ...    ...     ...
# 73     []     []      []
# 74     []     []      []
# 75     []     []      []
# 76     []     []      []
# 77     []     []      []
#
# [78 rows x 92 columns]

# %%
# 2. Get data with converted acronyms
gdf_acronyms = pg_factory.get_layer(layer_name, convert_acronyms=True, prop_mixed=False)

print("    ✅ Converted acronyms successfully.")
gdf_acronyms
# Out:
# 2025-09-15 21:00:50,375 - src.maritime_module.core.s57_data - INFO - Factory: Getting layer 'boyspp'...
# 2025-09-15 21:00:50,408 - src.maritime_module.core.s57_data - INFO - Factory: Applying S-57 conversions...
#     ✅ Converted acronyms successfully.
#     ogc_fid  Record identifier (rcid)  Object geometric primitive (prim)  \
# 0        13                         1                                  1
# 1        18                         1                                  1
# 2        14                         2                                  1
# 3        15                         3                                  1
# 4        16                         4                                  1
# ..      ...                       ...                                ...
# 73      138                       140                                  1
# 74      139                       141                                  1
# 75      140                       142                                  1
# 76       27                      3711                                  1
# 77       28                      3713                                  1
#
#     Group number (grup)  Object label code (objl)  Record version (rver)  \
# 0                     2                        19                      3
# 1                     2                        19                      2
# 2                     2                        19                      2
# 3                     2                        19                      4
# 4                     2                        19                      2
# ..                  ...                       ...                    ...
# 73                    2                        19                      1
# 74                    2                        19                      1
# 75                    2                        19                      1
# 76                    2                        19                      1
# 77                    2                        19                      1
#
#     Numeric agency code (agen)  Feature identification number (fidn)  \
# 0                          550                              29321383
# 1                          550                             175268243
# 2                          550                              29321359
# 3                          550                              29321392
# 4                          550                              29321390
# ..                         ...                                   ...
# 73                         550                             709558700
# 74                         550                              33957153
# 75                         550                             253936858
# 76                         550                             706997113
# 77                         550                             781363483
#
#     Feature identification subdivision (fids)  Long name (lnam)  ...  \
# 0                                          50  022601BF68A70032  ...
# 1                                       12345  02260A7261933039  ...
# 2                                          50  022601BF688F0032  ...
# 3                                          50  022601BF68B00032  ...
# 4                                          50  022601BF68AE0032  ...
# ..                                        ...               ...  ...
# 73                                       8673  02262A4B01AC21E1  ...
# 74                                         50  0226020625210032  ...
# 75                                       4044  02260F22C4DA0FCC  ...
# 76                                       7312  02262A23EB791C90  ...
# 77                                       7312  02262E92A91B1C90  ...
#
#    Category of vehicle transfer (catvtr) speed reference (lg_spr)  \
# 0                                     []                       []
# 1                                     []                       []
# 2                                     []                       []
# 3                                     []                       []
# 4                                     []                       []
# ..                                   ...                      ...
# 73                                    []                       []
# 74                                    []                       []
# 75                                    []                       []
# 76                                    []                       []
# 77                                    []                       []
#
#     related issue (lg_rel) Function of legal conditions (lg_fnc)  \
# 0                       []                                    []
# 1                       []                                    []
# 2                       []                                    []
# 3                       []                                    []
# 4                       []                                    []
# ..                     ...                                   ...
# 73                      []                                    []
# 74                      []                                    []
# 75                      []                                    []
# 76                      []                                    []
# 77                      []                                    []
#
#    category of ship (including) (lc_csi)  \
# 0                                     []
# 1                                     []
# 2                                     []
# 3                                     []
# 4                                     []
# ..                                   ...
# 73                                    []
# 74                                    []
# 75                                    []
# 76                                    []
# 77                                    []
#
#    category of ship (excluding) (lc_cse)  \
# 0                                     []
# 1                                     []
# 2                                     []
# 3                                     []
# 4                                     []
# ..                                   ...
# 73                                    []
# 74                                    []
# 75                                    []
# 76                                    []
# 77                                    []
#
#     Assemblies of ship (including) (lc_asi)  \
# 0                                        []
# 1                                        []
# 2                                        []
# 3                                        []
# 4                                        []
# ..                                      ...
# 73                                       []
# 74                                       []
# 75                                       []
# 76                                       []
# 77                                       []
#
#    Assemblies of ship (excluding) (lc_ase)  \
# 0                                       []
# 1                                       []
# 2                                       []
# 3                                       []
# 4                                       []
# ..                                     ...
# 73                                      []
# 74                                      []
# 75                                      []
# 76                                      []
# 77                                      []
#
#    Category of cargo (including) (lc_cci)  \
# 0                                      []
# 1                                      []
# 2                                      []
# 3                                      []
# 4                                      []
# ..                                    ...
# 73                                     []
# 74                                     []
# 75                                     []
# 76                                     []
# 77                                     []
#
#     Category of cargo (excluding) (lc_cce)
# 0                                       []
# 1                                       []
# 2                                       []
# 3                                       []
# 4                                       []
# ..                                     ...
# 73                                      []
# 74                                      []
# 75                                      []
# 76                                      []
# 77                                      []
#
# [78 rows x 92 columns]

# %%
# 3. Get data with converted properties
gdf_props = pg_factory.get_layer(layer_name, convert_acronyms=True, convert_properties=True, prop_mixed=True)

# Check if a known value (e.g., 1 for 'conical') was converted
# gdf_props.assertTrue(any('conical' in str(s) for s in gdf_props['Buoy shape (boyspp)']))
print("    ✅ Converted properties successfully.")
gdf_props
# Out:
# 2025-09-15 21:00:50,929 - src.maritime_module.core.s57_data - INFO - Factory: Getting layer 'boyspp'...
# 2025-09-15 21:00:50,962 - src.maritime_module.core.s57_data - INFO - Factory: Applying S-57 conversions...
#     ✅ Converted properties successfully.
#     ogc_fid  Record identifier (rcid)  Object geometric primitive (prim)  \
# 0        13                         1                                  1
# 1        18                         1                                  1
# 2        14                         2                                  1
# 3        15                         3                                  1
# 4        16                         4                                  1
# ..      ...                       ...                                ...
# 73      138                       140                                  1
# 74      139                       141                                  1
# 75      140                       142                                  1
# 76       27                      3711                                  1
# 77       28                      3713                                  1
#
#     Group number (grup)  Object label code (objl)  Record version (rver)  \
# 0                     2                        19                      3
# 1                     2                        19                      2
# 2                     2                        19                      2
# 3                     2                        19                      4
# 4                     2                        19                      2
# ..                  ...                       ...                    ...
# 73                    2                        19                      1
# 74                    2                        19                      1
# 75                    2                        19                      1
# 76                    2                        19                      1
# 77                    2                        19                      1
#
#     Numeric agency code (agen)  Feature identification number (fidn)  \
# 0                          550                              29321383
# 1                          550                             175268243
# 2                          550                              29321359
# 3                          550                              29321392
# 4                          550                              29321390
# ..                         ...                                   ...
# 73                         550                             709558700
# 74                         550                              33957153
# 75                         550                             253936858
# 76                         550                             706997113
# 77                         550                             781363483
#
#     Feature identification subdivision (fids)  Long name (lnam)  ...  \
# 0                                          50  022601BF68A70032  ...
# 1                                       12345  02260A7261933039  ...
# 2                                          50  022601BF688F0032  ...
# 3                                          50  022601BF68B00032  ...
# 4                                          50  022601BF68AE0032  ...
# ..                                        ...               ...  ...
# 73                                       8673  02262A4B01AC21E1  ...
# 74                                         50  0226020625210032  ...
# 75                                       4044  02260F22C4DA0FCC  ...
# 76                                       7312  02262A23EB791C90  ...
# 77                                       7312  02262E92A91B1C90  ...
#
#    Category of vehicle transfer (catvtr) speed reference (lg_spr)  \
# 0                                   None                     None
# 1                                   None                     None
# 2                                   None                     None
# 3                                   None                     None
# 4                                   None                     None
# ..                                   ...                      ...
# 73                                  None                     None
# 74                                  None                     None
# 75                                  None                     None
# 76                                  None                     None
# 77                                  None                     None
#
#    related issue (lg_rel) Function of legal conditions (lg_fnc)  \
# 0                    None                                  None
# 1                    None                                  None
# 2                    None                                  None
# 3                    None                                  None
# 4                    None                                  None
# ..                    ...                                   ...
# 73                   None                                  None
# 74                   None                                  None
# 75                   None                                  None
# 76                   None                                  None
# 77                   None                                  None
#
#    category of ship (including) (lc_csi)  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# ..                                   ...
# 73                                  None
# 74                                  None
# 75                                  None
# 76                                  None
# 77                                  None
#
#    category of ship (excluding) (lc_cse)  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# ..                                   ...
# 73                                  None
# 74                                  None
# 75                                  None
# 76                                  None
# 77                                  None
#
#    Assemblies of ship (including) (lc_asi)  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ..                                     ...
# 73                                    None
# 74                                    None
# 75                                    None
# 76                                    None
# 77                                    None
#
#    Assemblies of ship (excluding) (lc_ase)  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ..                                     ...
# 73                                    None
# 74                                    None
# 75                                    None
# 76                                    None
# 77                                    None
#
#    Category of cargo (including) (lc_cci)  \
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ..                                    ...
# 73                                   None
# 74                                   None
# 75                                   None
# 76                                   None
# 77                                   None
#
#    Category of cargo (excluding) (lc_cce)
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ..                                    ...
# 73                                   None
# 74                                   None
# 75                                   None
# 76                                   None
# 77                                   None
#
# [78 rows x 92 columns]

# %% [markdown]
# ### File-Based DB

# %%
from src.maritime_module.core.s57_data import ENCDataFactory, S57AdvancedConfig, S57Advanced

file_path = Path.cwd() / 'output' / 's57_advanced.gpkg'

print("\n--- Running test: Importing Dataset ---")
file_factory = ENCDataFactory(source=file_path)

print("\n--- Running test: Acronym and Property Conversion ---")
layer_name = 'boyspp' # A good layer with enumerated properties like BOYSHP

# 1. Get raw data
gdf_raw = file_factory.get_layer(layer_name)

print("    ✅ Fetched raw data successfully.")
gdf_raw
# Out:
# --- Running test: Importing Dataset ---
# 2025-09-15 21:03:50,679 - src.maritime_module.core.s57_data - INFO - Source is a .gpkg file, initializing GPKGManager.
# 2025-09-15 21:03:50,692 - src.maritime_module.core.s57_data - INFO - Successfully connected to GeoPackage 's57_advanced.gpkg'
#
# --- Running test: Acronym and Property Conversion ---
# 2025-09-15 21:03:50,693 - src.maritime_module.core.s57_data - INFO - Factory: Getting layer 'boyspp'...
#     ✅ Fetched raw data successfully.
#     rcid  prim  grup  objl  rver  agen       fidn   fids              lnam  \
# 0      1     1     2    19     3   550   29321383     50  022601BF68A70032
# 1      1     1     2    19     2   550  175268243  12345  02260A7261933039
# 2      2     1     2    19     2   550   29321359     50  022601BF688F0032
# 3      3     1     2    19     4   550   29321392     50  022601BF68B00032
# 4      4     1     2    19     2   550   29321390     50  022601BF68AE0032
# ..   ...   ...   ...   ...   ...   ...        ...    ...               ...
# 73   140     1     2    19     1   550  709558700   8673  02262A4B01AC21E1
# 74   141     1     2    19     1   550   33957153     50  0226020625210032
# 75   142     1     2    19     1   550  253936858   4044  02260F22C4DA0FCC
# 76  3711     1     2    19     1   550  706997113   7312  02262A23EB791C90
# 77  3713     1     2    19     1   550  781363483   7312  02262E92A91B1C90
#
#              lnam_refs  ... catvtr  lg_spr lg_rel lg_fnc lc_csi  lc_cse  \
# 0   [022601BF68A10032]  ...     []      []     []     []     []      []
# 1   [02262794ACF83039]  ...     []      []     []     []     []      []
# 2   [022601BF687E0032]  ...     []      []     []     []     []      []
# 3   [022601BF68B10032]  ...     []      []     []     []     []      []
# 4   [022601BF68AF0032]  ...     []      []     []     []     []      []
# ..                 ...  ...    ...     ...    ...    ...    ...     ...
# 73  [02260A11DBAD21E1]  ...     []      []     []     []     []      []
# 74                  []  ...     []      []     []     []     []      []
# 75  [02260F22C0E40FCC]  ...     []      []     []     []     []      []
# 76  [02262037D6251C90]  ...     []      []     []     []     []      []
# 77  [022617FCD4FA1C90]  ...     []      []     []     []     []      []
#
#    lc_asi lc_ase  lc_cci lc_cce
# 0      []     []      []     []
# 1      []     []      []     []
# 2      []     []      []     []
# 3      []     []      []     []
# 4      []     []      []     []
# ..    ...    ...     ...    ...
# 73     []     []      []     []
# 74     []     []      []     []
# 75     []     []      []     []
# 76     []     []      []     []
# 77     []     []      []     []
#
# [78 rows x 91 columns]

# %% [markdown]
# #### 2. Get data with converted acronyms

# %%
gdf_acronyms = file_factory.get_layer(layer_name, convert_acronyms=True, prop_mixed=False)

print("    ✅ Converted acronyms successfully.")
gdf_acronyms
# Out:
# 2025-09-15 21:04:20,706 - src.maritime_module.core.s57_data - INFO - Factory: Getting layer 'boyspp'...
# 2025-09-15 21:04:20,789 - src.maritime_module.core.s57_data - INFO - Factory: Applying S-57 conversions...
#     ✅ Converted acronyms successfully.
#     Record identifier (rcid)  Object geometric primitive (prim)  \
# 0                          1                                  1
# 1                          1                                  1
# 2                          2                                  1
# 3                          3                                  1
# 4                          4                                  1
# ..                       ...                                ...
# 73                       140                                  1
# 74                       141                                  1
# 75                       142                                  1
# 76                      3711                                  1
# 77                      3713                                  1
#
#     Group number (grup)  Object label code (objl)  Record version (rver)  \
# 0                     2                        19                      3
# 1                     2                        19                      2
# 2                     2                        19                      2
# 3                     2                        19                      4
# 4                     2                        19                      2
# ..                  ...                       ...                    ...
# 73                    2                        19                      1
# 74                    2                        19                      1
# 75                    2                        19                      1
# 76                    2                        19                      1
# 77                    2                        19                      1
#
#     Numeric agency code (agen)  Feature identification number (fidn)  \
# 0                          550                              29321383
# 1                          550                             175268243
# 2                          550                              29321359
# 3                          550                              29321392
# 4                          550                              29321390
# ..                         ...                                   ...
# 73                         550                             709558700
# 74                         550                              33957153
# 75                         550                             253936858
# 76                         550                             706997113
# 77                         550                             781363483
#
#     Feature identification subdivision (fids)  Long name (lnam)  \
# 0                                          50  022601BF68A70032
# 1                                       12345  02260A7261933039
# 2                                          50  022601BF688F0032
# 3                                          50  022601BF68B00032
# 4                                          50  022601BF68AE0032
# ..                                        ...               ...
# 73                                       8673  02262A4B01AC21E1
# 74                                         50  0226020625210032
# 75                                       4044  02260F22C4DA0FCC
# 76                                       7312  02262A23EB791C90
# 77                                       7312  02262E92A91B1C90
#
#    Long names of related features (lnam_refs)  ...  \
# 0                          [022601BF68A10032]  ...
# 1                          [02262794ACF83039]  ...
# 2                          [022601BF687E0032]  ...
# 3                          [022601BF68B10032]  ...
# 4                          [022601BF68AF0032]  ...
# ..                                        ...  ...
# 73                         [02260A11DBAD21E1]  ...
# 74                                         []  ...
# 75                         [02260F22C0E40FCC]  ...
# 76                         [02262037D6251C90]  ...
# 77                         [022617FCD4FA1C90]  ...
#
#    Category of vehicle transfer (catvtr)  speed reference (lg_spr)  \
# 0                                     []                        []
# 1                                     []                        []
# 2                                     []                        []
# 3                                     []                        []
# 4                                     []                        []
# ..                                   ...                       ...
# 73                                    []                        []
# 74                                    []                        []
# 75                                    []                        []
# 76                                    []                        []
# 77                                    []                        []
#
#    related issue (lg_rel) Function of legal conditions (lg_fnc)  \
# 0                      []                                    []
# 1                      []                                    []
# 2                      []                                    []
# 3                      []                                    []
# 4                      []                                    []
# ..                    ...                                   ...
# 73                     []                                    []
# 74                     []                                    []
# 75                     []                                    []
# 76                     []                                    []
# 77                     []                                    []
#
#    category of ship (including) (lc_csi)  \
# 0                                     []
# 1                                     []
# 2                                     []
# 3                                     []
# 4                                     []
# ..                                   ...
# 73                                    []
# 74                                    []
# 75                                    []
# 76                                    []
# 77                                    []
#
#     category of ship (excluding) (lc_cse)  \
# 0                                      []
# 1                                      []
# 2                                      []
# 3                                      []
# 4                                      []
# ..                                    ...
# 73                                     []
# 74                                     []
# 75                                     []
# 76                                     []
# 77                                     []
#
#    Assemblies of ship (including) (lc_asi)  \
# 0                                       []
# 1                                       []
# 2                                       []
# 3                                       []
# 4                                       []
# ..                                     ...
# 73                                      []
# 74                                      []
# 75                                      []
# 76                                      []
# 77                                      []
#
#    Assemblies of ship (excluding) (lc_ase)  \
# 0                                       []
# 1                                       []
# 2                                       []
# 3                                       []
# 4                                       []
# ..                                     ...
# 73                                      []
# 74                                      []
# 75                                      []
# 76                                      []
# 77                                      []
#
#     Category of cargo (including) (lc_cci)  \
# 0                                       []
# 1                                       []
# 2                                       []
# 3                                       []
# 4                                       []
# ..                                     ...
# 73                                      []
# 74                                      []
# 75                                      []
# 76                                      []
# 77                                      []
#
#    Category of cargo (excluding) (lc_cce)
# 0                                      []
# 1                                      []
# 2                                      []
# 3                                      []
# 4                                      []
# ..                                    ...
# 73                                     []
# 74                                     []
# 75                                     []
# 76                                     []
# 77                                     []
#
# [78 rows x 91 columns]

# %% [markdown]
# ### 3. Get data with converted properties

# %%
gdf_props = file_factory.get_layer(layer_name, convert_acronyms=True, convert_properties=True, prop_mixed=True)

print("    ✅ Converted properties successfully.")
gdf_props
# Out:
# 2025-09-15 21:05:05,785 - src.maritime_module.core.s57_data - INFO - Factory: Getting layer 'boyspp'...
# 2025-09-15 21:05:05,867 - src.maritime_module.core.s57_data - INFO - Factory: Applying S-57 conversions...
#     ✅ Converted properties successfully.
#     Record identifier (rcid)  Object geometric primitive (prim)  \
# 0                          1                                  1
# 1                          1                                  1
# 2                          2                                  1
# 3                          3                                  1
# 4                          4                                  1
# ..                       ...                                ...
# 73                       140                                  1
# 74                       141                                  1
# 75                       142                                  1
# 76                      3711                                  1
# 77                      3713                                  1
#
#     Group number (grup)  Object label code (objl)  Record version (rver)  \
# 0                     2                        19                      3
# 1                     2                        19                      2
# 2                     2                        19                      2
# 3                     2                        19                      4
# 4                     2                        19                      2
# ..                  ...                       ...                    ...
# 73                    2                        19                      1
# 74                    2                        19                      1
# 75                    2                        19                      1
# 76                    2                        19                      1
# 77                    2                        19                      1
#
#     Numeric agency code (agen)  Feature identification number (fidn)  \
# 0                          550                              29321383
# 1                          550                             175268243
# 2                          550                              29321359
# 3                          550                              29321392
# 4                          550                              29321390
# ..                         ...                                   ...
# 73                         550                             709558700
# 74                         550                              33957153
# 75                         550                             253936858
# 76                         550                             706997113
# 77                         550                             781363483
#
#     Feature identification subdivision (fids)  Long name (lnam)  \
# 0                                          50  022601BF68A70032
# 1                                       12345  02260A7261933039
# 2                                          50  022601BF688F0032
# 3                                          50  022601BF68B00032
# 4                                          50  022601BF68AE0032
# ..                                        ...               ...
# 73                                       8673  02262A4B01AC21E1
# 74                                         50  0226020625210032
# 75                                       4044  02260F22C4DA0FCC
# 76                                       7312  02262A23EB791C90
# 77                                       7312  02262E92A91B1C90
#
#    Long names of related features (lnam_refs)  ...  \
# 0                          [022601BF68A10032]  ...
# 1                          [02262794ACF83039]  ...
# 2                          [022601BF687E0032]  ...
# 3                          [022601BF68B10032]  ...
# 4                          [022601BF68AF0032]  ...
# ..                                        ...  ...
# 73                         [02260A11DBAD21E1]  ...
# 74                                       None  ...
# 75                         [02260F22C0E40FCC]  ...
# 76                         [02262037D6251C90]  ...
# 77                         [022617FCD4FA1C90]  ...
#
#    Category of vehicle transfer (catvtr) speed reference (lg_spr)  \
# 0                                   None                     None
# 1                                   None                     None
# 2                                   None                     None
# 3                                   None                     None
# 4                                   None                     None
# ..                                   ...                      ...
# 73                                  None                     None
# 74                                  None                     None
# 75                                  None                     None
# 76                                  None                     None
# 77                                  None                     None
#
#    related issue (lg_rel) Function of legal conditions (lg_fnc)  \
# 0                    None                                  None
# 1                    None                                  None
# 2                    None                                  None
# 3                    None                                  None
# 4                    None                                  None
# ..                    ...                                   ...
# 73                   None                                  None
# 74                   None                                  None
# 75                   None                                  None
# 76                   None                                  None
# 77                   None                                  None
#
#    category of ship (including) (lc_csi)  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# ..                                   ...
# 73                                  None
# 74                                  None
# 75                                  None
# 76                                  None
# 77                                  None
#
#    category of ship (excluding) (lc_cse)  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# ..                                   ...
# 73                                  None
# 74                                  None
# 75                                  None
# 76                                  None
# 77                                  None
#
#    Assemblies of ship (including) (lc_asi)  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ..                                     ...
# 73                                    None
# 74                                    None
# 75                                    None
# 76                                    None
# 77                                    None
#
#    Assemblies of ship (excluding) (lc_ase)  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ..                                     ...
# 73                                    None
# 74                                    None
# 75                                    None
# 76                                    None
# 77                                    None
#
#    Category of cargo (including) (lc_cci)  \
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ..                                    ...
# 73                                   None
# 74                                   None
# 75                                   None
# 76                                   None
# 77                                   None
#
#    Category of cargo (excluding) (lc_cce)
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# ..                                    ...
# 73                                   None
# 74                                   None
# 75                                   None
# 76                                   None
# 77                                   None
#
# [78 rows x 91 columns]

# %% [markdown]
# ## 3. NOAA Database Scraper

# %%
from src.maritime_module.utils.s57_utils import NoaaDatabase

noaa_db = NoaaDatabase()

noaa_db.get_charts(force_refresh=True, as_dataframe=True)
# Out:
#       enc_name  edition  update update_application_date issue_date cgds
# 0     US1AK90M       24       2              2024-09-17 2025-05-15   17
# 1     US1BS01M       16       1              2024-08-15 2024-10-10   17
# 2     US1BS02M       12       2              2024-03-22 2025-07-22   17
# 3     US1BS03M       11       5              2018-08-30 2020-11-19   17
# 4     US1BS04M        6       0              2018-08-29 2018-08-29   17
# ...        ...      ...     ...                     ...        ...  ...
# 6364  US6WI01A        1       0              2025-03-06 2025-03-06    9
# 6365  US6WI01M        4       0              2025-03-06 2025-03-06    9
# 6366  US6WI20A        1       1              2024-08-22 2024-09-18    9
# 6367  US6WI20B        1       1              2024-08-22 2024-09-18    9
# 6368  US6WI23A        1       0              2024-08-30 2024-08-30    9
#
# [6369 rows x 6 columns]
