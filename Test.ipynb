# %%
from src.maritime_module.core import S57Converter

# %%
converter = S57Converter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 converter = S57Converter()
#
# TypeError: S57Converter.__init__() missing 3 required positional arguments: 'input_dir', 'output_dest', and 'output_format'
